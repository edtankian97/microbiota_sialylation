# %%
#Library 
library(dplyr)
library(readr)
library(tidyr)
library(data.table)
library(stringr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last

# %%
setwd("/mnt/l/Sia_git/metagen_files/Study01_france_cancer/")

# %%
#Get data from NeuA - FR metagenomic colon cancer

#without a header
View_neuA_FR_40_cutted <-fread("output_data/hmmer_out/file_output_CMP.tsv",
  fill =Inf
)[, 1:25]
 
column_names <-c("target_ID", "accession_1", "tlen", "query_ID", "accession_2", "qlen", "e_value_seq",
                 "score_seq", "bias_seq", "#", "of", "c_value", "i_value", "score_dom", "bias_dom", 
                 "hmm_from", "hmm_to", "ali_from", "ali_to", "env_from", "env_to", "acc", "description",
                 "of_1", "target")

setnames(View_neuA_FR_40_cutted, column_names)

head(View_neuA_FR_40_cutted)
nrow(View_neuA_FR_40_cutted)
# Out:
#   target_ID                                  accession_1 tlen
# 1 PROKKA_ERR479057_bin.6.faa_CHOKBELJ_02120  -           227
# 2 PROKKA_ERR479294_bin.2.faa_IFEJEKBP_02504  -           227
# 3 PROKKA_ERR479287_bin.13.faa_INPKMMIH_01540 -           244
# 4 PROKKA_ERR479287_bin.13.faa_INPKMMIH_00605 -           409
# 5 PROKKA_ERR479165_bin.5.faa_OABKELFG_01894  -           253
# 6 PROKKA_ERR479165_bin.5.faa_OABKELFG_01264  -           242
#   query_ID              accession_2 qlen e_value_seq score_seq bias_seq # ⋯
# 1 neuA_final_mafft_auto -           321  4.6e-84     279.5     1.2      1 ⋯
# 2 neuA_final_mafft_auto -           321  5.1e-84     279.5     1.2      1 ⋯
# 3 neuA_final_mafft_auto -           321  2.7e-07      26.8     0.7      1 ⋯
# 4 neuA_final_mafft_auto -           321  8.8e-03      11.9     0.0      1 ⋯
# 5 neuA_final_mafft_auto -           321  4.0e-57     190.6     0.0      1 ⋯
# 6 neuA_final_mafft_auto -           321  2.2e-22      76.5     0.0      1 ⋯
# ...

# %%
View_neuA_FR_process <- View_neuA_FR_40_cutted  %>% distinct(target_ID, .keep_all = TRUE)

final_neuA_FR_process <-View_neuA_FR_process %>% 
  filter(View_neuA_FR_process$e_value_seq <= 0.001 & View_neuA_FR_process$score_seq >= 50.0)
nrow(final_neuA_FR_process)
# Out:
# [1] 2601

# %%
final_neuA_FR_process$GCF_ID <- str_extract(final_neuA_FR_process$target_ID, "^[^_]+_[^_]+")

final_neuA_FR_process_ID <- final_neuA_FR_process%>% distinct(GCF_ID, .keep_all = TRUE)

neuA_ID_FR <- final_neuA_FR_process_ID[,"GCF_ID"]
head(neuA_ID_FR)
nrow(neuA_ID_FR)
# Out:
#   GCF_ID
# 1 PROKKA_ERR479057
# 2 PROKKA_ERR479294
# 3 PROKKA_ERR479165
# 4 PROKKA_ERR478958
# 5 PROKKA_ERR479206
# 6 PROKKA_ERR479198
# [1] 343

# %%
#without a header
View_pm0188_FR_cutted <-fread("output_data/hmmer_out/file_output_pm0188.tsv",
  fill =Inf
)[, 1:25]

column_names <-c("target_ID", "accession_1", "tlen", "query_ID", "accession_2", "qlen", "e_value_seq",
                 "score_seq", "bias_seq", "#", "of", "c_value", "i_value", "score_dom", "bias_dom", 
                 "hmm_from", "hmm_to", "ali_from", "ali_to", "env_from", "env_to", "acc", "description",
                 "of_1", "target")

setnames(View_pm0188_FR_cutted, column_names)

head(View_pm0188_FR_cutted)
nrow(View_pm0188_FR_cutted)
# Out:
#   target_ID
# 1 PROKKA_ERR479186_bin.7.faa_PKHHDMMO_00144
# 2 PROKKA_ERR479038_bin.16.faa_PROKKA_ERR479038_bin.16.faa_AAJAEEDH_00605
# 3 PROKKA_ERR479038_bin.16.faa_PROKKA_ERR479038_bin.16.faa_AAJAEEDH_00505
# 4 PROKKA_ERR478992_bin.9.faa_MFKFIENB_01072
# 5 PROKKA_ERR479041_bin.5.faa_KMLGJMLK_00564
# 6 PROKKA_ERR479285_bin.30.faa_JBJLPMAM_00439
#   accession_1 tlen query_ID          accession_2 qlen e_value_seq score_seq
# 1 -           182  pm0188_final_auto -           397  8.7e-03     11.7
# 2 -           498  pm0188_final_auto -           397  1.1e-16     58.3
# 3 -           214  pm0188_final_auto -           397  1.0e-02     12.2
# 4 -           182  pm0188_final_auto -           397  5.8e-03     11.7
# 5 -           194  pm0188_final_auto -           397  4.1e-03     12.1
# 6 -           182  pm0188_final_auto -           397  7.3e-03     11.7
#   bias_seq # ⋯ hmm_from hmm_to ali_from ali_to env_from env_to acc
# ...

# %%
View_pm0188_FR_process <- View_pm0188_FR_cutted  %>% distinct(target_ID, .keep_all = TRUE)

final_pm0188_FR_process <-View_pm0188_FR_process %>% 
  filter(View_pm0188_FR_process$e_value_seq <= 0.001 & View_pm0188_FR_process$score_seq >= 50.0)

nrow(final_pm0188_FR_process)
# Out:
# [1] 15

# %%
final_pm0188_FR_process$GCF_ID <- str_extract(final_pm0188_FR_process$target_ID, "^[^_]+_[^_]+")

View_pm0188_FR_process_ID <- final_pm0188_FR_process%>% distinct(GCF_ID, .keep_all = TRUE)

pm0188_ID_FR <- View_pm0188_FR_process_ID[,"GCF_ID"]
head(pm0188_ID_FR)
nrow(pm0188_ID_FR)
# Out:
#   GCF_ID
# 1 PROKKA_ERR479038
# 2 PROKKA_ERR479147
# 3 PROKKA_ERR479049
# 4 PROKKA_ERR479285
# 5 PROKKA_ERR479235
# 6 PROKKA_ERR479226
# [1] 15

# %%
#without a header
View_PF11477_FR_cutted <-fread("output_data/hmmer_out/file_output_PF11477.tsv",
  fill =Inf
)[, 1:25]


column_names <-c("target_ID", "accession_1", "tlen", "query_ID", "accession_2", "qlen", "e_value_seq",
                 "score_seq", "bias_seq", "#", "of", "c_value", "i_value", "score_dom", "bias_dom", 
                 "hmm_from", "hmm_to", "ali_from", "ali_to", "env_from", "env_to", "acc", "description",
                 "of_1", "target")

setnames(View_PF11477_FR_cutted, column_names)

head(View_PF11477_FR_cutted)
nrow(View_PF11477_FR_cutted)
# Out:
#   target_ID                                  accession_1 tlen query_ID
# 1 PROKKA_ERR479049_bin.28.faa_PJPNNFLP_01211 -           168  PM0188
# 2 PROKKA_ERR479066_bin.2.faa_OBLJIPAE_00467  -           138  PM0188
# 3 PROKKA_ERR479235_bin.20.faa_BGKCOBEA_02339 -           132  PM0188
# 4 PROKKA_ERR479182_bin.5.faa_MHKFDHBF_00190  -           142  PM0188
# 5 PROKKA_ERR479063_bin.15.faa_FCBHHOIF_00570 -           132  PM0188
# 6 PROKKA_ERR479281_bin.14.faa_IJEOABAM_03522 -           132  PM0188
#   accession_2 qlen e_value_seq score_seq bias_seq # ⋯ hmm_from hmm_to ali_from
# 1 PF11477.15  390  8.0e-07     25.4      0.0      1 ⋯ 287      361    73
# 2 PF11477.15  390  9.6e-04     14.6      0.1      1 ⋯ 275      354    36
# 3 PF11477.15  390  1.2e-03     15.2      0.6      1 ⋯ 187      247    59
# 4 PF11477.15  390  1.1e-03     12.5      0.0      1 ⋯ 283      352     6
# 5 PF11477.15  390  1.8e-03     14.2      0.7      1 ⋯ 187      246    59
# ...

# %%
View_PF11477_FR_process <- View_PF11477_FR_cutted  %>% distinct(target_ID, .keep_all = TRUE)

final_PF11477_FR_process <-View_PF11477_FR_process %>% 
  filter(View_PF11477_FR_process$e_value_seq <= 0.001 & View_PF11477_FR_process$score_seq >= 50.0)

nrow(final_PF11477_FR_process)
# Out:
# [1] 0

# %%
final_PF11477_FR_process$GCF_ID <- str_extract(final_PF11477_FR_process$target_ID, "^[^_]+_[^_]+")

View_PF11477_FR_process_ID <- final_PF11477_FR_process%>% distinct(GCF_ID, .keep_all = TRUE)

PF11477_ID_FR <- View_PF11477_FR_process_ID[,"GCF_ID"]
head(PF11477_ID_FR)
nrow(PF11477_ID_FR)
# Out:
#      GCF_ID
# [1] 0

# %%
#without a header
View_PF06002_FR <-fread("output_data/hmmer_out/file_output_PF06002.tsv",
  fill =Inf
)[, 1:25]

setnames(View_PF06002_FR, column_names)
head(View_PF06002_FR)
nrow(View_PF06002_FR)
# Out:
#   target_ID
# 1 PROKKA_ERR479203_bin.11.faa_LLKOBHMP_00738
# 2 PROKKA_ERR478966_bin.17.faa_PROKKA_ERR478966_bin.17.faa_OONMHOAO_00598
# 3 PROKKA_ERR479006_bin.6.faa_PROKKA_ERR479006_bin.6.faa_GHOFLPIH_00511
# 4 PROKKA_ERR479078_bin.30.faa_JGNPNAMN_01261
# 5 PROKKA_ERR479272_bin.10.faa_NDCMKLMB_01163
# 6 PROKKA_ERR478977_bin.12.faa_JIPEFJIE_02091
#   accession_1 tlen query_ID accession_2 qlen e_value_seq score_seq bias_seq # ⋯
# 1 -            66  CST-I    PF06002.18  295  0.00300     13.2      0.3      1 ⋯
# 2 -           212  CST-I    PF06002.18  295  0.00012     17.1      0.0      1 ⋯
# 3 -            52  CST-I    PF06002.18  295  0.01300     12.4      0.0      1 ⋯
# 4 -           212  CST-I    PF06002.18  295  0.00026     17.1      0.0      1 ⋯
# 5 -            76  CST-I    PF06002.18  295  0.00130     14.8      1.1      1 ⋯
# 6 -           148  CST-I    PF06002.18  295  0.00520     13.2      0.2      1 ⋯
#   hmm_from hmm_to ali_from ali_to env_from env_to acc  description
# ...

# %%
View_PF06002_FR_process <- View_PF06002_FR  %>% distinct(target_ID, .keep_all = TRUE)

final_PF06002_FR_process <-View_PF06002_FR_process %>% 
  filter(View_PF06002_FR_process$e_value_seq <= 0.001 & View_PF06002_FR_process$score_seq >= 50.0)

head(final_PF06002_FR_process) #zero entries, so I will not continue

final_PF06002_FR_process$GCF_ID <- str_extract(final_PF06002_FR_process$target_ID, "^[^_]+_[^_]+")
# Out:
# Warning message in cbind(parts$left, chars$ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, chars$ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, chars$ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, chars$ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
#      target_ID accession_1 tlen query_ID accession_2 qlen e_value_seq score_seq
#      bias_seq # ⋯ hmm_from hmm_to ali_from ali_to env_from env_to acc
#      description of_1 target

# %%
#without a header
View_neuS_FR_40_cutted <-fread("output_data/hmmer_out/file_output_neuS.tsv",
  fill =Inf
)[, 1:25]

setnames(View_neuS_FR_40_cutted, column_names)
head(View_neuS_FR_40_cutted)
nrow(View_neuS_FR_40_cutted)
# Out:
#   target_ID                                  accession_1 tlen query_ID
# 1 PROKKA_ERR479084_bin.5.faa_DIHOACLE_03060  -           119  neuS_final_auto
# 2 PROKKA_ERR479198_bin.17.faa_NNMAHFLO_01074 -           213  neuS_final_auto
# 3 PROKKA_ERR479289_bin.20.faa_CAMLCKJE_00575 -           314  neuS_final_auto
# 4 PROKKA_ERR479413_bin.17.faa_DCPICOCF_01263 -           361  neuS_final_auto
# 5 PROKKA_ERR479022_bin.6.faa_PDFJBDOL_00215  -           327  neuS_final_auto
# 6 PROKKA_ERR479006_bin.4.faa_KFBEFBME_00137  -           359  neuS_final_auto
#   accession_2 qlen e_value_seq score_seq bias_seq # ⋯ hmm_from hmm_to ali_from
# 1 -           386  3.8e-03      14.2      2.4     1 ⋯  63      177     3
# 2 -           386  9.3e-04      15.6      1.2     1 ⋯ 145      262    98
# 3 -           386  2.5e-27      92.8      0.0     1 ⋯   8      303     1
# 4 -           386  4.1e-38     128.6      5.1     1 ⋯   8      300     2
# ...

# %%
View_neuS_FR_40_process <- View_neuS_FR_40_cutted  %>% distinct(target_ID, .keep_all = TRUE)

final_neuS_FR_process <-View_neuS_FR_40_process %>% 
  filter(View_neuS_FR_40_process$e_value_seq <= 0.001 & View_neuS_FR_40_process$score_seq >= 50.0)

final_neuS_FR_process$GCF_ID <- str_extract(final_neuS_FR_process$target_ID, "^[^_]+_[^_]+")
View_neuS_FR_process_ID <- final_neuS_FR_process%>% distinct(GCF_ID, .keep_all = TRUE)
# Out:
#   target_ID                                  accession_1 tlen query_ID
# 1 PROKKA_ERR479289_bin.20.faa_CAMLCKJE_00575 -           314  neuS_final_auto
# 2 PROKKA_ERR479413_bin.17.faa_DCPICOCF_01263 -           361  neuS_final_auto
# 3 PROKKA_ERR479006_bin.4.faa_KFBEFBME_00137  -           359  neuS_final_auto
# 4 PROKKA_ERR479218_bin.34.faa_PJGLDJPD_01246 -           335  neuS_final_auto
# 5 PROKKA_ERR479173_bin.6.faa_PEEBCOCD_06190  -           325  neuS_final_auto
# 6 PROKKA_ERR479173_bin.6.faa_PEEBCOCD_04924  -           389  neuS_final_auto
#   accession_2 qlen e_value_seq score_seq bias_seq # ⋯ hmm_from hmm_to ali_from
# 1 -           386  2.5e-27      92.8      0.0     1 ⋯   8      303      1
# 2 -           386  4.1e-38     128.6      5.1     1 ⋯   8      300      2
# 3 -           386  1.4e-15      53.8     12.4     1 ⋯   8      330      1
# 4 -           386  3.6e-64     214.5     25.4     1 ⋯   8      319      1
# ...

# %%
neuS_ID_FR <- View_neuS_FR_process_ID[,"GCF_ID"]
head(neuS_ID_FR)
# Out:
#   GCF_ID
# 1 PROKKA_ERR479289
# 2 PROKKA_ERR479413
# 3 PROKKA_ERR479006
# 4 PROKKA_ERR479218
# 5 PROKKA_ERR479173
# 6 PROKKA_ERR479292

# %%
#without a header
View_IPR010866_FR_40_cutted <-fread("output_data/hmmer_out/file_output_IPR010866.tsv",
  fill =Inf
)[, 1:25]

setnames(View_IPR010866_FR_40_cutted, column_names)

head(View_IPR010866_FR_40_cutted)
nrow(View_IPR010866_FR_40_cutted)
# Out:
#   target_ID                                  accession_1 tlen query_ID
# 1 PROKKA_ERR479186_bin.4.faa_APIFGJLE_00707  -           281  IPR010866_auto
# 2 PROKKA_ERR479034_bin.5.faa_AHOKLGBB_01223  -           320  IPR010866_auto
# 3 PROKKA_ERR479254_bin.1.faa_JIODJCMJ_00121  -           360  IPR010866_auto
# 4 PROKKA_ERR479203_bin.27.faa_HAFAJGOO_03533 -           389  IPR010866_auto
# 5 PROKKA_ERR479181_bin.17.faa_AICCALHA_00425 -           322  IPR010866_auto
# 6 PROKKA_ERR479136_bin.4.faa_GDCFGEFG_01057  -           498  IPR010866_auto
#   accession_2 qlen e_value_seq score_seq bias_seq # ⋯ hmm_from hmm_to ali_from
# 1 -           428  3.1e-12     44.0      0.4      1 ⋯ 143      324     44
# 2 -           428  3.1e-09     34.6      4.0      1 ⋯  37      314      4
# 3 -           428  3.1e-16     54.1      1.2      1 ⋯  36      338      1
# 4 -           428  6.8e-21     73.5      1.4      1 ⋯  42      329     24
# ...

# %%
View_IPR010866_FR_40_process <- View_IPR010866_FR_40_cutted  %>% distinct(target_ID, .keep_all = TRUE)

final_IPR010866_FR_process <-View_IPR010866_FR_40_process %>% 
  filter(View_IPR010866_FR_40_process$e_value_seq <= 0.001 & View_IPR010866_FR_40_process$score_seq >= 50.0)

final_IPR010866_FR_process$GCF_ID <- str_extract(final_IPR010866_FR_process$target_ID, "^[^_]+_[^_]+")
View_IPR010866_FR_process_ID <- final_IPR010866_FR_process%>% distinct(GCF_ID, .keep_all = TRUE)

head(View_IPR010866_FR_process_ID)
# Out:
#   target_ID                                  accession_1 tlen query_ID
# 1 PROKKA_ERR479254_bin.1.faa_JIODJCMJ_00121  -           360  IPR010866_auto
# 2 PROKKA_ERR479203_bin.27.faa_HAFAJGOO_03533 -           389  IPR010866_auto
# 3 PROKKA_ERR479139_bin.24.faa_GJBCGFFB_00895 -           335  IPR010866_auto
# 4 PROKKA_ERR479245_bin.7.faa_PECLJAIC_00473  -           324  IPR010866_auto
# 5 PROKKA_ERR479097_bin.17.faa_DBDBOGDB_00419 -           361  IPR010866_auto
# 6 PROKKA_ERR479132_bin.4.faa_APPGMHDI_00571  -           323  IPR010866_auto
#   accession_2 qlen e_value_seq score_seq bias_seq # ⋯ hmm_to ali_from ali_to
# 1 -           428  3.1e-16     54.1      1.2      1 ⋯ 338     1       326
# 2 -           428  6.8e-21     73.5      1.4      1 ⋯ 329    24       352
# 3 -           428  4.5e-23     80.8      3.9      1 ⋯ 316     1       318
# 4 -           428  5.0e-26     88.3      1.9      1 ⋯ 317     3       293
# ...

# %%
IPR010866_ID_FR <- View_IPR010866_FR_process_ID[,"GCF_ID"]
head(IPR010866_ID_FR)
nrow(IPR010866_ID_FR)
# Out:
#   GCF_ID
# 1 PROKKA_ERR479254
# 2 PROKKA_ERR479203
# 3 PROKKA_ERR479139
# 4 PROKKA_ERR479245
# 5 PROKKA_ERR479097
# 6 PROKKA_ERR479132
# [1] 192

# %%
#without a header
View_lst_FR <-fread("output_data/hmmer_out/file_output_lst.tsv",
  fill =Inf
)[, 1:25]

setnames(View_lst_FR, column_names)

head(View_lst_FR)
nrow(View_lst_FR)
# Out:
#   target_ID
# 1 PROKKA_ERR479019_bin.29.faa_GOMOACDP_01670
# 2 PROKKA_ERR479294_bin.15.faa_JEFOIMJM_00009
# 3 PROKKA_ERR479294_bin.15.faa_JEFOIMJM_01764
# 4 PROKKA_ERR479049_bin.27.faa_PLGEJJMN_00828
# 5 PROKKA_ERR478981_bin.21.faa_PROKKA_ERR478981_bin.21.faa_FBELJFPA_01547
# 6 PROKKA_ERR479075_bin.34.faa_DMGMADME_00767
#   accession_1 tlen query_ID       accession_2 qlen e_value_seq score_seq
# 1 -           339  lst_final_auto -           373  2.1e-23      82.1
# 2 -           361  lst_final_auto -           373  1.3e-30     103.9
# 3 -           361  lst_final_auto -           373  6.3e-29      98.3
# 4 -           361  lst_final_auto -           373  3.1e-29      98.3
# 5 -           128  lst_final_auto -           373  4.2e-03      13.5
# 6 -           362  lst_final_auto -           373  4.6e-15      52.6
#   bias_seq # ⋯ hmm_from hmm_to ali_from ali_to env_from env_to acc
# 1  6.3     1 ⋯ 48       340    15       328    4        338    0.71
# ...

# %%
View_lst_FR_40_process <- View_lst_FR  %>% distinct(target_ID, .keep_all = TRUE)

final_lst_FR_process <-View_lst_FR_40_process %>% 
  filter(View_lst_FR_40_process$e_value_seq <= 0.001 & View_lst_FR_40_process$score_seq >= 50.0)

final_lst_FR_process$GCF_ID <- str_extract(final_lst_FR_process$target_ID, "^[^_]+_[^_]+")
View_lst_FR_process_ID <- final_lst_FR_process%>% distinct(GCF_ID, .keep_all = TRUE)

# %%
lst_ID_FR <- View_lst_FR_process_ID[,"GCF_ID"]
head(lst_ID_FR)
nrow(lst_ID_FR)
# Out:
#   GCF_ID
# 1 PROKKA_ERR479019
# 2 PROKKA_ERR479294
# 3 PROKKA_ERR479049
# 4 PROKKA_ERR479075
# 5 PROKKA_ERR479144
# 6 PROKKA_ERR479023
# [1] 134

# %%
#without a header
View_lic3_FR <-fread("output_data/hmmer_out/file_output_lic3.tsv",
  fill =Inf
)[, 1:24]

column_names_lic3 <-c("target_ID", "accession_1", "tlen", "query_ID", "accession_2", "qlen", "e_value_seq",
                 "score_seq", "bias_seq", "#", "of", "c_value", "i_value", "score_dom", "bias_dom", 
                 "hmm_from", "hmm_to", "ali_from", "ali_to", "env_from", "env_to", "acc", "description",
                 "of_1")

setnames(View_lic3_FR, column_names_lic3)

head(View_lic3_FR)
nrow(View_lic3_FR)
# Out:
#   target_ID                                  accession_1 tlen query_ID
# 1 PROKKA_ERR479145_bin.6.faa_ODEPGCMN_04408  -           288  lic3X_final_auto
# 2 PROKKA_ERR479074_bin.21.faa_DHMCAEGM_00714 -           288  lic3X_final_auto
# 3 PROKKA_ERR479074_bin.21.faa_DHMCAEGM_00215 -           254  lic3X_final_auto
# 4 PROKKA_ERR479074_bin.21.faa_DHMCAEGM_00215 -           254  lic3X_final_auto
# 5 PROKKA_ERR479078_bin.21.faa_INLEIJIH_01486 -           132  lic3X_final_auto
# 6 PROKKA_ERR479144_bin.29.faa_AGKOKBPP_02099 -           288  lic3X_final_auto
#   accession_2 qlen e_value_seq score_seq bias_seq # ⋯ bias_dom hmm_from hmm_to
# 1 -           395  4.4e-04     17.6       8.0     1 ⋯  8.0     127      263
# 2 -           395  9.3e-05     17.6       8.0     1 ⋯  8.0     127      263
# 3 -           395  4.8e-04     15.2       0.1     1 ⋯  0.0      54       82
# 4 -           395  4.8e-04     15.2       0.1     2 ⋯  0.1     197      213
# ...

# %%
View_lic3_FR_40_process <- View_lic3_FR  %>% distinct(target_ID, .keep_all = TRUE)

final_lic3_FR_process <-View_lic3_FR_40_process %>% 
  filter(View_lic3_FR_40_process$e_value_seq <= 0.001 & View_lic3_FR_40_process$score_seq >= 50.0)

head(final_lic3_FR_process) #zero entries, so I will not continue
# Out:
# Warning message in cbind(parts$left, chars$ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, chars$ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, chars$ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, chars$ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
#      target_ID accession_1 tlen query_ID accession_2 qlen e_value_seq score_seq
#      bias_seq # ⋯ bias_dom hmm_from hmm_to ali_from ali_to env_from env_to acc
#      description of_1

# %%
final_lic3_FR_process$GCF_ID <- str_extract(final_lic3_FR_process$target_ID, "^[^_]+_[^_]+")
View_lic3_FR_process_ID <- final_lic3_FR_process%>% distinct(GCF_ID, .keep_all = TRUE)

head(View_lic3_FR_process_ID)

lic3_ID_FR <- View_lic3_FR_process_ID[,"GCF_ID"] #0
# Out:
# Warning message in cbind(parts$left, chars$ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, chars$ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, chars$ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
# Warning message in cbind(parts$left, chars$ellip_h, parts$right, deparse.level = 0L):
# “number of rows of result is not a multiple of vector length (arg 2)”
#      target_ID accession_1 tlen query_ID accession_2 qlen e_value_seq score_seq
#      bias_seq # ⋯ hmm_from hmm_to ali_from ali_to env_from env_to acc
#      description of_1 GCF_ID

# %%
###########
#See uniques in coverage 40 for Polisia, CMP and sia sequences- COMPLETE - COMPLETE ANALYSIS
#hmm_final_process - See what is commom between the files

#CMP versus neuS - thais' database
CMP_plus_neuS_comm_40_complete_FR  <- intersect(neuA_ID_FR$GCF_ID, neuS_ID_FR$GCF_ID)
TRUE_CMP_neuS_thais_data_40_complete_FR <- as.data.frame(CMP_plus_neuS_comm_40_complete_FR)
is.data.frame(TRUE_CMP_neuS_thais_data_40_complete_FR)
head(TRUE_CMP_neuS_thais_data_40_complete_FR)
nrow(TRUE_CMP_neuS_thais_data_40_complete_FR)

#CMP versus Lic3 - thais' database
#retrieve none


#CMP versus Lst - thais' database
CMP_plus_Lst_comm_40_complete_FR  <- intersect(neuA_ID_FR$GCF_ID, lst_ID_FR$GCF_ID)
TRUE_CMP_Lst_thais_data_40_complete_FR <- as.data.frame(CMP_plus_Lst_comm_40_complete_FR)
is.data.frame(TRUE_CMP_Lst_thais_data_40_complete_FR)
head(TRUE_CMP_Lst_thais_data_40_complete_FR)
nrow(TRUE_CMP_Lst_thais_data_40_complete_FR)

#CMP versus pm1088 - thais' database
CMP_plus_pm1088_comm_40_complete_FR  <- intersect(neuA_ID_FR$GCF_ID, pm0188_ID_FR$GCF_ID)
TRUE_CMP_pm1088_thais_data_40_complete_FR <- as.data.frame(CMP_plus_pm1088_comm_40_complete_FR)
is.data.frame(TRUE_CMP_pm1088_thais_data_40_complete_FR)
head(TRUE_CMP_pm1088_thais_data_40_complete_FR)
nrow(TRUE_CMP_pm1088_thais_data_40_complete_FR)

#CMP versus pm1088 - PFAM database
#retrieve no hits


# cst2 PFAM versus CMP

#retrieve none

#CMP versus neuS - PFAM database
CMP_plus_neuS_PFAM_comm_40_complete_FR  <- intersect(neuA_ID_FR$GCF_ID, IPR010866_ID_FR$GCF_ID)
TRUE_CMP_neuS_PFAM_data_40_complete_FR <- as.data.frame(CMP_plus_neuS_PFAM_comm_40_complete_FR)
is.data.frame(TRUE_CMP_neuS_PFAM_data_40_complete_FR)
head(TRUE_CMP_neuS_PFAM_data_40_complete_FR)
nrow(TRUE_CMP_neuS_PFAM_data_40_complete_FR)
# Out:
# [1] TRUE
#   CMP_plus_neuS_comm_40_complete_FR
# 1 PROKKA_ERR479057
# 2 PROKKA_ERR479294
# 3 PROKKA_ERR479165
# 4 PROKKA_ERR479206
# 5 PROKKA_ERR479198
# 6 PROKKA_ERR479212
# [1] 216
# [1] TRUE
#   CMP_plus_Lst_comm_40_complete_FR
# 1 PROKKA_ERR479294
# 2 PROKKA_ERR479206
# 3 PROKKA_ERR479212
# 4 PROKKA_ERR479103
# 5 PROKKA_ERR479203
# 6 PROKKA_ERR479209
# [1] 134
# [1] TRUE
#   CMP_plus_pm1088_comm_40_complete_FR
# 1 PROKKA_ERR479084
# 2 PROKKA_ERR479051
# 3 PROKKA_ERR479083
# 4 PROKKA_ERR479147
# 5 PROKKA_ERR479047
# 6 PROKKA_ERR479049
# [1] 15
# [1] TRUE
#   CMP_plus_neuS_PFAM_comm_40_complete_FR
# 1 PROKKA_ERR479057
# 2 PROKKA_ERR479294
# 3 PROKKA_ERR479206
# 4 PROKKA_ERR479212
# 5 PROKKA_ERR479103
# 6 PROKKA_ERR479203
# [1] 192

# %%
###########################################################################################################

#Retrieve IDs to get sequences for Interpro analysis

# rename colnames to match exactly
colnames(TRUE_CMP_neuS_PFAM_data_40_complete_FR) <- "GCF_ID"
colnames(TRUE_CMP_pm1088_thais_data_40_complete_FR) <- "GCF_ID"
colnames(TRUE_CMP_Lst_thais_data_40_complete_FR) <- "GCF_ID"
colnames(TRUE_CMP_neuS_thais_data_40_complete_FR) <- "GCF_ID"

all_data_FR <- rbind(TRUE_CMP_neuS_PFAM_data_40_complete_FR,TRUE_CMP_pm1088_thais_data_40_complete_FR, TRUE_CMP_Lst_thais_data_40_complete_FR,
                       TRUE_CMP_neuS_thais_data_40_complete_FR)


#Sequences with complete sialylation that are not filtered in Interpro
all_data_FR_unique <-  all_data_FR %>% distinct(GCF_ID)

head(all_data_FR_unique)
nrow(all_data_FR_unique)
# Out:
#   GCF_ID
# 1 PROKKA_ERR479057
# 2 PROKKA_ERR479294
# 3 PROKKA_ERR479206
# 4 PROKKA_ERR479212
# 5 PROKKA_ERR479103
# 6 PROKKA_ERR479203
# [1] 229

# %%
#save output
write_tsv(all_data_FR_unique, "microbiota_sialylation/genomes_download/proteins/completesialylation_GCF_ID.tsv")

# %%
#retrieve sequences

#CMP sialic acid synthase


get_ID_CMP_sequence_FR <- semi_join(final_neuA_FR_process_ID, all_data_FR_unique, by="GCF_ID")
head(get_ID_CMP_sequence_FR)

#select column
get_ID_CMP_sequence_col_FR <- get_ID_CMP_sequence_FR[,1]

#lst
get_ID_lst_sequence_FR <- semi_join(View_lst_FR_process_ID, all_data_FR_unique, by="GCF_ID")
get_ID_lst_sequence_col_FR <- get_ID_lst_sequence_FR[,1]

#pm1088 Thais database
get_ID_pm1088_sequence_FR <- semi_join(View_pm0188_FR_process_ID, all_data_FR_unique, by="GCF_ID")
get_ID_pm1088_sequence_col_FR <- get_ID_pm1088_sequence_FR[,1]

#neuS
# get for PFAM NeuS
get_ID_neuS_sequence_PFAM_FR <- semi_join(View_IPR010866_FR_process_ID, all_data_FR_unique, by="GCF_ID")
get_ID_neuS_sequence_col_PFAM_FR <- get_ID_neuS_sequence_PFAM_FR[,1]

#for  Thais

get_ID_neuS_sequence_FR <- semi_join(View_neuS_FR_process_ID, all_data_FR_unique, by="GCF_ID")
get_ID_neuS_sequence_col_FR <- get_ID_neuS_sequence_FR[,1]

# %%
#save file - No need to do this step, as result is available at PATH: metagen_files/Study01_france_cancer/output_data/Interpro_results/
write_tsv(get_ID_CMP_sequence_col_FR, "bins_paired/all_prokka/CMP_ID_sequence_for_Interpro_france.tsv")
write_tsv(get_ID_lst_sequence_col_FR, "bins_paired/all_prokka/Lst_ID_sequence_for_Interpro_france.tsv")
write_tsv(get_ID_pm1088_sequence_col_FR, "bins_paired/all_prokka/pm0188_ID_sequence_for_Interpro_france.tsv")
write_tsv(get_ID_neuS_sequence_col_PFAM_FR, "bins_paired/all_prokka/neuS_ID_PFAM_sequence_for_Interpro_france.tsv")
write_tsv(get_ID_neuS_sequence_col_FR, "bins_paired/all_prokka/neuS_ID_thais_sequence_for_Interpro_france.tsv")
