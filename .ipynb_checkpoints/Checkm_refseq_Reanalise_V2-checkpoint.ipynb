# %%
#Install and load libraries
library(readr)
library(dplyr)

# %%
setwd("~")

# %%
#Upload summary file

assembly_summary_complete_data <- read_delim("microbiota_sialylation/genomes_download/assembly_complete_summary.tsv", 
                                           delim = "\t", escape_double = FALSE, 
                                           trim_ws = TRUE, col_names = FALSE)
head(assembly_summary_complete_data)
# Out:
# Rows: 38181 Columns: 4
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (4): X1, X2, X3, X4
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   X1              X2                      X3
# 1 GCF_900128725.1 Buchnera aphidicola     strain=BCifornacula
# 2 GCF_003044255.1 Shewanella putrefaciens strain=WS13
# 3 GCF_016406325.1 Shewanella putrefaciens strain=ATCC 8071
# 4 GCF_017068195.1 Shewanella putrefaciens strain=XY07
# 5 GCF_009730575.1 Shewanella putrefaciens strain=FDAARGOS_681
# 6 GCF_025402875.1 Shewanella putrefaciens strain=4H
#   X4
# 1 https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/900/128/725/GCF_900128725.1_BCifornacula_v1.0
# 2 https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/003/044/255/GCF_003044255.1_ASM304425v1
# 3 https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/016/406/325/GCF_016406325.1_ASM1640632v1
# 4 https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/017/068/195/GCF_017068195.1_ASM1706819v1
# 5 https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/009/730/575/GCF_009730575.1_ASM973057v1
# 6 https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/025/402/875/GCF_025402875.1_ASM2540287v1

# %%
#Put columm names
colnames(assembly_summary_complete_data) <- c("ID", "species_name", "species_lineage", "link_download")
#extract ID columm
columm_ID_assembly_complete <- assembly_summary_complete_data[,1]
colnames(columm_ID_assembly_complete) <- "refseq-accession"
head(columm_ID_assembly_complete)
# Out:
#   refseq-accession
# 1 GCF_900128725.1
# 2 GCF_003044255.1
# 3 GCF_016406325.1
# 4 GCF_017068195.1
# 5 GCF_009730575.1
# 6 GCF_025402875.1

# %%
#Save file
write_tsv(columm_ID_assembly_complete, "microbiota_sialylation/genomes_download/assembly_summary_complete_ID.txt")

# %%
#checkM info file upload
CheckM_report_prokaryotes <- read_delim("microbiota_sialylation/genomes_download/CheckM_report_prokaryotes.txt", 
                                        delim = "\t", escape_double = FALSE, 
                                        trim_ws = TRUE)
head(CheckM_report_prokaryotes)
# Out:
# Rows: 351119 Columns: 10
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (6): #genbank-accession, refseq-accession, organism-name, species-name, ...
# dbl (4): taxid, species-taxid, checkm-completeness, checkm-contamination
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   #genbank-accession refseq-accession taxid  species-taxid
# 1 GCA_000005845.2    GCF_000005845.2  511145   562
# 2 GCA_000006765.1    GCF_000006765.1  208964   287
# 3 GCA_000006805.1    GCF_000006805.1   64091  2242
# 4 GCA_000006925.2    GCF_000006925.2  198214   623
# 5 GCA_000007605.1    GCF_000007605.1  227941 83557
# 6 GCA_000008505.1    GCF_000008505.1  281309  1428
#   organism-name                                         species-name
# 1 Escherichia coli str. K-12 substr. MG1655             Escherichia coli
# 2 Pseudomonas aeruginosa PAO1                           Pseudomonas aeruginosa
# 3 Halobacterium salinarum NRC-1                         Halobacterium salinarum
# 4 Shigella flexneri 2a str. 301                         Shigella flexneri
# 5 Chlamydia caviae GPIC                                 Chlamydia caviae
# 6 [Bacillus thuringiensis] serovar konkukian str. 97-27 Bacillus thuringiensis
#   assembly-name checkm-completeness checkm-contamination checkm-marker-set
# 1 ASM584v2      99.48               0.15                 Escherichia coli
# 2 ASM676v1      99.61               0.49                 Pseudomonas aeruginosa
# 3 ASM680v1      99.05               0.22                 Halobacterium
# 4 ASM692v2      97.22               0.47                 Shigella flexneri
# 5 ASM760v1      98.67               0.23                 Chlamydia
# 6 ASM850v1      99.44               0.32                 Bacillus thuringiensis

# %%
#Filter lines

filtered_lines_complete <- CheckM_report_prokaryotes%>%semi_join(columm_ID_assembly_complete, by = "refseq-accession")
View(filtered_lines_complete)
dim(filtered_lines_complete)

#extract lines that did not matched
remain_lines_complete <- anti_join(columm_ID_assembly_complete, filtered_lines_complete, by = "refseq-accession")
dim(remain_lines_complete)

write_delim(remain_lines_complete, "GCF_complete_without_checkM.txt")
# Out:
#       #genbank-accession refseq-accession taxid   species-taxid
# 1     GCA_000005845.2    GCF_000005845.2   511145    562
# 2     GCA_000006765.1    GCF_000006765.1   208964    287
# 3     GCA_000006925.2    GCF_000006925.2   198214    623
# 4     GCA_000007605.1    GCF_000007605.1   227941  83557
# 5     GCA_000008505.1    GCF_000008505.1   281309   1428
# 6     GCA_000008725.1    GCF_000008725.1   272561    813
# 7     GCA_000009045.1    GCF_000009045.1   224308   1423
# 8     GCA_000009085.1    GCF_000009085.1   192222    197
# 9     GCA_000009765.2    GCF_000009765.2   227882  33903
# 10    GCA_000010365.1    GCF_000010365.1   387662 114186
# 11    GCA_000013425.1    GCF_000013425.1    93061   1280
# 12    GCA_000013925.2    GCF_000013925.1   362242   1809
# 13    GCA_000014145.1    GCF_000014145.1   269798    985
# 14    GCA_000015985.1    GCF_000015985.1   349101   1063
# 15    GCA_000017465.2    GCF_000017465.2   360105    200
# 16    GCA_000017725.2    GCF_000017725.2   360104    199
# 17    GCA_000017885.4    GCF_000017885.4   315750   1408
# 18    GCA_000018525.1    GCF_000018525.1   483179  36855
# 19    GCA_000019245.3    GCF_000019245.4     1597   1597
# 20    GCA_000019565.1    GCF_000019565.1   244366 244366
# 21    GCA_000019585.2    GCF_000019585.2   360094    347
# 22    GCA_000020325.1    GCF_000020325.1   436114 436114
# 23    GCA_000020585.3    GCF_000020585.3  1774373 314275
# 24    GCA_000020785.1    GCF_000020785.1   380749 380749
# 25    GCA_000021905.1    GCF_000021905.1   218208 218208
# 26    GCA_000022005.1    GCF_000022005.1   565050 155892
# 27    GCA_000024425.1    GCF_000024425.1   504728    277
# 28    GCA_000025125.1    GCF_000025125.1  1453429 713887
# 29    GCA_000025185.1    GCF_000025185.1   530564    125
# 30    GCA_000025985.1    GCF_000025985.1   272559    817
# ⋮     ⋮                  ⋮                ⋮       ⋮
# 38105 GCA_036542145.1    GCF_036542145.1  3115647 3115647
# 38106 GCA_036542205.1    GCF_036542205.1      573     573
# 38107 GCA_036542225.1    GCF_036542225.1      573     573
# 38108 GCA_036542245.1    GCF_036542245.1      573     573
# 38109 GCA_036542325.1    GCF_036542325.1      238     238
# 38110 GCA_036542345.1    GCF_036542345.1      573     573
# 38111 GCA_036542365.1    GCF_036542365.1      573     573
# 38112 GCA_036542385.1    GCF_036542385.1    33923   33923
# 38113 GCA_036542405.1    GCF_036542405.1     2110    2110
# 38114 GCA_036542425.1    GCF_036542425.1     2110    2110
# 38115 GCA_036542445.1    GCF_036542445.1     2110    2110
# 38116 GCA_036542465.1    GCF_036542465.1     2110    2110
# 38117 GCA_036542485.1    GCF_036542485.1     1351    1351
# 38118 GCA_036549095.1    GCF_036549095.1      573     573
# 38119 GCA_036549115.1    GCF_036549115.1   492670  492670
# 38120 GCA_036549135.1    GCF_036549135.1    72407     573
# 38121 GCA_036549155.1    GCF_036549155.1    34085   34085
# 38122 GCA_036549195.1    GCF_036549195.1      562     562
# 38123 GCA_036549215.1    GCF_036549215.1  3118169 3118169
# 38124 GCA_036549535.1    GCF_036549535.1      549     549
# 38125 GCA_036549555.1    GCF_036549555.1     2110    2110
# 38126 GCA_036549575.1    GCF_036549575.1  3114884 3114884
# 38127 GCA_023669645.2    GCF_023669645.2    48296   48296
# 38128 GCA_036556685.1    GCF_036556685.1  3094835 3094835
# 38129 GCA_036583945.1    GCF_036583945.1    47715   47715
# 38130 GCA_001623645.2    GCF_001623645.2  1454641   28901
# 38131 GCA_030503895.2    GCF_030503895.2  3059077 3059077
# 38132 GCA_034008175.1    GCF_034008175.1      666     666
# 38133 GCA_034008205.1    GCF_034008205.1  3043450 3043450
# 38134 GCA_034008165.1    GCF_034008165.1      666     666
#       organism-name
# 1     Escherichia coli str. K-12 substr. MG1655
# 2     Pseudomonas aeruginosa PAO1
# 3     Shigella flexneri 2a str. 301
# 4     Chlamydia caviae GPIC
# 5     [Bacillus thuringiensis] serovar konkukian str. 97-27
# 6     Chlamydia trachomatis D/UW-3/CX
# 7     Bacillus subtilis subsp. subtilis str. 168
# 8     Campylobacter jejuni subsp. jejuni NCTC 11168 = ATCC 700819
# 9     Streptomyces avermitilis MA-4680 = NBRC 14893
# 10    Candidatus Carsonella ruddii PV
# 11    Staphylococcus aureus subsp. aureus NCTC 8325
# 12    Mycobacterium ulcerans Agy99
# 13    Cytophaga hutchinsonii ATCC 33406
# 14    Cereibacter sphaeroides ATCC 17029
# 15    Campylobacter curvus 525.92
# 16    Campylobacter concisus 13826
# 17    Bacillus pumilus SAFR-032
# 18    Brucella canis ATCC 23365
# 19    Lacticaseibacillus paracasei
# 20    Klebsiella variicola
# 21    Xanthomonas oryzae pv. oryzae PXO99A
# 22    Sulfurihydrogenibium sp. YO3AOP1
# 23    Alteromonas mediterranea DE
# 24    Hydrogenobaculum sp. Y04AAS1
# 25    Desulfatibacillum aliphaticivorans
# 26    Caulobacter vibrioides NA1000
# 27    Meiothermus ruber DSM 1279
# 28    Candidatus Atelocyanobacterium thalassa isolate ALOHA
# 29    Pirellula staleyi DSM 6068
# 30    Bacteroides fragilis NCTC 9343
# ⋮     ⋮
# 38105 Pseudomonas sp. ZY71
# 38106 Klebsiella pneumoniae
# 38107 Klebsiella pneumoniae
# 38108 Klebsiella pneumoniae
# 38109 Elizabethkingia meningoseptica
# 38110 Klebsiella pneumoniae
# 38111 Klebsiella pneumoniae
# 38112 Mycoplasmopsis felis
# 38113 Mycoplasmopsis agalactiae
# 38114 Mycoplasmopsis agalactiae
# 38115 Mycoplasmopsis agalactiae
# 38116 Mycoplasmopsis agalactiae
# 38117 Enterococcus faecalis
# 38118 Klebsiella pneumoniae
# 38119 Bacillus velezensis
# 38120 Klebsiella pneumoniae subsp. pneumoniae
# 38121 Riemerella anatipestifer
# 38122 Escherichia coli
# 38123 Candidatus Blochmannia sp. SNP
# 38124 Pantoea agglomerans
# 38125 Mycoplasmopsis agalactiae
# 38126 Pseudomonas sp. LH21
# 38127 Acinetobacter pittii
# 38128 Sulfurospirillum sp. 1612
# 38129 Lacticaseibacillus rhamnosus
# 38130 Salmonella enterica subsp. enterica serovar Typhimurium str. CDC 2010K-1587
# 38131 Marivirga sp. ABR2-2
# 38132 Vibrio cholerae
# 38133 Pseudomonas sp. P9_35
# 38134 Vibrio cholerae
#       species-name                            assembly-name checkm-completeness
# 1     Escherichia coli                        ASM584v2      99.48
# 2     Pseudomonas aeruginosa                  ASM676v1      99.61
# 3     Shigella flexneri                       ASM692v2      97.22
# 4     Chlamydia caviae                        ASM760v1      98.67
# 5     Bacillus thuringiensis                  ASM850v1      99.44
# 6     Chlamydia trachomatis                   ASM872v1      98.98
# 7     Bacillus subtilis                       ASM904v1      98.62
# 8     Campylobacter jejuni                    ASM908v1      99.59
# 9     Streptomyces avermitilis                ASM976v2      99.91
# 10    Candidatus Carsonella ruddii            ASM1036v1      6.67
# 11    Staphylococcus aureus                   ASM1342v1     97.59
# 12    Mycobacterium ulcerans                  ASM1392v2     94.40
# 13    Cytophaga hutchinsonii                  ASM1414v1     98.81
# 14    Cereibacter sphaeroides                 ASM1598v1     96.21
# 15    Campylobacter curvus                    ASM1746v2     97.60
# 16    Campylobacter concisus                  ASM1772v2     99.58
# 17    Bacillus pumilus                        ASM1788v4     98.10
# 18    Brucella canis                          ASM1852v1     97.72
# 19    Lacticaseibacillus paracasei            ASM1924v3     92.43
# 20    Klebsiella variicola                    ASM1956v1     99.23
# 21    Xanthomonas oryzae                      ASM1958v2     95.49
# 22    Sulfurihydrogenibium sp. YO3AOP1        ASM2032v1     98.77
# 23    Alteromonas mediterranea                ASM2058v3     96.21
# 24    Hydrogenobaculum sp. Y04AAS1            ASM2078v1     99.00
# 25    Desulfatibacillum aliphaticivorans      ASM2190v1     96.29
# 26    Caulobacter vibrioides                  ASM2200v1     99.56
# 27    Meiothermus ruber                       ASM2442v1     99.20
# 28    Candidatus Atelocyanobacterium thalassa ASM2512v1     80.85
# 29    Pirellula staleyi                       ASM2518v1     99.28
# 30    Bacteroides fragilis                    ASM2598v1     99.00
# ⋮     ⋮                                       ⋮             ⋮
# 38105 Pseudomonas sp. ZY71                    ASM3654214v1   99.29
# 38106 Klebsiella pneumoniae                   ASM3654220v1   96.98
# 38107 Klebsiella pneumoniae                   ASM3654222v1   98.30
# 38108 Klebsiella pneumoniae                   ASM3654224v1   96.55
# 38109 Elizabethkingia meningoseptica          ASM3654232v1   89.94
# 38110 Klebsiella pneumoniae                   ASM3654234v1   99.04
# 38111 Klebsiella pneumoniae                   ASM3654236v1   98.56
# 38112 Mycoplasmopsis felis                    ASM3654238v1  100.00
# 38113 Mycoplasmopsis agalactiae               ASM3654240v1   99.37
# 38114 Mycoplasmopsis agalactiae               ASM3654242v1   99.37
# 38115 Mycoplasmopsis agalactiae               ASM3654244v1   99.37
# 38116 Mycoplasmopsis agalactiae               ASM3654246v1   99.37
# 38117 Enterococcus faecalis                   ASM3654248v1   98.60
# 38118 Klebsiella pneumoniae                   ASM3654909v1   98.82
# 38119 Bacillus velezensis                     ASM3654911v1   98.32
# 38120 Klebsiella pneumoniae                   ASM3654913v1   98.43
# 38121 Riemerella anatipestifer                ASM3654915v1   98.74
# 38122 Escherichia coli                        ASM3654919v1   98.37
# 38123 Candidatus Blochmannia sp. SNP          ASM3654921v1   97.60
# 38124 Pantoea agglomerans                     ASM3654953v1   98.01
# 38125 Mycoplasmopsis agalactiae               ASM3654955v1   99.37
# 38126 Pseudomonas sp. LH21                    ASM3654957v1   99.56
# 38127 Acinetobacter pittii                    ASM2366964v2   99.99
# 38128 Sulfurospirillum sp. 1612               ASM3655668v1   86.68
# 38129 Lacticaseibacillus rhamnosus            ASM3658394v1   98.86
# 38130 Salmonella enterica                     ASM162364v2    99.71
# 38131 Marivirga sp. ABR2-2                    ASM3050389v2   99.70
# 38132 Vibrio cholerae                         ASM3400817v1   99.69
# 38133 Pseudomonas sp. P9_35                   ASM3400820v1   99.95
# 38134 Vibrio cholerae                         ASM3400816v1   99.69
#       checkm-contamination checkm-marker-set
# 1     0.15                 Escherichia coli
# 2     0.49                 Pseudomonas aeruginosa
# 3     0.47                 Shigella flexneri
# 4     0.23                 Chlamydia
# 5     0.32                 Bacillus thuringiensis
# 6     2.22                 Chlamydia trachomatis
# 7     1.32                 Bacillus subtilis
# 8     0.25                 Campylobacter jejuni
# 9     1.17                 Streptomyces
# 10    0.00                 Halomonadaceae
# 11    0.39                 Staphylococcus aureus
# 12    0.18                 Mycobacterium
# 13    0.00                 Cytophaga
# 14    2.49                 Rhodobacter sphaeroides
# 15    0.38                 Campylobacter curvus
# 16    0.13                 Campylobacter
# 17    0.19                 Bacillus pumilus
# 18    0.91                 Brucella canis
# 19    2.76                 Lactobacillus paracasei
# 20    0.34                 Klebsiella
# 21    4.47                 Xanthomonas oryzae
# 22    0.59                 Sulfurihydrogenibium
# 23    0.76                 Alteromonas
# 24    0.26                 Hydrogenobaculum
# 25    0.81                 Desulfatibacillum
# 26    1.54                 Caulobacter crescentus
# 27    0.70                 Meiothermus
# 28    0.00                 Chroococcales
# 29    0.00                 Planctomycetia
# 30    0.11                 Bacteroides fragilis
# ⋮     ⋮                    ⋮
# 38105 0.48                 Pseudomonas
# 38106 1.36                 Klebsiella pneumoniae
# 38107 0.19                 Klebsiella pneumoniae
# 38108 0.07                 Klebsiella pneumoniae
# 38109 4.00                 Elizabethkingia
# 38110 0.43                 Klebsiella pneumoniae
# 38111 0.62                 Klebsiella pneumoniae
# 38112 0.00                 Tenericutes
# 38113 0.00                 Tenericutes
# 38114 0.00                 Tenericutes
# 38115 0.00                 Tenericutes
# 38116 0.00                 Tenericutes
# 38117 0.77                 Enterococcus faecalis
# 38118 0.62                 Klebsiella pneumoniae
# 38119 0.00                 Bacillus
# 38120 0.49                 Klebsiella pneumoniae
# 38121 0.10                 Riemerella anatipestifer
# 38122 1.89                 Escherichia coli
# 38123 0.34                 Candidatus Blochmannia
# 38124 0.94                 Pantoea
# 38125 0.00                 Tenericutes
# 38126 0.28                 Pseudomonas
# 38127 0.51                 Acinetobacter
# 38128 5.01                 Sulfurospirillum
# 38129 0.45                 Lactobacillus rhamnosus
# 38130 0.44                 Salmonella enterica
# 38131 0.30                 Cytophagales
# 38132 0.24                 Vibrio cholerae
# 38133 0.30                 Pseudomonas
# 38134 0.64                 Vibrio cholerae
# [1] 38134    10
# [1] 47  1

# %%
#From this step follow the README file instructions in the topic 1.3
#After this, With the GCF_complete_without_checkM.txt file, do in the bash shell command line the command below to retreve remain data
# xargs -a GCF_complete_without_checkM.txt -I {} datasets summary genome accession {} --as-json-lines | dataformat tsv genome --fields organism-name,accession,checkm-completeness,checkm-contamination > remain_CheckM_data.tsv

#data will be saved in remain_CheckM_data.tsv file

# %% [markdown]
# # Part 02

# %%
#Upload file with missing data
remain_CheckM_data_complete <- read_delim("microbiota_sialylation/genomes_download/remain_CheckM_data_complete.tsv", 
                                 delim = "\t", escape_double = FALSE, 
                                 trim_ws = TRUE)
head(remain_CheckM_data_complete)
# Out:
# Rows: 47 Columns: 4
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (2): Organism Name, Assembly Accession
# dbl (2): CheckM completeness, CheckM contamination
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   Organism Name           Assembly Accession CheckM completeness
# 1 Pseudomonas aeruginosa  GCF_024089375.1    94.28
# 2 Acinetobacter baumannii GCF_008802935.1    95.92
# 3 Bordetella pertussis    GCF_022407395.1    96.45
# 4 Bordetella pertussis    GCF_022409195.1    94.19
# 5 Bordetella pertussis    GCF_022407335.1    95.74
# 6 Bordetella pertussis    GCF_022409595.1    92.95
#   CheckM contamination
# 1 0.49
# 2 1.16
# 3 0.43
# 4 0.89
# 5 0.89
# 6 0.96

# %%
#see if there is a NA value 
is.na(remain_CheckM_data_complete)
# Out:
#       Organism Name Assembly Accession CheckM completeness CheckM contamination
#  [1,] FALSE         FALSE              FALSE               FALSE
#  [2,] FALSE         FALSE              FALSE               FALSE
#  [3,] FALSE         FALSE              FALSE               FALSE
#  [4,] FALSE         FALSE              FALSE               FALSE
#  [5,] FALSE         FALSE              FALSE               FALSE
#  [6,] FALSE         FALSE              FALSE               FALSE
#  [7,] FALSE         FALSE              FALSE               FALSE
#  [8,] FALSE         FALSE               TRUE                TRUE
#  [9,] FALSE         FALSE              FALSE               FALSE
# [10,] FALSE         FALSE              FALSE               FALSE
# [11,] FALSE         FALSE              FALSE               FALSE
# [12,] FALSE         FALSE              FALSE               FALSE
# [13,] FALSE         FALSE              FALSE               FALSE
# [14,] FALSE         FALSE              FALSE               FALSE
# [15,] FALSE         FALSE              FALSE               FALSE
# [16,] FALSE         FALSE              FALSE               FALSE
# [17,] FALSE         FALSE              FALSE               FALSE
# [18,] FALSE         FALSE              FALSE               FALSE
# [19,] FALSE         FALSE              FALSE               FALSE
# [20,] FALSE         FALSE              FALSE               FALSE
# [21,] FALSE         FALSE              FALSE               FALSE
# [22,] FALSE         FALSE              FALSE               FALSE
# [23,] FALSE         FALSE              FALSE               FALSE
# [24,] FALSE         FALSE              FALSE               FALSE
# [25,] FALSE         FALSE              FALSE               FALSE
# [26,] FALSE         FALSE              FALSE               FALSE
# [27,] FALSE         FALSE              FALSE               FALSE
# [28,] FALSE         FALSE              FALSE               FALSE
# [29,] FALSE         FALSE              FALSE               FALSE
# [30,] FALSE         FALSE              FALSE               FALSE
# [31,] FALSE         FALSE              FALSE               FALSE
# [32,] FALSE         FALSE              FALSE               FALSE
# [33,] FALSE         FALSE              FALSE               FALSE
# [34,] FALSE         FALSE              FALSE               FALSE
# [35,] FALSE         FALSE               TRUE                TRUE
# [36,] FALSE         FALSE              FALSE               FALSE
# [37,] FALSE         FALSE               TRUE                TRUE
# [38,] FALSE         FALSE              FALSE               FALSE
# [39,] FALSE         FALSE               TRUE                TRUE
# [40,] FALSE         FALSE              FALSE               FALSE
# [41,] FALSE         FALSE              FALSE               FALSE
# [42,] FALSE         FALSE              FALSE               FALSE
# [43,] FALSE         FALSE              FALSE               FALSE
# [44,] FALSE         FALSE              FALSE               FALSE
# [45,] FALSE         FALSE              FALSE               FALSE
# [46,] FALSE         FALSE              FALSE               FALSE
# [47,] FALSE         FALSE              FALSE               FALSE

# %%
#the data has incomplete information with NAs, so we will take those ones, save in another file and then run CheckM separately in bash
#First, take lines with NA
remain_CheckM_data_complete_with_NA <- remain_CheckM_data_complete[!complete.cases(remain_CheckM_data_complete), ]
#take ID columm
remain_CheckM_data_complete_with_NA_ID <- remain_CheckM_data_complete_with_NA[,2]
#save file with only NA
write_tsv(remain_CheckM_data_complete_with_NA_ID, "microbiota_sialylation/genomes_download/remain_CheckM_data_complete_with_NA.tsv")

#Now, we will remove NAs from orginal data to merge after
remain_CheckM_data_complete_no_NA <- na.omit(remain_CheckM_data_complete)
#see if there is a NA value remaining
is.na(remain_CheckM_data_complete_no_NA)
# Out:
#       Organism Name Assembly Accession CheckM completeness CheckM contamination
#  [1,] FALSE         FALSE              FALSE               FALSE
#  [2,] FALSE         FALSE              FALSE               FALSE
#  [3,] FALSE         FALSE              FALSE               FALSE
#  [4,] FALSE         FALSE              FALSE               FALSE
#  [5,] FALSE         FALSE              FALSE               FALSE
#  [6,] FALSE         FALSE              FALSE               FALSE
#  [7,] FALSE         FALSE              FALSE               FALSE
#  [8,] FALSE         FALSE              FALSE               FALSE
#  [9,] FALSE         FALSE              FALSE               FALSE
# [10,] FALSE         FALSE              FALSE               FALSE
# [11,] FALSE         FALSE              FALSE               FALSE
# [12,] FALSE         FALSE              FALSE               FALSE
# [13,] FALSE         FALSE              FALSE               FALSE
# [14,] FALSE         FALSE              FALSE               FALSE
# [15,] FALSE         FALSE              FALSE               FALSE
# [16,] FALSE         FALSE              FALSE               FALSE
# [17,] FALSE         FALSE              FALSE               FALSE
# [18,] FALSE         FALSE              FALSE               FALSE
# [19,] FALSE         FALSE              FALSE               FALSE
# [20,] FALSE         FALSE              FALSE               FALSE
# [21,] FALSE         FALSE              FALSE               FALSE
# [22,] FALSE         FALSE              FALSE               FALSE
# [23,] FALSE         FALSE              FALSE               FALSE
# [24,] FALSE         FALSE              FALSE               FALSE
# [25,] FALSE         FALSE              FALSE               FALSE
# [26,] FALSE         FALSE              FALSE               FALSE
# [27,] FALSE         FALSE              FALSE               FALSE
# [28,] FALSE         FALSE              FALSE               FALSE
# [29,] FALSE         FALSE              FALSE               FALSE
# [30,] FALSE         FALSE              FALSE               FALSE
# [31,] FALSE         FALSE              FALSE               FALSE
# [32,] FALSE         FALSE              FALSE               FALSE
# [33,] FALSE         FALSE              FALSE               FALSE
# [34,] FALSE         FALSE              FALSE               FALSE
# [35,] FALSE         FALSE              FALSE               FALSE
# [36,] FALSE         FALSE              FALSE               FALSE
# [37,] FALSE         FALSE              FALSE               FALSE
# [38,] FALSE         FALSE              FALSE               FALSE
# [39,] FALSE         FALSE              FALSE               FALSE
# [40,] FALSE         FALSE              FALSE               FALSE
# [41,] FALSE         FALSE              FALSE               FALSE
# [42,] FALSE         FALSE              FALSE               FALSE
# [43,] FALSE         FALSE              FALSE               FALSE

# %%
#Filter data from filtered_lines and take completeness and contamination

filter_complete <- filtered_lines_complete[, c(2,8,9)]
head(filter_complete)
# Out:
#   refseq-accession checkm-completeness checkm-contamination
# 1 GCF_000005845.2  99.48               0.15
# 2 GCF_000006765.1  99.61               0.49
# 3 GCF_000006925.2  97.22               0.47
# 4 GCF_000007605.1  98.67               0.23
# 5 GCF_000008505.1  99.44               0.32
# 6 GCF_000008725.1  98.98               2.22

# %%
remain_CheckM2_data <- read_delim("microbiota_sialylation/genomes_download/checkm_result_ncbi/quality_report.tsv", 
                                 delim = "\t", escape_double = FALSE, 
                                 trim_ws = TRUE, col_names=c("Genome_ID", "Completeness", "Contamination"))
head(remain_CheckM2_data)
# Out:
# Rows: 4 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): Genome_ID
# dbl (2): Completeness, Contamination
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   Genome_ID                             Completeness Contamination
# 1 GCF_000146065.2_ASM14606v1_genomic    100.00000    1.09890110
# 2 GCF_000010245.2_ASM1024v1_genomic      99.96693    0.03720238
# 3 GCF_000967155.2_HUSEC2011CHR1_genomic  99.92873    0.14263937
# 4 GCF_000264665.3_ASM26466v2_genomic     99.91192    1.25048393

# %%
#filter columm to match
remain_CheckM2_data_filter <- select(remain_CheckM2_data, Genome_ID, Completeness, Contamination)
#rename columms
colnames(remain_CheckM2_data_filter) <- c("refseq-accession", "checkm-completeness", "checkm-contamination")
colnames(remain_CheckM_data_complete_no_NA) <- c("Organism_name", "refseq-accession", "checkm-completeness", "checkm-contamination")

#select desired columms
remain_CheckM_data_complete_no_NA_filter <- select(remain_CheckM_data_complete_no_NA, `refseq-accession`, `checkm-completeness`, `checkm-contamination`)
filter_complete_final <- select(filter_complete, `refseq-accession`, `checkm-completeness`, `checkm-contamination`)

#join data
join_contamination <- rbind(remain_CheckM_data_complete_no_NA_filter, remain_CheckM2_data_filter)

#join final data  with all completeness and contamination                                             
join_contamination_complete <- rbind(join_contamination, filter_complete_final) 
head(join_contamination_complete)
# Out:
#   refseq-accession checkm-completeness checkm-contamination
# 1 GCF_024089375.1  94.28               0.49
# 2 GCF_008802935.1  95.92               1.16
# 3 GCF_022407395.1  96.45               0.43
# 4 GCF_022409195.1  94.19               0.89
# 5 GCF_022407335.1  95.74               0.89
# 6 GCF_022409595.1  92.95               0.96

# %%
#load libraries and font
install.packages("ggplot2")
install.packages("extrafont")
library(ggplot2)
library(extrafont)
font_import(pattern = "Times") 
yloadfonts()
# Out:
# Installing package into ‘/home/edbvb97/R/x86_64-pc-linux-gnu-library/4.1’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘colorspace’, ‘farver’, ‘labeling’, ‘munsell’, ‘RColorBrewer’, ‘viridisLite’, ‘gtable’, ‘isoband’, ‘scales’
#
#
# Installing package into ‘/home/edbvb97/R/x86_64-pc-linux-gnu-library/4.1’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘extrafontdb’, ‘Rttf2pt1’
#
#
# Registering fonts with R
# Importing fonts may take a few minutes, depending on the number of fonts and the speed of the system.
# Continue? [y/n]  y
# Scanning ttf files in /usr/share/fonts/, /usr/local/share/fonts/ ...
#
# Extracting .afm files from .ttf files...
# Error in data.frame(fontfile = ttfiles, FontName = "", stringsAsFactors = FALSE): arguments imply differing number of rows: 0, 1
# Traceback:
#
# 1. ttf_import(paths, recursive, pattern)
# 2. ttf_extract(ttfiles)
# 3. data.frame(fontfile = ttfiles, FontName = "", stringsAsFactors = FALSE)
# 4. stop(gettextf("arguments imply differing number of rows: %s",
#  .     paste(unique(nrows), collapse = ", ")), domain = NA)
# 5. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = invokeRestart("eval_error",
#  .             cnd))
#  . }, "arguments imply differing number of rows: 0, 1", base::quote(data.frame(fontfile = ttfiles,
#  .     FontName = "", stringsAsFactors = FALSE)))

# %%
# Define the threshold   

threshold <- 10
threshold_completude <- 90

#Count how many meet the conditions
sum(join_contamination_complete$`checkm-contamination` < threshold & join_contamination_complete$`checkm-completeness` >= threshold_completude) #331671


# a data frame with all the annotation info
annotation_contamination_complete <- data.frame(
  x = c(115,30), 
  y = c(5, 22),
  label = c("36.353\n remain","1.828 left"))
# Out:
# [1] 36353

# %%
#ggplot graph
checkm_graph_v2_complete <- ggplot(join_contamination_complete, aes(x= `checkm-completeness`, y= `checkm-contamination`, color = `checkm-contamination` < threshold  & `checkm-completeness` >= threshold_completude )) + 
  geom_point() 


final_graph_v2_complete <-checkm_graph_v2_complete +  scale_color_manual(values = c("#CAE9FF", "#62B6CB"),name = "Contamination\n(Completeness)",
                                                       labels = c("Above 10% (< 90%)", "Below 10% (>= 90%)")) +
  theme_classic()+ theme(text = element_text(family = "Times", face = "bold", size = 16),
                         axis.text.y = element_text(angle = 0, size = 13, colour = "black", family = "Times"),
                         axis.text.x = element_text(angle = 0, size = 13, colour = "black", family = "Times"),
                         legend.text=element_text(size=13, family = "Times"),
                         legend.key.size = unit(0.8, "cm"),
                         legend.title = element_text(margin= margin(t =10, r=0, b=10,l=30))) + scale_x_continuous(breaks = c(0, 10,25, 50, 75, 90, 100),
                                                                                                                  limits = c(0,120)) +
  scale_y_continuous(breaks = c(0,10, 25, 50)) + labs(x= "Completeness", y = " Contamination" )

options(repr.plot.width = 14, repr.plot.height = 7)
print(final_graph_v2_complete)

options(repr.plot.width = 14, repr.plot.height = 7)
final_graph_v2_complete + geom_vline(xintercept = 90)

options(repr.plot.width = 14, repr.plot.height = 7)
final_graph_v2_complete + geom_vline(xintercept = 90, color = "#06402B", linetype = "dashed")+
  geom_hline(yintercept=10, color = "#06402B", linetype = "dashed") + geom_label(data=annotation_contamination_complete,aes( x=x, y=y, label=label),                 , 
                                                                                 color=c("#62B6CB","#CAE9FF"), 
                                                                                 size=4.5 , angle=0, fontface="bold" )
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %%
#Final contamination and completeness analysis e filtering based on threshold to completeness and contamination

#sum(colunas_all_sp$V9 < threshold)
#right_one <-sum(colunas_all_sp$V8 >= threshold_completude)
complete_lines_complete <- join_contamination_complete[join_contamination_complete$`checkm-contamination` < threshold & join_contamination_complete$`checkm-completeness` >= threshold_completude, ]

View(complete_lines_complete)
#save file
write.table(complete_lines_complete, file = "checkm_filter_v2_complete.tsv", sep = "\t", col.names = TRUE)
# Out:
#       refseq-accession checkm-completeness checkm-contamination
# 1     GCF_024089375.1  94.28               0.49
# 2     GCF_008802935.1  95.58               1.12
# 3     GCF_022407395.1  96.77               0.45
# 4     GCF_022409195.1  94.19               0.89
# 5     GCF_022407335.1  95.74               0.89
# 6     GCF_022409595.1  92.95               0.96
# 7     GCF_032346775.1  97.89               3.38
# 8     GCF_020526825.1  99.13               0.15
# 9     GCF_020526805.1  99.13               0.15
# 10    GCF_020526725.1  99.13               0.15
# 11    GCF_020526745.1  99.13               0.15
# 12    GCF_020526785.1  99.13               0.15
# 13    GCF_020526765.1  99.13               0.15
# 14    GCF_020526845.1  99.13               0.15
# 15    GCF_027947475.1  97.77               1.16
# 16    GCF_028735995.1  98.56               1.54
# 17    GCF_013137915.1  99.06               1.21
# 18    GCF_025559665.1  93.68               0.59
# 19    GCF_017378695.1  92.35               0.35
# 20    GCF_025562875.2  99.34               0.63
# 21    GCF_002078615.3  99.06               0.36
# 22    GCF_030061985.1  91.70               1.06
# 23    GCF_030061935.1  92.58               1.06
# 24    GCF_030061915.1  90.81               0.98
# 25    GCF_017068235.1  93.00               1.50
# 26    GCF_002847425.1  98.87               0.62
# 27    GCF_003713105.1  99.15               2.07
# 28    GCF_001051115.1  93.05               0.03
# 29    GCF_001267395.1  92.84               0.24
# 30    GCF_004324035.2  96.02               0.62
# ⋮     ⋮                ⋮                   ⋮
# 36324 GCF_036542105.1   99.18              1.59
# 36325 GCF_036542125.1   99.52              0.44
# 36326 GCF_036542145.1   99.29              0.48
# 36327 GCF_036542205.1   96.98              1.36
# 36328 GCF_036542225.1   98.30              0.19
# 36329 GCF_036542245.1   96.55              0.07
# 36330 GCF_036542345.1   99.04              0.43
# 36331 GCF_036542365.1   98.56              0.62
# 36332 GCF_036542385.1  100.00              0.00
# 36333 GCF_036542405.1   99.37              0.00
# 36334 GCF_036542425.1   99.37              0.00
# 36335 GCF_036542445.1   99.37              0.00
# 36336 GCF_036542465.1   99.37              0.00
# 36337 GCF_036542485.1   98.60              0.77
# 36338 GCF_036549095.1   98.82              0.62
# 36339 GCF_036549115.1   98.32              0.00
# 36340 GCF_036549135.1   98.43              0.49
# 36341 GCF_036549155.1   98.74              0.10
# 36342 GCF_036549195.1   98.37              1.89
# 36343 GCF_036549215.1   97.60              0.34
# 36344 GCF_036549535.1   98.01              0.94
# 36345 GCF_036549555.1   99.37              0.00
# 36346 GCF_036549575.1   99.56              0.28
# 36347 GCF_023669645.2   99.99              0.51
# 36348 GCF_036583945.1   98.86              0.45
# 36349 GCF_001623645.2   99.71              0.44
# 36350 GCF_030503895.2   99.70              0.30
# 36351 GCF_034008175.1   99.69              0.24
# 36352 GCF_034008205.1   99.95              0.30
# 36353 GCF_034008165.1   99.69              0.64
