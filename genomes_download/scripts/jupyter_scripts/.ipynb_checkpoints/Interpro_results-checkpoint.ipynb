# %%
#Upload libraries
library(readr)
library(data.table)
library(dplyr)
library(stringr)

# %%
#Upload data for CMP
matched_CMP_ID_interpro <- read_delim("genomes_download/plots_data/Interpro_results/CMP_ID_sequence_for_Interpro.tsv_retrieved_now_results.tsv", 
                                                       delim = "\t", escape_double = FALSE, 
                                                       col_names = FALSE, trim_ws = TRUE)
head(matched_CMP_ID_interpro)
# Out:
# Rows: 29458 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (11): X1, X2, X4, X5, X6, X9, X11, X12, X13, X14, X15
# dbl  (3): X3, X7, X8
# lgl  (1): X10
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   X1                                         X2
# 1 GCF_000767075.1_protein.faa_WP_038441453.1 8aa4af5264db8082f5c1db7822f7f6dc
# 2 GCF_000767075.1_protein.faa_WP_038441453.1 8aa4af5264db8082f5c1db7822f7f6dc
# 3 GCF_000767075.1_protein.faa_WP_038441453.1 8aa4af5264db8082f5c1db7822f7f6dc
# 4 GCF_000767075.1_protein.faa_WP_038441453.1 8aa4af5264db8082f5c1db7822f7f6dc
# 5 GCF_000767075.1_protein.faa_WP_038441453.1 8aa4af5264db8082f5c1db7822f7f6dc
# 6 GCF_032598905.1_protein.faa_WP_316726141.1 fe270c16d4b9987af95acf03ef898cac
#   X3  X4          X5
# 1 224 CDD         cd02513
# 2 224 Gene3D      G3DSA:3.90.550.10
# 3 224 PANTHER     PTHR21485
# 4 224 Pfam        PF02348
# 5 224 SUPERFAMILY SSF53448
# 6 433 PANTHER     PTHR21485
#   X6                                                           X7 X8
# 1 CMP-NeuAc_Synthase                                            4 220
# 2 Spore Coat Polysaccharide Biosynthesis Protein SpsA; Chain A  2 223
# 3 HAD SUPERFAMILY MEMBERS CMAS AND KDSC                         3 221
# 4 Cytidylyltransferase                                          4 129
# 5 Nucleotide-diphospho-sugar transferases                       1 222
# 6 HAD SUPERFAMILY MEMBERS CMAS AND KDSC                        10 421
#   X9          X10  X11        X12       X13
# 1 1.83995E-88 TRUE 05-12-2025 -         -
# 2 5.1E-66     TRUE 05-12-2025 IPR029044 Nucleotide-diphospho-sugar transferases
# 3 1.2E-54     TRUE 05-12-2025 IPR050793 CMP-NeuNAc synthase
# 4 1.5E-19     TRUE 05-12-2025 IPR003329 Acylneuraminate cytidylyltransferase
# 5 5.4E-49     TRUE 05-12-2025 IPR029044 Nucleotide-diphospho-sugar transferases
# 6 2.6E-96     TRUE 05-12-2025 IPR050793 CMP-NeuNAc synthase
#   X14 X15
# 1 -   -
# 2 -   -
# 3 -   -
# 4 -   -
# 5 -   -
# 6 -   -

# %%
#rename header
column_names_interpro <-c("Sequence", "md5", "unkown", "Bank", "signature", "annotation", "align_begin",
                 "align_end", "e-value","Hit", "date", "Interpro_code", "annotation_two", "unkown2", "unkown3")

setnames(matched_CMP_ID_interpro, column_names_interpro)

unique(matched_CMP_ID_interpro$annotation)

patterns_of_teste_CMP <- c("TIGR00466","PTHR42866","NF003952", "cd02517", "MF_00057", "TIGR03584") #remove only other nonulosonic citidyltransferase
# Out:
#  [1] "CMP-NeuAc_Synthase"
#  [2] "Spore Coat Polysaccharide Biosynthesis Protein SpsA; Chain A"
#  [3] "HAD SUPERFAMILY MEMBERS CMAS AND KDSC"
#  [4] "Cytidylyltransferase"
#  [5] "Nucleotide-diphospho-sugar transferases"
#  [6] "consensus disorder prediction"
#  [7] "haloacid dehalogenase-like hydrolase"
#  [8] "C1.6: Phosphoserine Phosphatase Like"
#  [9] "Haloacid Dehalogenase"
# [10] "HAD-like"
# [11] "C1.6.2: Deoxy-d-mannose-octulosonate 8-phosphate Phosphatase Like"
# [12] "HAD_KDO-like"
# [13] "-"
# [14] "3-DEOXY-MANNO-OCTULOSONATE CYTIDYLYLTRANSFERASE"
# [15] "3-deoxy-manno-octulosonate cytidylyltransferase"
# [16] "CMP-KDO-Synthetase"
# [17] "8-amino-3,8-dideoxy-manno-octulosonate cytidylyltransferase [kdsB]."
# [18] "Glycosyltransferase family 28 C-terminal domain"
# [19] "Glycogen Phosphorylase B;"
# [20] "UDP-N-ACETYLGLUCOSAMINE--N-ACETYLMURAMYL-(PENTAPEPTIDE) PYROPHOSPHORYL-UNDECAPRENOL N-ACETYLGLUCOSAMINE TRANSFERASE 1"
# [21] "UDP-Glycosyltransferase/glycogen phosphorylase"
# [22] "pseudaminic acid cytidylyltransferase"
# [23] "GT2_SpsF"
# [24] "SGNH hydrolase"
# [25] "GDSL-like Lipase/Acylhydrolase family"
# [26] "3-deoxy-D-manno-octulosonate 8-phosphate phosphatase, YrbI family"
# [27] "Coil"
# [28] "NnaC_like"
# [29] "Beta-1,4-N-acetylgalactosaminyltransferase (CgtA)"
# [30] "Aldolase/RraA"
# [31] "RraA-like"
# [32] "RraA_family"
# [33] "UDP-2,4-diacetamido-2,4,6-trideoxy-beta-L-altropyranose hydrolase"
# [34] "HAD-IIIA family hydrolase"

# %% [markdown]
# # Filter sequences with annotation to other nonusolosonic

# %%
# 1. Find all Sequence IDs containing any of the patterns
bad_ids <- matched_CMP_ID_interpro %>%
  filter(grepl(paste(patterns_of_teste_CMP, collapse = "|"), signature)) %>%
  pull(Sequence) %>%
  unique()

# 2. Remove those IDs entirely
filtered_CMP_interpro_rm <- matched_CMP_ID_interpro %>%
  filter(!(Sequence %in% bad_ids))

# %%
#get real names in annotation

patterns <- c("PF02348","SSF53448","G3DSA:3.90.550.10","PTHR21485","cd02513")

filtered_CMP_interpro <- filtered_CMP_interpro_rm %>%
  filter(signature %in% patterns)

head(filtered_CMP_interpro)
  CMP_interpro_distinct <- filtered_CMP_interpro%>% distinct(Sequence, .keep_all = TRUE)
# Out:
#   Sequence                                   md5
# 1 GCF_000767075.1_protein.faa_WP_038441453.1 8aa4af5264db8082f5c1db7822f7f6dc
# 2 GCF_000767075.1_protein.faa_WP_038441453.1 8aa4af5264db8082f5c1db7822f7f6dc
# 3 GCF_000767075.1_protein.faa_WP_038441453.1 8aa4af5264db8082f5c1db7822f7f6dc
# 4 GCF_000767075.1_protein.faa_WP_038441453.1 8aa4af5264db8082f5c1db7822f7f6dc
# 5 GCF_000767075.1_protein.faa_WP_038441453.1 8aa4af5264db8082f5c1db7822f7f6dc
# 6 GCF_032598905.1_protein.faa_WP_316726141.1 fe270c16d4b9987af95acf03ef898cac
#   unkown Bank        signature
# 1 224    CDD         cd02513
# 2 224    Gene3D      G3DSA:3.90.550.10
# 3 224    PANTHER     PTHR21485
# 4 224    Pfam        PF02348
# 5 224    SUPERFAMILY SSF53448
# 6 433    PANTHER     PTHR21485
#   annotation                                                   align_begin
# 1 CMP-NeuAc_Synthase                                            4
# 2 Spore Coat Polysaccharide Biosynthesis Protein SpsA; Chain A  2
# 3 HAD SUPERFAMILY MEMBERS CMAS AND KDSC                         3
# 4 Cytidylyltransferase                                          4
# 5 Nucleotide-diphospho-sugar transferases                       1
# 6 HAD SUPERFAMILY MEMBERS CMAS AND KDSC                        10
#   align_end e-value     Hit  date       Interpro_code
# 1 220       1.83995E-88 TRUE 05-12-2025 -
# 2 223       5.1E-66     TRUE 05-12-2025 IPR029044
# 3 221       1.2E-54     TRUE 05-12-2025 IPR050793
# 4 129       1.5E-19     TRUE 05-12-2025 IPR003329
# 5 222       5.4E-49     TRUE 05-12-2025 IPR029044
# 6 421       2.6E-96     TRUE 05-12-2025 IPR050793
#   annotation_two                          unkown2 unkown3
# 1 -                                       -       -
# 2 Nucleotide-diphospho-sugar transferases -       -
# 3 CMP-NeuNAc synthase                     -       -
# 4 Acylneuraminate cytidylyltransferase    -       -
# 5 Nucleotide-diphospho-sugar transferases -       -
# 6 CMP-NeuNAc synthase                     -       -

# %% [markdown]
# # Do the same for Lic3X sequences

# %%
#Lic3
Lic3_Interpro_data <- read_delim("genomes_download/plots_data/Interpro_results/Lic3_ID_sequence_for_Interpro.tsv_retrieved_now_results.tsv", 
                                                       delim = "\t", escape_double = FALSE, 
                                                       col_names = FALSE, trim_ws = TRUE)

head(Lic3_Interpro_data)
# Out:
# Rows: 1321 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (11): X1, X2, X4, X5, X6, X9, X11, X12, X13, X14, X15
# dbl  (3): X3, X7, X8
# lgl  (1): X10
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   X1                                         X2
# 1 GCF_002891825.2_protein.faa_WP_102827040.1 55bb15651016a61c87461f2c52d0ade5
# 2 GCF_002891825.2_protein.faa_WP_102827040.1 55bb15651016a61c87461f2c52d0ade5
# 3 GCF_002891825.2_protein.faa_WP_102827040.1 55bb15651016a61c87461f2c52d0ade5
# 4 GCF_000754275.1_protein.faa_WP_231963904.1 084973c5e948ffd39d6aa3ac0db0aad9
# 5 GCF_000754275.1_protein.faa_WP_231963904.1 084973c5e948ffd39d6aa3ac0db0aad9
# 6 GCF_000754275.1_protein.faa_WP_231963904.1 084973c5e948ffd39d6aa3ac0db0aad9
#   X3  X4          X5                 X6                                  X7 X8
# 1 303 Gene3D      G3DSA:3.90.1480.10 -                                    2 282
# 2 303 SUPERFAMILY SSF102414          Alpha-2,3/8-sialyltransferase CstII 11 270
# 3 303 Pfam        PF06002            Alpha-2,3-sialyltransferase (CST-I) 11 303
# 4 198 Gene3D      G3DSA:3.90.1480.10 -                                    2 197
# 5 198 Pfam        PF06002            Alpha-2,3-sialyltransferase (CST-I) 11 194
# 6 198 SUPERFAMILY SSF102414          Alpha-2,3/8-sialyltransferase CstII 11 194
#   X9        X10  X11        X12       X13
# 1 1.2E-94   TRUE 05-12-2025 -         -
# 2 1.31E-110 TRUE 05-12-2025 IPR036715 Alpha-2,3-sialyltransferase superfamily
# 3 0.0       TRUE 05-12-2025 IPR009251 Alpha-2,3-sialyltransferase
# 4 3.7E-72   TRUE 05-12-2025 -         -
# 5 3.1E-105  TRUE 05-12-2025 IPR009251 Alpha-2,3-sialyltransferase
# 6 6.54E-85  TRUE 05-12-2025 IPR036715 Alpha-2,3-sialyltransferase superfamily
#   X14 X15
# 1 -   -
# 2 -   -
# 3 -   -
# 4 -   -
# 5 -   -
# 6 -   -

# %%
setnames(Lic3_Interpro_data, column_names_interpro)

Lic3_interpro_annot_unique <- unique(Lic3_Interpro_data$annotation)
Lic3_interpro_annot_unique

patterns_Lic3 <- c("SSF102414","G3DSA:3.90.1480.10","PF06002")

filtered_Lic3_interpro <- Lic3_Interpro_data %>%
  filter(signature %in% patterns_Lic3)

Lic3_interpro_distinct <- filtered_Lic3_interpro %>% distinct(Sequence, .keep_all = TRUE)
# Out:
# [1] "-"
# [2] "Alpha-2,3/8-sialyltransferase CstII"
# [3] "Alpha-2,3-sialyltransferase (CST-I)"
# [4] "Coil"
# [5] "SLR1441 PROTEIN"
# [6] "PROTEIN-COUPLED RECEPTOR GPR1, PUTATIVE-RELATED"
# [7] "consensus disorder prediction"

# %% [markdown]
# # Do the same for pm0188 from our own database

# %%
pm1088_Interpro_data <- read_delim("genomes_download/plots_data/Interpro_results/pm0188_ID_sequence_for_Interpro.tsv_retrieved_now_results.tsv", 
                                                       delim = "\t", escape_double = FALSE, 
                                                       col_names = FALSE, trim_ws = TRUE)
head(pm1088_Interpro_data)
# Out:
# Rows: 1487 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (11): X1, X2, X4, X5, X6, X9, X11, X12, X13, X14, X15
# dbl  (3): X3, X7, X8
# lgl  (1): X10
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   X1                                         X2
# 1 GCF_004684345.1_protein.faa_WP_135323030.1 0479cb1b1e762899484b42eff71886d5
# 2 GCF_004684345.1_protein.faa_WP_135323030.1 0479cb1b1e762899484b42eff71886d5
# 3 GCF_004684345.1_protein.faa_WP_135323030.1 0479cb1b1e762899484b42eff71886d5
# 4 GCF_004684345.1_protein.faa_WP_135323030.1 0479cb1b1e762899484b42eff71886d5
# 5 GCF_029773835.1_protein.faa_WP_278226567.1 97ce6dfaac27e1e4ddf95fcff6a384f2
# 6 GCF_029773835.1_protein.faa_WP_278226567.1 97ce6dfaac27e1e4ddf95fcff6a384f2
#   X3  X4          X5
# 1 377 Pfam        PF11477
# 2 377 Gene3D      G3DSA:3.40.50.11120
# 3 377 Gene3D      G3DSA:3.40.50.11110
# 4 377 SUPERFAMILY SSF53756
# 5 402 Gene3D      G3DSA:3.40.50.11120
# 6 402 Pfam        PF11477
#   X6                                             X7  X8  X9       X10
# 1 Sialyltransferase PMO188                         5 357 3.3E-30  TRUE
# 2 -                                                1 209 1.9E-43  TRUE
# 3 -                                              212 377 2.0E-27  TRUE
# 4 UDP-Glycosyltransferase/glycogen phosphorylase   2 352 3.45E-34 TRUE
# 5 -                                                8 219 3.6E-57  TRUE
# 6 Sialyltransferase PMO188                        10 390 1.9E-99  TRUE
#   X11        X12
# 1 05-12-2025 IPR021574
# 2 05-12-2025 IPR043078
# 3 05-12-2025 -
# 4 05-12-2025 -
# 5 05-12-2025 IPR043078
# 6 05-12-2025 IPR021574
#   X13                                                                  X14 X15
# 1 Sialyltransferase PMO188                                             -   -
# 2 Sialyltransferase, N-terminal GT-B Rossman nucleotide-binding domain -   -
# 3 -                                                                    -   -
# 4 -                                                                    -   -
# 5 Sialyltransferase, N-terminal GT-B Rossman nucleotide-binding domain -   -
# 6 Sialyltransferase PMO188                                             -   -

# %%
setnames(pm1088_Interpro_data, column_names_interpro) #rename header


pm1088_interpro_annot_unique <- unique(pm1088_Interpro_data$annotation)
pm1088_interpro_annot_unique

patterns_off_pm1088 <- c("PTHR30160","PF01075","G3DSA:2.60.40.10","cd14948","G3DSA:3.40.50.2000", "PF22352")

# 1. Find all Sequence IDs containing any of the patterns
bad_ids_pm1088 <- pm1088_Interpro_data %>%
  filter(grepl(paste(patterns_off_pm1088, collapse = "|"), signature)) %>%
  pull(Sequence) %>%
  unique()

# 2. Remove those IDs entirely
filtered_pm1088_interpro <- pm1088_Interpro_data %>%
  filter(!(Sequence %in% bad_ids_pm1088))
# Out:
#  [1] "Sialyltransferase PMO188"
#  [2] "-"
#  [3] "UDP-Glycosyltransferase/glycogen phosphorylase"
#  [4] "Coil"
#  [5] "K319L-like, PKD domain"
#  [6] "Glycosyltransferase family 9 (heptosyltransferase)"
#  [7] "Glycogen Phosphorylase B;"
#  [8] "TETRAACYLDISACCHARIDE 4'-KINASE-RELATED"
#  [9] "BACON"
# [10] "Immunoglobulins"

# %%
patterns_pm1088 <- c("PF11477")

filtered_pm1088_interpro_test <- filtered_pm1088_interpro %>%
  filter(signature %in% patterns_pm1088)

pm1088_interpro_distinct <- filtered_pm1088_interpro_test  %>% distinct(Sequence, .keep_all = TRUE)

# %% [markdown]
# # Do for pm0188 PFAM

# %%
pm1088_PFAM_Interpro_data <- read_delim("genomes_download/plots_data/Interpro_results/pm0188_PFAM_ID_sequence_for_Interpro.tsv_retrieved_now_results.tsv", 
                                                       delim = "\t", escape_double = FALSE, 
                                                       col_names = FALSE, trim_ws = TRUE)
head(pm1088_PFAM_Interpro_data)
# Out:
# Rows: 1319 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (11): X1, X2, X4, X5, X6, X9, X11, X12, X13, X14, X15
# dbl  (3): X3, X7, X8
# lgl  (1): X10
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   X1                                         X2
# 1 GCF_004684345.1_protein.faa_WP_135323030.1 0479cb1b1e762899484b42eff71886d5
# 2 GCF_004684345.1_protein.faa_WP_135323030.1 0479cb1b1e762899484b42eff71886d5
# 3 GCF_004684345.1_protein.faa_WP_135323030.1 0479cb1b1e762899484b42eff71886d5
# 4 GCF_004684345.1_protein.faa_WP_135323030.1 0479cb1b1e762899484b42eff71886d5
# 5 GCF_029773835.1_protein.faa_WP_278226567.1 97ce6dfaac27e1e4ddf95fcff6a384f2
# 6 GCF_029773835.1_protein.faa_WP_278226567.1 97ce6dfaac27e1e4ddf95fcff6a384f2
#   X3  X4          X5
# 1 377 Pfam        PF11477
# 2 377 Gene3D      G3DSA:3.40.50.11120
# 3 377 Gene3D      G3DSA:3.40.50.11110
# 4 377 SUPERFAMILY SSF53756
# 5 402 Gene3D      G3DSA:3.40.50.11120
# 6 402 Pfam        PF11477
#   X6                                             X7  X8  X9       X10
# 1 Sialyltransferase PMO188                         5 357 3.3E-30  TRUE
# 2 -                                                1 209 1.9E-43  TRUE
# 3 -                                              212 377 2.0E-27  TRUE
# 4 UDP-Glycosyltransferase/glycogen phosphorylase   2 352 3.45E-34 TRUE
# 5 -                                                8 219 3.6E-57  TRUE
# 6 Sialyltransferase PMO188                        10 390 1.9E-99  TRUE
#   X11        X12
# 1 05-12-2025 IPR021574
# 2 05-12-2025 IPR043078
# 3 05-12-2025 -
# 4 05-12-2025 -
# 5 05-12-2025 IPR043078
# 6 05-12-2025 IPR021574
#   X13                                                                  X14 X15
# 1 Sialyltransferase PMO188                                             -   -
# 2 Sialyltransferase, N-terminal GT-B Rossman nucleotide-binding domain -   -
# 3 -                                                                    -   -
# 4 -                                                                    -   -
# 5 Sialyltransferase, N-terminal GT-B Rossman nucleotide-binding domain -   -
# 6 Sialyltransferase PMO188                                             -   -

# %%
setnames(pm1088_PFAM_Interpro_data, column_names_interpro)


pm1088_PFAM_interpro_annot_unique <- unique(pm1088_PFAM_Interpro_data$annotation)
pm1088_PFAM_interpro_annot_unique

patterns_off_pm1088 <- c("PTHR30160","PF01075","G3DSA:2.60.40.10","cd14948","G3DSA:3.40.50.2000", "PF22352")

# 1. Find all Sequence IDs containing any of the patterns
bad_ids_pm1088_PFAM <- pm1088_PFAM_Interpro_data %>%
  filter(grepl(paste(patterns_off_pm1088, collapse = "|"), signature)) %>%
  pull(Sequence) %>%
  unique()

# 2. Remove those IDs entirely
filtered_pm1088_PFAM_interpro <- pm1088_PFAM_Interpro_data %>%
  filter(!(Sequence %in% bad_ids_pm1088_PFAM))
# Out:
# [1] "Sialyltransferase PMO188"
# [2] "-"
# [3] "UDP-Glycosyltransferase/glycogen phosphorylase"
# [4] "Coil"
# [5] "K319L-like, PKD domain"

# %%
patterns_pm1088 <- c("PF11477")

filtered_pm1088_PFAM_interpro_test <- filtered_pm1088_PFAM_interpro %>%
  filter(signature %in% patterns_pm1088)

pm1088_PFAM_interpro_distinct <- filtered_pm1088_PFAM_interpro_test  %>% distinct(Sequence, .keep_all = TRUE)

# %% [markdown]
# # Do for NeuS from our own database

# %%
neuS_interpro_data <- read_delim("genomes_download/plots_data/Interpro_results/neuS_ID_thais_sequence_for_Interpro.tsv_retrieved_now_results.tsv", 
                                                       delim = "\t", escape_double = FALSE, 
                                                       col_names = FALSE, trim_ws = TRUE)
head(neuS_interpro_data)
# Out:
# Rows: 2580 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (11): X1, X2, X4, X5, X6, X9, X11, X12, X13, X14, X15
# dbl  (3): X3, X7, X8
# lgl  (1): X10
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   X1                                         X2
# 1 GCF_001314975.1_protein.faa_WP_229084347.1 f24666ac0820a4d166dfbc037a7ba383
# 2 GCF_014131755.1_protein.faa_WP_229084347.1 f24666ac0820a4d166dfbc037a7ba383
# 3 GCF_018291825.1_protein.faa_WP_229084347.1 f24666ac0820a4d166dfbc037a7ba383
# 4 GCF_000011065.1_protein.faa_WP_229084347.1 f24666ac0820a4d166dfbc037a7ba383
# 5 GCF_017603825.1_protein.faa_WP_208575181.1 8516e9911108b7081246df3e79d33700
# 6 GCF_017603825.1_protein.faa_WP_208575181.1 8516e9911108b7081246df3e79d33700
#   X3  X4         X5          X6                                       X7  X8
# 1 327 Pfam       PF07388     Alpha-2,8-polysialyltransferase (POLYST)  50 298
# 2 327 Pfam       PF07388     Alpha-2,8-polysialyltransferase (POLYST)  50 298
# 3 327 Pfam       PF07388     Alpha-2,8-polysialyltransferase (POLYST)  50 298
# 4 327 Pfam       PF07388     Alpha-2,8-polysialyltransferase (POLYST)  50 298
# 5 461 Pfam       PF07388     Alpha-2,8-polysialyltransferase (POLYST)   4 331
# 6 461 MobiDBLite mobidb-lite consensus disorder prediction            197 218
#   X9      X10  X11        X12       X13                             X14 X15
# 1 3.7E-7  TRUE 05-12-2025 IPR010866 Alpha-2,8-polysialyltransferase -   -
# 2 3.7E-7  TRUE 05-12-2025 IPR010866 Alpha-2,8-polysialyltransferase -   -
# 3 3.7E-7  TRUE 05-12-2025 IPR010866 Alpha-2,8-polysialyltransferase -   -
# 4 3.7E-7  TRUE 05-12-2025 IPR010866 Alpha-2,8-polysialyltransferase -   -
# 5 2.1E-22 TRUE 05-12-2025 IPR010866 Alpha-2,8-polysialyltransferase -   -
# 6 -       TRUE 05-12-2025 -         -                               -   -

# %%
setnames(neuS_interpro_data, column_names_interpro) 


neuS_interpro_annot_unique <- unique(neuS_interpro_data$annotation)


patterns_neuS <- c("PF07388")

filtered_neuS_interpro <- neuS_interpro_data %>%
  filter(signature %in% patterns_neuS)

neuS_interpro_distinct <- filtered_neuS_interpro %>% distinct(Sequence, .keep_all = TRUE)

# %% [markdown]
# # For NeuS PFAM

# %%
neuS_PFAM_interpro_data <-  read_delim("genomes_download/plots_data/Interpro_results/neuS_ID_PFAM_sequence_for_Interpro.tsv_retrieved_now_results.tsv", 
                                                       delim = "\t", escape_double = FALSE, 
                                                       col_names = FALSE, trim_ws = TRUE)
head(neuS_PFAM_interpro_data)
# Out:
# Rows: 2961 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (11): X1, X2, X4, X5, X6, X9, X11, X12, X13, X14, X15
# dbl  (3): X3, X7, X8
# lgl  (1): X10
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   X1                                         X2
# 1 GCF_001314975.1_protein.faa_WP_229084347.1 f24666ac0820a4d166dfbc037a7ba383
# 2 GCF_014131755.1_protein.faa_WP_229084347.1 f24666ac0820a4d166dfbc037a7ba383
# 3 GCF_018291825.1_protein.faa_WP_229084347.1 f24666ac0820a4d166dfbc037a7ba383
# 4 GCF_000011065.1_protein.faa_WP_229084347.1 f24666ac0820a4d166dfbc037a7ba383
# 5 GCF_017603825.1_protein.faa_WP_208575181.1 8516e9911108b7081246df3e79d33700
# 6 GCF_017603825.1_protein.faa_WP_208575181.1 8516e9911108b7081246df3e79d33700
#   X3  X4         X5          X6                                       X7  X8
# 1 327 Pfam       PF07388     Alpha-2,8-polysialyltransferase (POLYST)  50 298
# 2 327 Pfam       PF07388     Alpha-2,8-polysialyltransferase (POLYST)  50 298
# 3 327 Pfam       PF07388     Alpha-2,8-polysialyltransferase (POLYST)  50 298
# 4 327 Pfam       PF07388     Alpha-2,8-polysialyltransferase (POLYST)  50 298
# 5 461 Pfam       PF07388     Alpha-2,8-polysialyltransferase (POLYST)   4 331
# 6 461 MobiDBLite mobidb-lite consensus disorder prediction            197 218
#   X9      X10  X11        X12       X13                             X14 X15
# 1 3.7E-7  TRUE 05-12-2025 IPR010866 Alpha-2,8-polysialyltransferase -   -
# 2 3.7E-7  TRUE 05-12-2025 IPR010866 Alpha-2,8-polysialyltransferase -   -
# 3 3.7E-7  TRUE 05-12-2025 IPR010866 Alpha-2,8-polysialyltransferase -   -
# 4 3.7E-7  TRUE 05-12-2025 IPR010866 Alpha-2,8-polysialyltransferase -   -
# 5 2.1E-22 TRUE 05-12-2025 IPR010866 Alpha-2,8-polysialyltransferase -   -
# 6 -       TRUE 05-12-2025 -         -                               -   -

# %%
setnames(neuS_PFAM_interpro_data, column_names_interpro) #rename header

neuS_PFAM_interpro_annot_unique <- unique(neuS_PFAM_interpro_data$annotation) #see names of signatures

patterns_neuS <- c("PF07388") #filter for signature of NeuS

filtered_neuS_PFAM_interpro <- neuS_PFAM_interpro_data %>%
  filter(signature %in% patterns_neuS)

neuS_PFAM_interpro_distinct <- filtered_neuS_PFAM_interpro %>% distinct(Sequence, .keep_all = TRUE)

# %% [markdown]
# # For Lst

# %%
#Lst

Lst_Interpro_data <- read_delim("genomes_download/plots_data/Interpro_results/Lst_ID_sequence_for_Interpro.tsv_retrieved_now_results.tsv", 
                                                       delim = "\t", escape_double = FALSE, 
                                                       col_names = FALSE, trim_ws = TRUE)

head(Lst_Interpro_data)
# Out:
# Rows: 2750 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (11): X1, X2, X4, X5, X6, X9, X11, X12, X13, X14, X15
# dbl  (3): X3, X7, X8
# lgl  (1): X10
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   X1                                         X2
# 1 GCF_034480505.1_protein.faa_WP_025520227.1 e4950302bbefae3b8253e5170f6ff1ce
# 2 GCF_001700835.1_protein.faa_WP_025520227.1 e4950302bbefae3b8253e5170f6ff1ce
# 3 GCF_030994225.1_protein.faa_WP_025520227.1 e4950302bbefae3b8253e5170f6ff1ce
# 4 GCF_007990445.1_protein.faa_WP_147004514.1 3127fa06a4c20d96d11b86eeae404ece
# 5 GCF_007990445.1_protein.faa_WP_147004514.1 3127fa06a4c20d96d11b86eeae404ece
# 6 GCF_949790945.1_protein.faa_WP_000725508.1 3a868a711476af2be48794b8f7f3823c
#   X3  X4     X5                  X6                            X7 X8  X9
# 1 310 Pfam   PF07922             Glycosyltransferase family 52 54 295 3.6E-17
# 2 310 Pfam   PF07922             Glycosyltransferase family 52 54 295 3.6E-17
# 3 310 Pfam   PF07922             Glycosyltransferase family 52 54 295 3.6E-17
# 4 119 Gene3D G3DSA:3.40.50.11110 -                              2 113 1.1E-9
# 5 119 Pfam   PF07922             Glycosyltransferase family 52  7 110 1.6E-12
# 6 311 Pfam   PF07922             Glycosyltransferase family 52 30 308 1.9E-58
#   X10  X11        X12       X13                           X14 X15
# 1 TRUE 05-12-2025 IPR012477 Glycosyltransferase family 52 -   -
# 2 TRUE 05-12-2025 IPR012477 Glycosyltransferase family 52 -   -
# 3 TRUE 05-12-2025 IPR012477 Glycosyltransferase family 52 -   -
# 4 TRUE 05-12-2025 -         -                             -   -
# 5 TRUE 05-12-2025 IPR012477 Glycosyltransferase family 52 -   -
# 6 TRUE 05-12-2025 IPR012477 Glycosyltransferase family 52 -   -

# %%
setnames(Lst_Interpro_data, column_names_interpro) #rename header

lst_interpro_annot_unique <- unique(Lst_Interpro_data$annotation) #see signatures' names

patterns_Lst <- c("PF07922") #filter signature's ID of Lst

filtered_Lst_interpro <- Lst_Interpro_data %>%
  filter(signature %in% patterns_Lst)

head(filtered_Lst_interpro)
lst_filtered_annot_unique <- unique(filtered_Lst_interpro$annotation)

Lst_interpro_distinct <- filtered_Lst_interpro %>% distinct(Sequence, .keep_all = TRUE) #remove duplicates
# Out:
#   Sequence                                   md5
# 1 GCF_034480505.1_protein.faa_WP_025520227.1 e4950302bbefae3b8253e5170f6ff1ce
# 2 GCF_001700835.1_protein.faa_WP_025520227.1 e4950302bbefae3b8253e5170f6ff1ce
# 3 GCF_030994225.1_protein.faa_WP_025520227.1 e4950302bbefae3b8253e5170f6ff1ce
# 4 GCF_007990445.1_protein.faa_WP_147004514.1 3127fa06a4c20d96d11b86eeae404ece
# 5 GCF_949790945.1_protein.faa_WP_000725508.1 3a868a711476af2be48794b8f7f3823c
# 6 GCF_031203395.1_protein.faa_WP_000725508.1 3a868a711476af2be48794b8f7f3823c
#   unkown Bank signature annotation                    align_begin align_end
# 1 310    Pfam PF07922   Glycosyltransferase family 52 54          295
# 2 310    Pfam PF07922   Glycosyltransferase family 52 54          295
# 3 310    Pfam PF07922   Glycosyltransferase family 52 54          295
# 4 119    Pfam PF07922   Glycosyltransferase family 52  7          110
# 5 311    Pfam PF07922   Glycosyltransferase family 52 30          308
# 6 311    Pfam PF07922   Glycosyltransferase family 52 30          308
#   e-value Hit  date       Interpro_code annotation_two                unkown2
# 1 3.6E-17 TRUE 05-12-2025 IPR012477     Glycosyltransferase family 52 -
# 2 3.6E-17 TRUE 05-12-2025 IPR012477     Glycosyltransferase family 52 -
# 3 3.6E-17 TRUE 05-12-2025 IPR012477     Glycosyltransferase family 52 -
# 4 1.6E-12 TRUE 05-12-2025 IPR012477     Glycosyltransferase family 52 -
# 5 1.9E-58 TRUE 05-12-2025 IPR012477     Glycosyltransferase family 52 -
# 6 1.9E-58 TRUE 05-12-2025 IPR012477     Glycosyltransferase family 52 -
#   unkown3
# 1 -
# 2 -
# 3 -
# 4 -
# 5 -
# 6 -

# %% [markdown]
# # For Cst Pfam

# %%
#cst PFAM

cst_PFAM_Interpro_data <- read_delim("genomes_download/plots_data/Interpro_results/cst_ID_PFAM_sequence_for_Interpro.tsv_retrieved_now_results.tsv", 
                                 delim = "\t", escape_double = FALSE, 
                                 col_names = FALSE, trim_ws = TRUE)
head(cst_PFAM_Interpro_data)
# Out:
# Rows: 1307 Columns: 15
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (11): X1, X2, X4, X5, X6, X9, X11, X12, X13, X14, X15
# dbl  (3): X3, X7, X8
# lgl  (1): X10
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   X1                                         X2
# 1 GCF_033097285.1_protein.faa_WP_052801091.1 72c05f52fe36b59e7d09a0ab57260797
# 2 GCF_033097285.1_protein.faa_WP_052801091.1 72c05f52fe36b59e7d09a0ab57260797
# 3 GCF_033097285.1_protein.faa_WP_052801091.1 72c05f52fe36b59e7d09a0ab57260797
# 4 GCF_002891825.2_protein.faa_WP_102827040.1 55bb15651016a61c87461f2c52d0ade5
# 5 GCF_002891825.2_protein.faa_WP_102827040.1 55bb15651016a61c87461f2c52d0ade5
# 6 GCF_002891825.2_protein.faa_WP_102827040.1 55bb15651016a61c87461f2c52d0ade5
#   X3  X4          X5                 X6                                  X7 X8
# 1 301 Pfam        PF06002            Alpha-2,3-sialyltransferase (CST-I)  3 295
# 2 301 SUPERFAMILY SSF102414          Alpha-2,3/8-sialyltransferase CstII  1 255
# 3 301 Gene3D      G3DSA:3.90.1480.10 -                                    1 274
# 4 303 Gene3D      G3DSA:3.90.1480.10 -                                    2 282
# 5 303 SUPERFAMILY SSF102414          Alpha-2,3/8-sialyltransferase CstII 11 270
# 6 303 Pfam        PF06002            Alpha-2,3-sialyltransferase (CST-I) 11 303
#   X9        X10  X11        X12       X13
# 1 2.7E-100  TRUE 05-12-2025 IPR009251 Alpha-2,3-sialyltransferase
# 2 4.32E-98  TRUE 05-12-2025 IPR036715 Alpha-2,3-sialyltransferase superfamily
# 3 1.6E-103  TRUE 05-12-2025 -         -
# 4 1.2E-94   TRUE 05-12-2025 -         -
# 5 1.31E-110 TRUE 05-12-2025 IPR036715 Alpha-2,3-sialyltransferase superfamily
# 6 0.0       TRUE 05-12-2025 IPR009251 Alpha-2,3-sialyltransferase
#   X14 X15
# 1 -   -
# 2 -   -
# 3 -   -
# 4 -   -
# 5 -   -
# 6 -   -

# %%
setnames(cst_PFAM_Interpro_data, column_names_interpro) #rename header

cst_PFAM_Interpro_annot_unique <- unique(cst_PFAM_Interpro_data$annotation)
cst_PFAM_Interpro_annot_unique #see unique signatures' names

patterns_cst <- c("SSF102414","G3DSA:3.90.1480.10","PF06002") #get ID of signatures

filtered_cst_interpro <- cst_PFAM_Interpro_data %>%
  filter(signature %in% patterns_cst) #filter sequences with cst signatures

cst_PFAM_interpro_distinct <- filtered_cst_interpro %>% distinct(Sequence, .keep_all = TRUE) #remove duplicates
# Out:
# [1] "Alpha-2,3-sialyltransferase (CST-I)"
# [2] "Alpha-2,3/8-sialyltransferase CstII"
# [3] "-"
# [4] "Coil"
# [5] "PROTEIN-COUPLED RECEPTOR GPR1, PUTATIVE-RELATED"
# [6] "consensus disorder prediction"
# [7] "SLR1441 PROTEIN"

# %%
#join all data

#extract GCF ID
CMP_interpro_distinct$GCF_ID <- str_extract(CMP_interpro_distinct$Sequence, "^[^_]+_[^_]+")

#get CMP GCF ID
get_CMP_final_interpro_ID <- CMP_interpro_distinct[,"GCF_ID"]

#get ID for all sialyltransferases
#Lic3
Lic3_interpro_distinct$GCF_ID <- str_extract(Lic3_interpro_distinct$Sequence, "^[^_]+_[^_]+")
get_Lic3_final_interpro_ID <- Lic3_interpro_distinct[,"GCF_ID"]

#pm1088
pm1088_interpro_distinct$GCF_ID <- str_extract(pm1088_interpro_distinct$Sequence, "^[^_]+_[^_]+")
get_pm1088_final_interpro_ID <- pm1088_interpro_distinct[,"GCF_ID"]

#pm1088 PFAM
pm1088_PFAM_interpro_distinct$GCF_ID <- str_extract(pm1088_PFAM_interpro_distinct$Sequence, "^[^_]+_[^_]+")
get_pm1088_PFAM_final_interpro_ID <- pm1088_PFAM_interpro_distinct[,"GCF_ID"]

#NeuS
neuS_interpro_distinct$GCF_ID <- str_extract(neuS_interpro_distinct$Sequence, "^[^_]+_[^_]+")
get_neuS_final_interpro_ID <- neuS_interpro_distinct[,"GCF_ID"]

#NeuS PFAM
neuS_PFAM_interpro_distinct$GCF_ID <- str_extract(neuS_PFAM_interpro_distinct$Sequence, "^[^_]+_[^_]+")
get_neuS_PFAM_final_interpro_ID <- neuS_PFAM_interpro_distinct[,"GCF_ID"]

#Lst 
Lst_interpro_distinct$GCF_ID <- str_extract(Lst_interpro_distinct$Sequence, "^[^_]+_[^_]+")
get_Lst_final_interpro_ID <- Lst_interpro_distinct[,"GCF_ID"]

#cst PFAM
cst_PFAM_interpro_distinct$GCF_ID <- str_extract(cst_PFAM_interpro_distinct$Sequence, "^[^_]+_[^_]+")
get_cst_PFAM_final_interpro_ID <- cst_PFAM_interpro_distinct[,"GCF_ID"]

# %% [markdown]
# # see what have sialylation complete pathway

# %%
#join all sialyltransferase
all_sialyltrans_ID <- rbind(get_Lic3_final_interpro_ID,get_pm1088_final_interpro_ID, get_neuS_final_interpro_ID,get_Lst_final_interpro_ID,
                            get_neuS_PFAM_final_interpro_ID, get_cst_PFAM_final_interpro_ID, get_pm1088_PFAM_final_interpro_ID)

all_sialyltrans_ID_unique <-all_sialyltrans_ID %>% distinct(GCF_ID)

#After filtration, see what are complete pathway that match with CMP
complete_sialylation_interpro <- semi_join(get_CMP_final_interpro_ID, all_sialyltrans_ID_unique, by="GCF_ID")

# %%
#save result to an output
write_tsv(complete_sialylation_interpro, 
          "genomes_download/plots_data/complete_sialylation_interpro_filtration_final.tsv")

# %% [markdown]
# # see how many are from Polysialylation pathway

# %%
#Polysialylation
get_neuS_PFAM <- semi_join(complete_sialylation_interpro,get_neuS_PFAM_final_interpro_ID, by="GCF_ID")
get_neuS <- semi_join(complete_sialylation_interpro, get_neuS_final_interpro_ID, by="GCF_ID")

all_poly <- rbind(get_neuS_PFAM,get_neuS)
all_poly_unique <- distinct(all_poly)
head(all_poly_unique)
nrow(all_poly_unique)
polysia_path_count <- nrow(all_poly_unique)
# Out:
#   GCF_ID
# 1 GCF_032598905.1
# 2 GCF_002866045.1
# 3 GCF_036189845.1
# 4 GCF_036226185.1
# 5 GCF_036224405.1
# 6 GCF_008704995.1
# [1] 1373

# %% [markdown]
# # see how many are from Sialylation pathway

# %%
get_pm0188<- semi_join(complete_sialylation_interpro,pm1088_interpro_distinct, by="GCF_ID")
get_Lic3 <- semi_join(complete_sialylation_interpro, Lic3_interpro_distinct, by="GCF_ID")
get_pm0188_PFAM <- semi_join(complete_sialylation_interpro, pm1088_PFAM_interpro_distinct, by="GCF_ID")
get_cst_PFAM <- semi_join(complete_sialylation_interpro, cst_PFAM_interpro_distinct, by="GCF_ID")
get_lst <- semi_join(complete_sialylation_interpro,Lst_interpro_distinct, by="GCF_ID")

all_sialyl_ID_together <- rbind(get_lst,get_pm0188, get_Lic3,get_pm0188_PFAM,get_cst_PFAM)
all_sialyl_ID_together_unique <-all_sialyl_ID_together %>% distinct(GCF_ID)
head(all_sialyl_ID_together_unique)
nrow(all_sialyl_ID_together_unique)
sia_path_count <- nrow(all_sialyl_ID_together_unique)
# Out:
#   GCF_ID
# 1 GCF_000767075.1
# 2 GCF_035221255.1
# 3 GCF_023572865.1
# 4 GCF_002998595.1
# 5 GCF_902387815.1
# 6 GCF_003253795.1
# [1] 1175

# %% [markdown]
# # See how many has both pathway

# %%
#see what have both
join_all_path <-rbind(all_sialyl_ID_together_unique, all_poly_unique)
duplicated_rows <- join_all_path[duplicated(join_all_path), ]#duplicate
nrow(duplicated_rows)
both_path <- nrow(duplicated_rows)
# Out:
# [1] 89

# %% [markdown]
# #  Create barplot for sialylation pathway

# %%
install.packages("VennDiagram")               
library(VennDiagram)
# Out:
# Installing package into ‘/home/edbvb97/R/x86_64-pc-linux-gnu-library/4.4’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘formatR’, ‘lambda.r’, ‘futile.options’, ‘futile.logger’
#
#
# Warning message in download.file(url, destfile, method, mode = "wb", ...):
# “URL 'https://cloud.r-project.org/src/contrib/formatR_1.14.tar.gz': Timeout of 60 seconds was reached”
# Error in download.file(url, destfile, method, mode = "wb", ...) :
#   cannot open URL 'https://cloud.r-project.org/src/contrib/formatR_1.14.tar.gz'
# Warning message in download.packages(pkgs, destdir = tmpd, available = available, :
# “download of package ‘formatR’ failed”
# Warning message in install.packages("VennDiagram"):
# “installation of package ‘lambda.r’ had non-zero exit status”
# Warning message in install.packages("VennDiagram"):
# “installation of package ‘futile.logger’ had non-zero exit status”
# Warning message in install.packages("VennDiagram"):
# “installation of package ‘VennDiagram’ had non-zero exit status”
# Error in library(VennDiagram): there is no package called ‘VennDiagram’
# Traceback:
#
# 1. stop(packageNotFoundError(package, lib.loc, sys.call()))

# %%
# create pairwise Venn diagram
draw.pairwise.venn(area1=1264, area2=1462,cross.area=both_path,
                   category=c("LPS/LOS Sialylation","Polysialylation"),fill=c("#f768a1","#ae017e"),
cex = 2,        # number labels size
cat.cex = 2,    # category labels size
# font family and face for the number labels
fontfamily = "Times",
fontface = "bold",
# font family and face for the category labels
cat.fontfamily = "Times",
cat.fontface = "bold",
cat.pos = c(-10, 10),

# distance from the circles (float numbers): increase to move farther away
cat.dist = c(0.06, 0.06),
)
