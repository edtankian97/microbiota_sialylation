# %% [markdown]
# # Part 01 - Coverage filtration

# %%
#Library 
library(dplyr)
library(readr)
library(tidyr)
library(data.table)
library(stringr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last

# %%
# Set the working directory to the parent folder of microbiota_sialylation/genomes_download/
# Example:
# setwd("~")

# %%
#Upload data
#KpsM
cover_kpsM_ncbi <-read.table("plots_data/hmmer_out/all_kpsM_coverage.tsv", 
                                       header = FALSE, col.names = c("V1", "V2"))
head(cover_kpsM_ncbi)
nrow(cover_kpsM_ncbi)
#KpsT
cover_kpsT_ncbi <-read.table("plots_data/hmmer_out/all_kpsT_coverage.tsv", 
                             header = FALSE, col.names = c("V1", "V2"))

head(cover_kpsT_ncbi)
nrow(cover_kpsT_ncbi)
#KpsD
cover_kpsD_ncbi <-read.table("plots_data/hmmer_out/all_KpsD_coverage.tsv", 
                             header = FALSE, col.names = c("V1", "V2"))

head(cover_kpsD_ncbi)
nrow(cover_kpsD_ncbi)

#neuD
cover_neuD_ncbi <-read.table("plots_data/hmmer_out/all_neuD_coverage.tsv", 
                             header = FALSE, col.names = c("V1", "V2"))
head(cover_neuD_ncbi)
nrow(cover_neuD_ncbi)

#neuO
cover_neuO_ncbi <-read.table("plots_data/hmmer_out/all_neuO_coverage.tsv", 
                             header = FALSE, col.names = c("V1", "V2"))
head(cover_neuO_ncbi)
nrow(cover_neuO_ncbi)
# Out:
#   V1       V2
# 1 94.33960 kpsM_final_mafft_GCF_000006825.1_protein_output.tsv
# 2  5.75342 kpsM_final_mafft_GCF_000007265.1_protein_output.tsv
# 3 88.14230 kpsM_final_mafft_GCF_000007945.1_protein_output.tsv
# 4 90.45940 kpsM_final_mafft_GCF_000007985.2_protein_output.tsv
# 5 85.71430 kpsM_final_mafft_GCF_000008465.1_protein_output.tsv
# 6 90.10600 kpsM_final_mafft_GCF_000008485.1_protein_output.tsv
# [1] 2364
#   V1       V2
# 1 98.63010 kpsT_final_mafft_GCF_000006825.1_protein_output.tsv
# 2  6.10932 kpsT_final_mafft_GCF_000007265.1_protein_output.tsv
# 3  9.09091 kpsT_final_mafft_GCF_000007945.1_protein_output.tsv
# 4  6.87204 kpsT_final_mafft_GCF_000007985.2_protein_output.tsv
# 5  7.53532 kpsT_final_mafft_GCF_000008465.1_protein_output.tsv
# 6 44.09280 kpsT_final_mafft_GCF_000008485.1_protein_output.tsv
# [1] 2459
#   V1       V2
# 1 58.91470 kpsD_final_mafft_GCF_000006825.1_protein_output.tsv
# 2 35.02300 kpsD_final_mafft_GCF_000007265.1_protein_output.tsv
# ...

# %%
#Filter by coverage
#KpsM
cover_kpsM_ncbi_filter <- cover_kpsM_ncbi %>% filter(cover_kpsM_ncbi$V1 >= 40.00)
nrow(cover_kpsM_ncbi_filter)

#KpsT
cover_kpsT_ncbi_filter <- cover_kpsT_ncbi %>% filter(cover_kpsT_ncbi$V1 >= 40.00)
nrow(cover_kpsT_ncbi_filter)

#KpsD
cover_kpsD_ncbi_filter <- cover_kpsD_ncbi %>% filter(cover_kpsD_ncbi$V1 >= 40.00)
nrow(cover_kpsD_ncbi_filter)

#neuO
cover_neuO_ncbi_filter <- cover_neuO_ncbi %>% filter(cover_neuO_ncbi$V1 >= 40.00)
nrow(cover_neuO_ncbi_filter)

#neuD
cover_neuD_ncbi_filter <- cover_neuD_ncbi %>% filter(cover_neuD_ncbi$V1 >= 40.00)
nrow(cover_neuO_ncbi_filter)
# Out:
# [1] 2205
# [1] 1849
# [1] 971
# [1] 1490
# [1] 1490

# %%
#save files
write_tsv(cover_kpsM_ncbi_filter, "Protein_database/external_rings_models/external_rings_output/cover_kpsM_ncbi_filter.tsv")
write_tsv(cover_kpsT_ncbi_filter, "Protein_database/external_rings_models/external_rings_output/cover_kpsT_ncbi_filter.tsv")
write_tsv(cover_kpsD_ncbi_filter, "Protein_database/external_rings_models/external_rings_output/cover_kpsD_ncbi_filter.tsv")
write_tsv(cover_neuD_ncbi_filter, "Protein_database/external_rings_models/external_rings_output/cover_neuD_ncbi_filter.tsv")
write_tsv(cover_neuO_ncbi_filter, "Protein_database/external_rings_models/external_rings_output/cover_neuO_ncbi_filter.tsv")

# %% [markdown]
# # Part 02 - Output process

# %%
#KpsM

View_kpsM_ncbi_40_complete <-fread("~/Downloads/new_pos_neg/fastas_others_final/hmmer_models/external_ring_hmm_result_final/filter_kpsM/file_output_kpsM.tsv", fill = 36)


#View_kpsM_ncbi_40_complete <- View_kpsM_ncbi_40[,-c(26:36)]

column_names <-c("target_ID", "accession_1", "tlen", "query_ID", "accession_2", "qlen", "e_value_seq",
                 "score_seq", "bias_seq", "#", "of", "c_value", "i_value", "score_dom", "bias_dom", 
                 "hmm_from", "hmm_to", "ali_from", "ali_to", "env_from", "env_to", "acc", "description")

setnames(View_kpsM_ncbi_40_complete, column_names)
# Out:
#   V1       V2
# 1  95.9064 lst_final_auto_GCF_000008465.1_protein_output.tsv
# 2 100.0000 lst_final_auto_GCF_000008805.1_protein_output.tsv
# 3  94.5455 lst_final_auto_GCF_000009745.1_protein_output.tsv
# 4  97.8979 lst_final_auto_GCF_000018045.1_protein_output.tsv
# 5  11.7764 lst_final_auto_GCF_000021445.1_protein_output.tsv
# 6  94.7368 lst_final_auto_GCF_000026745.1_protein_output.tsv
# [1] 2977

# %%
#Cover filter

LST_cover_filter_2_NCBI <- View_lst_NCBI %>% filter(View_lst_NCBI$V1 >= 40.00)
head(LST_cover_filter_2_NCBI)
nrow(LST_cover_filter_2_NCBI)
# Out:
#   V1       V2
# 1  95.9064 lst_final_auto_GCF_000008465.1_protein_output.tsv
# 2 100.0000 lst_final_auto_GCF_000008805.1_protein_output.tsv
# 3  94.5455 lst_final_auto_GCF_000009745.1_protein_output.tsv
# 4  97.8979 lst_final_auto_GCF_000018045.1_protein_output.tsv
# 5  94.7368 lst_final_auto_GCF_000026745.1_protein_output.tsv
# 6  99.7305 lst_final_auto_GCF_000026965.1_protein_output.tsv
# [1] 1829

# %%
# Save result into a file
write_tsv(LST_cover_filter_2_NCBI, "HMMER_analysis/LST_NCBI_ID_cover_filter_40.tsv")

# %%
########################### pm0188  ##################################################################################################
#upload data for pm0188. Change PATH of the file, if needed
View_pm1088_NCBI <-read.table("plots_data/pm0188_coverage.tsv", 
                              header = FALSE, col.names = c("V1", "V2"))

head(View_pm1088_NCBI)
nrow(View_pm1088_NCBI)
# Out:
#   V1      V2
# 1 16.7109 pm0188_final_auto_GCF_000009725.1_protein_output.tsv
# 2 43.3121 pm0188_final_auto_GCF_000009745.1_protein_output.tsv
# 3 46.3303 pm0188_final_auto_GCF_000010385.1_protein_output.tsv
# 4 46.3303 pm0188_final_auto_GCF_000010745.1_protein_output.tsv
# 5 50.3968 pm0188_final_auto_GCF_000015645.1_protein_output.tsv
# 6 46.3303 pm0188_final_auto_GCF_000017745.1_protein_output.tsv
# [1] 3387

# %%
#Cover filter

pm1088_cover_filter_2_NCBI <- View_pm1088_NCBI %>% filter(View_pm1088_NCBI$V1 >= 40.00)
head(pm1088_cover_filter_2_NCBI)
nrow(pm1088_cover_filter_2_NCBI)
# Out:
#   V1      V2
# 1 43.3121 pm0188_final_auto_GCF_000009745.1_protein_output.tsv
# 2 46.3303 pm0188_final_auto_GCF_000010385.1_protein_output.tsv
# 3 46.3303 pm0188_final_auto_GCF_000010745.1_protein_output.tsv
# 4 50.3968 pm0188_final_auto_GCF_000015645.1_protein_output.tsv
# 5 46.3303 pm0188_final_auto_GCF_000017745.1_protein_output.tsv
# 6 46.3303 pm0188_final_auto_GCF_000023665.1_protein_output.tsv
# [1] 2745

# %%
# Save result into a file
write_tsv(pm1088_cover_filter_2_NCBI, "HMMER_analysis/pm1088_NCBI_ID_cover_filter_40.tsv")

# %%
############################ Lic3A and Lic3B ##########################################################
#Change PATH of the file, if needed
View_lic3_NCBI <-read.table("plots_data/lic3X_coverage.tsv", 
                            header = FALSE, col.names = c("V1", "V2"))

head(View_lic3_NCBI)
nrow(View_lic3_NCBI)
# Out:
#   V1      V2
# 1 98.9796 lic3X_final_auto_GCF_000009085.1_protein_output.tsv
# 2 20.2091 lic3X_final_auto_GCF_000012865.1_protein_output.tsv
# 3 11.2583 lic3X_final_auto_GCF_000016305.1_protein_output.tsv
# 4 98.9796 lic3X_final_auto_GCF_000025425.1_protein_output.tsv
# 5 11.2583 lic3X_final_auto_GCF_000025465.1_protein_output.tsv
# 6 20.6897 lic3X_final_auto_GCF_000050405.1_protein_output.tsv
# [1] 3531

# %%
#Cover filter

Lic3_cover_filter_2_NCBI <- View_lic3_NCBI %>% filter(View_lic3_NCBI$V1 >= 40.00)
head(Lic3_cover_filter_2_NCBI)
nrow(Lic3_cover_filter_2_NCBI)
# Out:
#   V1      V2
# 1 98.9796 lic3X_final_auto_GCF_000009085.1_protein_output.tsv
# 2 98.9796 lic3X_final_auto_GCF_000025425.1_protein_output.tsv
# 3 77.1084 lic3X_final_auto_GCF_000147335.1_protein_output.tsv
# 4 74.7664 lic3X_final_auto_GCF_000152165.1_protein_output.tsv
# 5 74.7664 lic3X_final_auto_GCF_000191485.1_protein_output.tsv
# 6 74.7664 lic3X_final_auto_GCF_000191505.1_protein_output.tsv
# [1] 674

# %%
# Save result into a file

write_tsv(Lic3_cover_filter_2_NCBI, "HMMER_analysis/Lic3_NCBI_ID_cover_filter_40.tsv")

# %%
############################################# neuS - Thais' database
#Change PATH of the file, if needed
View_neuS_thais_NCBI <-read.table("plots_data/neuS_coverage.tsv", 
                                  header = FALSE, col.names = c("V1", "V2"))

head(View_neuS_thais_NCBI)
nrow(View_neuS_thais_NCBI)
# Out:
#   V1      V2
# 1 26.2626 neuS_final_auto_GCF_000007045.1_protein_output.tsv
# 2 51.0471 neuS_final_auto_GCF_000007465.2_protein_output.tsv
# 3 40.0000 neuS_final_auto_GCF_000007605.1_protein_output.tsv
# 4 15.3173 neuS_final_auto_GCF_000007705.1_protein_output.tsv
# 5 44.6352 neuS_final_auto_GCF_000008045.1_protein_output.tsv
# 6 55.4455 neuS_final_auto_GCF_000008185.1_protein_output.tsv
# [1] 9994

# %%
#Cover filter

neuS_tha_cover_filter_2_NCBI <- View_neuS_thais_NCBI %>% filter(View_neuS_thais_NCBI$V1 >= 40.00)
head(neuS_tha_cover_filter_2_NCBI)
nrow(neuS_tha_cover_filter_2_NCBI)
# Out:
#   V1      V2
# 1 51.0471 neuS_final_auto_GCF_000007465.2_protein_output.tsv
# 2 40.0000 neuS_final_auto_GCF_000007605.1_protein_output.tsv
# 3 44.6352 neuS_final_auto_GCF_000008045.1_protein_output.tsv
# 4 55.4455 neuS_final_auto_GCF_000008185.1_protein_output.tsv
# 5 64.9485 neuS_final_auto_GCF_000008225.1_protein_output.tsv
# 6 64.9485 neuS_final_auto_GCF_000008405.1_protein_output.tsv
# [1] 4585

# %%
# Save result into a file
write_tsv(neuS_tha_cover_filter_2_NCBI, "HMMER_analysis/neuS_thais_NCBI_ID_cover_filter_40.tsv")

# %%
########################## pm1088 PFAM "11477"
#Change PATH of the file, if needed
View_pm1088_11477_PFAM_NCBI <-read.table("plots_data/PF11477_coverage.tsv", 
                                         header = FALSE, col.names = c("V1", "V2"))

head(View_pm1088_11477_PFAM_NCBI)
nrow(View_pm1088_11477_PFAM_NCBI)
# Out:
#   V1      V2
# 1 41.6667 PF11477_GCF_000011505.1_protein_output.tsv
# 2 13.4328 PF11477_GCF_000012205.1_protein_output.tsv
# 3 13.3995 PF11477_GCF_000012265.1_protein_output.tsv
# 4 12.6521 PF11477_GCF_000013805.1_protein_output.tsv
# 5 12.6521 PF11477_GCF_000016445.1_protein_output.tsv
# 6  7.4813 PF11477_GCF_000016665.1_protein_output.tsv
# [1] 3530

# %%
#Cover filter

pm1088_PFAM_cover_filter_NCBI <- View_pm1088_11477_PFAM_NCBI %>% filter(V1 >= 40.00)
head(pm1088_PFAM_cover_filter_NCBI)
nrow(pm1088_PFAM_cover_filter_NCBI)
# Out:
#   V1      V2
# 1 41.6667 PF11477_GCF_000011505.1_protein_output.tsv
# 2 43.6548 PF11477_GCF_000025365.1_protein_output.tsv
# 3 43.6548 PF11477_GCF_000092585.1_protein_output.tsv
# 4 46.8750 PF11477_GCF_000231385.2_protein_output.tsv
# 5 90.0485 PF11477_GCF_000259545.1_protein_output.tsv
# 6 53.2609 PF11477_GCF_000499805.2_protein_output.tsv
# [1] 684

# %%
# Save result into a file

write_tsv(pm1088_PFAM_cover_filter_NCBI, "HMMER_analysis/PF11477_NCBI_ID_cover_filter_40.tsv")

# %%
########################################## PFAM cst2 - PF06002
#Change PATH of the file, if needed
View_cst2_06002_PFAM_NCBI <-read.table("plots_data/PF06002_coverage.tsv", 
                                       header = FALSE, col.names = c("V1", "V2"))

head(View_cst2_06002_PFAM_NCBI)
nrow(View_cst2_06002_PFAM_NCBI)
# Out:
#   V1       V2
# 1 88.65030 PF06002_GCF_000012185.1_protein_output.tsv
# 2  9.79021 PF06002_GCF_000012325.1_protein_output.tsv
# 3 25.23660 PF06002_GCF_000014505.1_protein_output.tsv
# 4 99.31270 PF06002_GCF_000015525.1_protein_output.tsv
# 5 24.57420 PF06002_GCF_000017025.1_protein_output.tsv
# 6 24.33460 PF06002_GCF_000019045.1_protein_output.tsv
# [1] 1694

# %%
#Cover filter

cst2_PFAM_cover_filter_NCBI <- View_cst2_06002_PFAM_NCBI %>% filter(V1 >= 40.00)
head(cst2_PFAM_cover_filter_NCBI)
nrow(cst2_PFAM_cover_filter_NCBI)
# Out:
#   V1      V2
# 1 88.6503 PF06002_GCF_000012185.1_protein_output.tsv
# 2 99.3127 PF06002_GCF_000015525.1_protein_output.tsv
# 3 86.1210 PF06002_GCF_000091985.1_protein_output.tsv
# 4 58.2656 PF06002_GCF_000148915.1_protein_output.tsv
# 5 88.9571 PF06002_GCF_000165525.1_protein_output.tsv
# 6 61.6667 PF06002_GCF_000185885.1_protein_output.tsv
# [1] 633

# %%
# Save result into a file
write_tsv(cst2_PFAM_cover_filter_NCBI, "HMMER_analysis/PF06002_NCBI_ID_cover_filter_40.tsv")

# %%
##########################PFAM neuS - IPR010866
# Change PATH of the file, if needed
View_neuS_PFAM_NCBI <-read.table("plots_data/IPR010866_coverage.tsv", 
                                 header = FALSE, col.names = c("V1", "V2"))

head(View_neuS_PFAM_NCBI)
nrow(View_neuS_PFAM_NCBI)
# Out:
#   V1      V2
# 1 27.2152 IPR010866_auto_GCF_000009045.1_protein_output.tsv
# 2  5.5102 IPR010866_auto_GCF_000009685.1_protein_output.tsv
# 3 99.3243 IPR010866_auto_GCF_000009765.2_protein_output.tsv
# 4 74.9319 IPR010866_auto_GCF_000010065.1_protein_output.tsv
# 5 12.9817 IPR010866_auto_GCF_000010265.1_protein_output.tsv
# 6 13.8776 IPR010866_auto_GCF_000010705.1_protein_output.tsv
# [1] 10775

# %%
#Cover filter

neuS_PFAM_cover_filter_NCBI <- View_neuS_PFAM_NCBI %>% filter(V1 >= 40.00)
head(neuS_PFAM_cover_filter_NCBI)
nrow(neuS_PFAM_cover_filter_NCBI)
# Out:
#      V1      V2
# 1    99.3243 IPR010866_auto_GCF_000009765.2_protein_output.tsv
# 2    74.9319 IPR010866_auto_GCF_000010065.1_protein_output.tsv
# 3    91.6168 IPR010866_auto_GCF_000012965.1_protein_output.tsv
# 4    76.0163 IPR010866_auto_GCF_000014105.1_protein_output.tsv
# 5    87.9765 IPR010866_auto_GCF_000015045.1_protein_output.tsv
# 6    61.3312 IPR010866_auto_GCF_000015685.1_protein_output.tsv
# 7    92.4290 IPR010866_auto_GCF_000017045.1_protein_output.tsv
# 8    48.2255 IPR010866_auto_GCF_000017805.1_protein_output.tsv
# 9    92.4290 IPR010866_auto_GCF_000019305.1_protein_output.tsv
# 10   43.7500 IPR010866_auto_GCF_000020465.1_protein_output.tsv
# 11   50.4695 IPR010866_auto_GCF_000021905.1_protein_output.tsv
# 12   62.3377 IPR010866_auto_GCF_000024405.1_protein_output.tsv
# 13   45.2128 IPR010866_auto_GCF_000025985.1_protein_output.tsv
# 14   76.5743 IPR010866_auto_GCF_000061505.1_protein_output.tsv
# 15   92.4290 IPR010866_auto_GCF_000063585.1_protein_output.tsv
# ...

# %%
# Save result into a file
write_tsv(neuS_PFAM_cover_filter_NCBI, "HMMER_analysis/IPR01086_NCBI_ID_cover_filter_40.tsv")

# %%
#Poly(oacetil) representative


cover_oacetil_representative <-read.table("microbiota_sialylation/genomes_download/HMMER_analysis/o_acetiltrans_plus_poli/representative_oacetil/all_oacetil_cover", 
                                       header = FALSE,col.names = c("V1", "V2"))

View(cover_oacetil_representative)

# %%
#Filter by coverage
oacetilpresentative_cover_filter <- cover_oacetil_representative %>%filter(cover_oacetil_representative$V1 >= 60.00)
oacetil_representative_cover_filter_2 <- cover_oacetil_representative %>% filter(cover_oacetil_representative$V1 >= 40.00)
nrow(oacetil_representative_cover_filter)
nrow(oacetil_representative_cover_filter_2)

# Save result into a file

write_tsv(oacetil_representative_cover_filter_2, "microbiota_sialylation/genomes_download/HMMER_analysis/o_acetiltrans_plus_poli/representative_oacetil/oacetil_representative_cover_filter_40.tsv")

# %%
#Get data from poly(oacetil) representative 
library(data.table)
#without a header
View_oacetil_representative_40 <-fread("microbiota_sialylation/genomes_download/HMMER_analysis/o_acetiltrans_plus_poli/representative_oacetil/filtered_oacetil/all_oacetil_plus_poli.tsv", fill =33)

View_oacetil_representative_40 <- View_oacetil_representative_40[,-c(26:33)]

column_names <-c("target_ID", "accession_1", "tlen", "query_ID", "accession_2", "qlen", "e_value_seq",
                 "score_seq", "bias_seq", "#", "of", "c_value", "i_value", "score_dom", "bias_dom", 
                 "hmm_from", "hmm_to", "ali_from", "ali_to", "env_from", "env_to", "acc", "description",
                 "of_1", "target")

setnames(View_oacetil_representative_40, column_names)

# %%
View_oacetil_representative_process <- View_oacetil_representative_40%>% distinct(View_oacetil_representative_40$target_ID, .keep_all = TRUE)

final_oacetil_representative_process <-View_oacetil_representative_process %>% 
  filter(View_oacetil_representative_process$e_value_seq <= 0.001 & View_oacetil_representative_process$score_seq >= 50.0)

write_tsv(final_oacetil_representative_process, "microbiota_sialylation/genomes_download/plots_data/itol/oacetil_represent_filter.tsv")

# %%
#RfaH for representative

cover_rfah_representative <-read.table("microbiota_sialylation/genomes_download/HMMER_analysis/RfaH/representative_RfaH/rfah_coverage", 
                                          header = FALSE,col.names = c("V1", "V2"))

head(cover_oacetil_representative)
getwd()

#Filter by coverage
rfah_resentative_cover_filter <- cover_rfah_representative %>%filter(cover_rfah_representative$V1 >= 60.00)
rfah_representative_cover_filter_2 <- cover_rfah_representative %>% filter(cover_rfah_representative$V1 >= 40.00)
nrow(rfah_resentative_cover_filter)
nrow(rfah_representative_cover_filter_2)

# Save result into a file

write_tsv(rfah_representative_cover_filter_2, "microbiota_sialylation/genomes_download/HMMER_analysis/RfaH/representative_RfaH/rfah_representative_cover_filter_40.tsv")

# %%
#get tsv file with all results from representative

#without a header
View_rfah_representative_40 <-fread("microbiota_sialylation/genomes_download/HMMER_analysis/RfaH/representative_RfaH/filter_rfaH/all_rfah_tsv_w_o_cruz.tsv", fill = 33)

View_rfah_representative_40 <- View_rfah_representative_40[,-c(26:33)]

column_names <-c("target_ID","accession_1","tlen","query_ID","accession_2","qlen","e_value_seq",
                 "score_seq","bias_seq","#", "of", "c_value", "i_value", "score_dom", "bias_dom", 
                 "hmm_from", "hmm_to", "ali_from", "ali_to", "env_from", "env_to", "acc", "description",
                 "of_1", "target")

setnames(View_rfah_representative_40, column_names)

# %%
View_rfah_representative_process <- View_rfah_representative_40%>% distinct(View_rfah_representative_40$target_ID, .keep_all = TRUE)

final_rfah_representative_process <-View_rfah_representative_process %>% 
  filter(View_rfah_representative_process$e_value_seq <= 0.001 & View_rfah_representative_process$score_seq >= 50.0)

write_tsv(final_rfah_representative_process, "microbiota_sialylation/genomes_download/plots_data/itol/rfah_represent_filter.tsv")
