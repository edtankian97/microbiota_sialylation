# %%
#Itol annotation for tree phylogeny

#Load libraries
library(readr)
library(dplyr)
library(stringr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
setwd("/mnt/l/Sia_git")

# %%
# Set the working directory to the parent folder of genomes_download/
# Example:
# setwd("~/microbiota_sialylation")

# %%
#all data files upload
#set PATH to microbiota_sialylation folder in R environment. Example: setwd(home/user/microbiota_sialylation)
all_GCF_files <- read_delim("genomes_download/plots_data/itol/complete_sialylation_interpro_filtration_final.tsv",  , 
                             delim = "\t", escape_double = FALSE, 
                             trim_ws = TRUE, col_names = "GCF_ID")

head(all_GCF_files)

#KpsM
KpsM_phylogeny <-read_delim("genomes_download/plots_data/itol/KpsM_interpro_distinct_unique_phylogeny.tsv", 
                                                      delim = "\t", escape_double = FALSE, 
                                                      trim_ws = TRUE)
head(KpsM_phylogeny)

#KpsT
KpsT_phylogeny <-read_delim("genomes_download/plots_data/itol/KpsT_interpro_distinct_unique_phylogeny.tsv", 
                                                      delim = "\t", escape_double = FALSE, 
                                                      trim_ws = TRUE)
head(KpsT_phylogeny)

#neuO
neuO_phylogeny <-read_delim("genomes_download/plots_data/itol/neuO_interpro_distinct_unique_phylogeny.tsv", 
                                                      delim = "\t", escape_double = FALSE, 
                                                      trim_ws = TRUE)
head(neuO_phylogeny)

#neuD
neuD_phylogeny <- read_delim("genomes_download/plots_data/itol/neuD_interpro_distinct_unique_phylogeny.tsv", 
                                                      delim = "\t", escape_double = FALSE, 
                                                      trim_ws = TRUE)
head(neuD_phylogeny)

#KpsD
KpsD_phylogeny <- read_delim("genomes_download/plots_data/itol/KpsD_interpro_distinct_unique_phylogeny.tsv", 
                                                      delim = "\t", escape_double = FALSE, 
                                                      trim_ws = TRUE)
head(KpsD_phylogeny)

vfdb_70id_60cov <- read_csv("genomes_download/plots_data/itol/out_70id_60cov.csv")
# Out:
# Rows: 2459 Columns: 1
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): GCF_ID
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   GCF_ID
# 1 GCF_000767075.1
# 2 GCF_032598905.1
# 3 GCF_002866045.1
# 4 GCF_029338175.1
# 5 GCF_033096605.1
# 6 GCF_036189845.1
# Rows: 2172 Columns: 1
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): GCF_ID
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   GCF_ID
# 1 GCF_012224765.1
# 2 GCF_020783455.1
# 3 GCF_012850815.1
# 4 GCF_012849875.1
# 5 GCF_000969315.2
# 6 GCF_003864155.1
# Rows: 1849 Columns: 1
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): GCF_ID
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   GCF_ID
# 1 GCF_020410765.1
# 2 GCF_002128305.1
# 3 GCF_029025785.1
# 4 GCF_036014215.1
# 5 GCF_001856725.1
# 6 GCF_019930705.1
# Rows: 1386 Columns: 1
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): GCF_ID
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   GCF_ID
# 1 GCF_008704715.1
# 2 GCF_013375055.1
# 3 GCF_028898665.1
# 4 GCF_028898625.1
# 5 GCF_035918115.1
# 6 GCF_035917555.1
# Rows: 1278 Columns: 1
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): GCF_ID
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   GCF_ID
# 1 GCF_036345175.1
# 2 GCF_024347515.1
# 3 GCF_027945035.1
# 4 GCF_027945015.1
# 5 GCF_027945095.1
# 6 GCF_027944715.1
# Rows: 818 Columns: 1
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): GCF_ID
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   GCF_ID
# 1 GCF_013357745.1
# 2 GCF_001687475.2
# 3 GCF_002407505.1
# 4 GCF_963666525.1
# 5 GCF_022220325.1
# 6 GCF_009498375.1
# Rows: 169927 Columns: 15
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (10): #FILE, SEQUENCE, STRAND, GENE, COVERAGE, COVERAGE_MAP, GAPS, DATAB...
# dbl  (4): START, END, %COVERAGE, %IDENTITY
# lgl  (1): RESISTANCE
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
#Itol
#KpsM
#See what is different: the ones which were not in protein dataset's results
diff_representative_kpsM <- setdiff(all_GCF_files %>% select(GCF_ID), KpsM_phylogeny %>% select(GCF_ID))
head(diff_representative_kpsM)

#Atributte color and attach string "_protein" to IDs which were not identified any protein
diff_representative_kpsM$level <- "#FFFF8F"
diff_representative_kpsM$GCF_ID <- paste0(diff_representative_kpsM$GCF_ID, "_protein")

#Atributte color and attach string "_protein" to ID's identified with protein
KpsM_phylogeny$level <- "#FDDA0D"
KpsM_phylogeny$GCF_ID <- paste0(KpsM_phylogeny$GCF_ID, "_protein")


#Join the data
data_kpsM_itol_represent <- rbind(KpsM_phylogeny, diff_representative_kpsM)
View(data_kpsM_itol_represent)

#save results into a file
write_tsv(data_kpsM_itol_represent, "genomes_download/plots_data/itol/kpsM_itol_represent_EANS_paper.tsv")
# Out:
#   GCF_ID
# 1 GCF_000767075.1
# 2 GCF_002866045.1
# 3 GCF_000253195.1
# 4 GCF_000193205.1
# 5 GCF_907163125.1
# 6 GCF_900477945.1
#      GCF_ID                  level
# 1    GCF_012224765.1_protein #FDDA0D
# 2    GCF_020783455.1_protein #FDDA0D
# 3    GCF_012850815.1_protein #FDDA0D
# 4    GCF_012849875.1_protein #FDDA0D
# 5    GCF_000969315.2_protein #FDDA0D
# 6    GCF_003864155.1_protein #FDDA0D
# 7    GCF_011765605.1_protein #FDDA0D
# 8    GCF_012850455.1_protein #FDDA0D
# 9    GCF_012850955.1_protein #FDDA0D
# 10   GCF_012850275.1_protein #FDDA0D
# 11   GCF_012850655.1_protein #FDDA0D
# 12   GCF_012850075.1_protein #FDDA0D
# 13   GCF_036010645.1_protein #FDDA0D
# 14   GCF_036180305.1_protein #FDDA0D
# 15   GCF_036075115.1_protein #FDDA0D
# 16   GCF_036226365.1_protein #FDDA0D
# 17   GCF_009763565.1_protein #FDDA0D
# 18   GCF_001682175.1_protein #FDDA0D
# 19   GCF_002220985.3_protein #FDDA0D
# 20   GCF_002209725.2_protein #FDDA0D
# 21   GCF_008271365.1_protein #FDDA0D
# 22   GCF_035224565.1_protein #FDDA0D
# 23   GCF_032598655.1_protein #FDDA0D
# 24   GCF_009495655.1_protein #FDDA0D
# 25   GCF_019703895.1_protein #FDDA0D
# 26   GCF_000196495.1_protein #FDDA0D
# 27   GCF_013423905.1_protein #FDDA0D
# 28   GCF_025163575.1_protein #FDDA0D
# 29   GCF_000695235.1_protein #FDDA0D
# 30   GCF_000935185.3_protein #FDDA0D
# ⋮    ⋮                       ⋮
# 2430 GCF_016755695.1_protein #FFFF8F
# 2431 GCF_016748925.1_protein #FFFF8F
# 2432 GCF_000224535.1_protein #FFFF8F
# 2433 GCF_000224555.1_protein #FFFF8F
# 2434 GCF_000277365.1_protein #FFFF8F
# 2435 GCF_016755655.1_protein #FFFF8F
# 2436 GCF_014931275.1_protein #FFFF8F
# 2437 GCF_003425645.1_protein #FFFF8F
# 2438 GCF_003425445.1_protein #FFFF8F
# 2439 GCF_003425625.1_protein #FFFF8F
# 2440 GCF_003425815.1_protein #FFFF8F
# 2441 GCF_003019315.1_protein #FFFF8F
# 2442 GCF_004328885.1_protein #FFFF8F
# 2443 GCF_002327205.1_protein #FFFF8F
# 2444 GCF_900168365.1_protein #FFFF8F
# 2445 GCF_002327185.1_protein #FFFF8F
# 2446 GCF_900683745.1_protein #FFFF8F
# 2447 GCF_001889345.1_protein #FFFF8F
# 2448 GCF_002865765.1_protein #FFFF8F
# 2449 GCF_028657925.1_protein #FFFF8F
# 2450 GCF_031759225.1_protein #FFFF8F
# 2451 GCF_001602095.1_protein #FFFF8F
# 2452 GCF_031191225.1_protein #FFFF8F
# 2453 GCF_019047825.1_protein #FFFF8F
# 2454 GCF_009730515.1_protein #FFFF8F
# 2455 GCF_000148585.2_protein #FFFF8F
# 2456 GCF_000427075.1_protein #FFFF8F
# 2457 GCF_009930895.1_protein #FFFF8F
# 2458 GCF_029625275.1_protein #FFFF8F
# 2459 GCF_001999985.1_protein #FFFF8F

# %%
#KpsT

#See what is different: the ones which were not in protein dataset's results
diff_representative_kpsT <- setdiff(all_GCF_files %>% select(GCF_ID), KpsT_phylogeny %>% select(GCF_ID))
head(diff_representative_kpsT)

#Atributte color and attach string "_protein" to IDs which were not identified any protein
diff_representative_kpsT$level <- "#F88379"
diff_representative_kpsT$GCF_ID <- paste0(diff_representative_kpsT$GCF_ID, "_protein")

#Atributte color and attach string "_protein" to ID's identified with protein
KpsT_phylogeny$level <- "#9F2B68"
KpsT_phylogeny$GCF_ID <- paste0(KpsT_phylogeny$GCF_ID, "_protein")


#Join the data
data_kpsT_itol_represent <- rbind(KpsT_phylogeny, diff_representative_kpsT)
View(data_kpsT_itol_represent)

#save results into a file
write_tsv(data_kpsT_itol_represent, "genomes_download/plots_data/itol/kpsT_itol_represent_EANS_paper.tsv")
# Out:
#   GCF_ID
# 1 GCF_000767075.1
# 2 GCF_002866045.1
# 3 GCF_029338175.1
# 4 GCF_900478135.1
# 5 GCF_902386615.1
# 6 GCF_963678185.1
#      GCF_ID                  level
# 1    GCF_020410765.1_protein #9F2B68
# 2    GCF_002128305.1_protein #9F2B68
# 3    GCF_029025785.1_protein #9F2B68
# 4    GCF_036014215.1_protein #9F2B68
# 5    GCF_001856725.1_protein #9F2B68
# 6    GCF_019930705.1_protein #9F2B68
# 7    GCF_003351585.1_protein #9F2B68
# 8    GCF_016861285.1_protein #9F2B68
# 9    GCF_014701215.1_protein #9F2B68
# 10   GCF_000210875.1_protein #9F2B68
# 11   GCF_014151925.1_protein #9F2B68
# 12   GCF_014151825.1_protein #9F2B68
# 13   GCF_016458865.1_protein #9F2B68
# 14   GCF_035917655.1_protein #9F2B68
# 15   GCF_000739105.1_protein #9F2B68
# 16   GCF_023973125.1_protein #9F2B68
# 17   GCF_001767235.1_protein #9F2B68
# 18   GCF_036250675.1_protein #9F2B68
# 19   GCF_036248295.1_protein #9F2B68
# 20   GCF_036346815.1_protein #9F2B68
# 21   GCF_035954955.1_protein #9F2B68
# 22   GCF_016467295.1_protein #9F2B68
# 23   GCF_025231465.1_protein #9F2B68
# 24   GCF_004104485.1_protein #9F2B68
# 25   GCF_034424055.1_protein #9F2B68
# 26   GCF_012931585.1_protein #9F2B68
# 27   GCF_016026555.1_protein #9F2B68
# 28   GCF_016026595.1_protein #9F2B68
# 29   GCF_036013645.1_protein #9F2B68
# 30   GCF_001729485.1_protein #9F2B68
# ⋮    ⋮                       ⋮
# 2430 GCF_029774055.1_protein #F88379
# 2431 GCF_023206035.1_protein #F88379
# 2432 GCF_024347415.1_protein #F88379
# 2433 GCF_031191225.1_protein #F88379
# 2434 GCF_019047825.1_protein #F88379
# 2435 GCF_009730515.1_protein #F88379
# 2436 GCF_000148585.2_protein #F88379
# 2437 GCF_014892695.1_protein #F88379
# 2438 GCF_009665215.1_protein #F88379
# 2439 GCF_028898665.1_protein #F88379
# 2440 GCF_028898625.1_protein #F88379
# 2441 GCF_000427075.1_protein #F88379
# 2442 GCF_009930895.1_protein #F88379
# 2443 GCF_029625275.1_protein #F88379
# 2444 GCF_034071365.1_protein #F88379
# 2445 GCF_029987435.1_protein #F88379
# 2446 GCF_000328545.1_protein #F88379
# 2447 GCF_016653495.1_protein #F88379
# 2448 GCF_028743695.1_protein #F88379
# 2449 GCF_036347715.1_protein #F88379
# 2450 GCF_035220555.1_protein #F88379
# 2451 GCF_023586965.1_protein #F88379
# 2452 GCF_035222775.1_protein #F88379
# 2453 GCF_008086425.1_protein #F88379
# 2454 GCF_016415165.1_protein #F88379
# 2455 GCF_008087605.1_protein #F88379
# 2456 GCF_002240035.1_protein #F88379
# 2457 GCF_019930805.1_protein #F88379
# 2458 GCF_001999985.1_protein #F88379
# 2459 GCF_008931805.1_protein #F88379

# %%
#neuO

#See what is different: the ones which were not in protein dataset's results
diff_representative_neuO <- setdiff(all_GCF_files %>% select(GCF_ID), neuO_phylogeny %>% select(GCF_ID))
head(diff_representative_neuO)

#Atributte color and attach string "_protein" to IDs which were not identified any protein
diff_representative_neuO$level <- "#64b6ee"
diff_representative_neuO$GCF_ID <- paste0(diff_representative_neuO$GCF_ID, "_protein")

#Atributte color and attach string "_protein" to ID's identified with protein
neuO_phylogeny$level <- "#2c43b0"
neuO_phylogeny$GCF_ID <- paste0(neuO_phylogeny$GCF_ID, "_protein")


#Join the data
data_neuO_itol_represent <- rbind(neuO_phylogeny, diff_representative_neuO)
View(data_neuO_itol_represent)

#save results into a file
write_tsv(data_neuO_itol_represent, "genomes_download/plots_data/itol/neuO_itol_represent_EANS_paper.tsv")
# Out:
#   GCF_ID
# 1 GCF_000767075.1
# 2 GCF_033096605.1
# 3 GCF_008704995.1
# 4 GCF_017352335.1
# 5 GCF_900478135.1
# 6 GCF_902386615.1
#      GCF_ID                  level
# 1    GCF_008704715.1_protein #2c43b0
# 2    GCF_013375055.1_protein #2c43b0
# 3    GCF_028898665.1_protein #2c43b0
# 4    GCF_028898625.1_protein #2c43b0
# 5    GCF_035918115.1_protein #2c43b0
# 6    GCF_035917555.1_protein #2c43b0
# 7    GCF_000831125.1_protein #2c43b0
# 8    GCF_022807935.1_protein #2c43b0
# 9    GCF_014058605.1_protein #2c43b0
# 10   GCF_014058585.1_protein #2c43b0
# 11   GCF_014058625.1_protein #2c43b0
# 12   GCF_014058645.1_protein #2c43b0
# 13   GCF_014058485.1_protein #2c43b0
# 14   GCF_023587665.1_protein #2c43b0
# 15   GCF_014058665.1_protein #2c43b0
# 16   GCF_014058465.1_protein #2c43b0
# 17   GCF_016890085.1_protein #2c43b0
# 18   GCF_016888985.1_protein #2c43b0
# 19   GCF_036232025.1_protein #2c43b0
# 20   GCF_034668605.1_protein #2c43b0
# 21   GCF_036248545.1_protein #2c43b0
# 22   GCF_036250085.1_protein #2c43b0
# 23   GCF_036250635.1_protein #2c43b0
# 24   GCF_036226985.1_protein #2c43b0
# 25   GCF_029338175.1_protein #2c43b0
# 26   GCF_000010605.1_protein #2c43b0
# 27   GCF_003627155.1_protein #2c43b0
# 28   GCF_035917935.1_protein #2c43b0
# 29   GCF_036347215.1_protein #2c43b0
# 30   GCF_036243495.1_protein #2c43b0
# ⋮    ⋮                       ⋮
# 2430 GCF_002209045.1_protein #64b6ee
# 2431 GCF_007289895.1_protein #64b6ee
# 2432 GCF_009834145.1_protein #64b6ee
# 2433 GCF_032927875.1_protein #64b6ee
# 2434 GCF_009730395.1_protein #64b6ee
# 2435 GCF_030370375.1_protein #64b6ee
# 2436 GCF_036013785.1_protein #64b6ee
# 2437 GCF_035979555.1_protein #64b6ee
# 2438 GCF_034071365.1_protein #64b6ee
# 2439 GCF_029987435.1_protein #64b6ee
# 2440 GCF_018128905.1_protein #64b6ee
# 2441 GCF_030370195.1_protein #64b6ee
# 2442 GCF_030370215.1_protein #64b6ee
# 2443 GCF_030370355.1_protein #64b6ee
# 2444 GCF_020971705.1_protein #64b6ee
# 2445 GCF_030503855.1_protein #64b6ee
# 2446 GCF_016653495.1_protein #64b6ee
# 2447 GCF_009649035.1_protein #64b6ee
# 2448 GCF_001870105.1_protein #64b6ee
# 2449 GCF_033096785.1_protein #64b6ee
# 2450 GCF_001870085.1_protein #64b6ee
# 2451 GCF_009498375.1_protein #64b6ee
# 2452 GCF_002407125.1_protein #64b6ee
# 2453 GCF_003971585.1_protein #64b6ee
# 2454 GCF_030035405.1_protein #64b6ee
# 2455 GCF_008086425.1_protein #64b6ee
# 2456 GCF_016415165.1_protein #64b6ee
# 2457 GCF_008087605.1_protein #64b6ee
# 2458 GCF_002240035.1_protein #64b6ee
# 2459 GCF_019930805.1_protein #64b6ee

# %%
#neuD

#See what is different: the ones which were not in protein dataset's results
diff_representative_neuD <- setdiff(all_GCF_files %>% select(GCF_ID), neuD_phylogeny %>% select(GCF_ID))
head(diff_representative_neuD)

#Atributte color and attach string "_protein" to IDs which were not identified any protein
diff_representative_neuD$level <- "#bdbdbd"
diff_representative_neuD$GCF_ID <- paste0(diff_representative_neuD$GCF_ID, "_protein")

#Atributte color and attach string "_protein" to ID's identified with protein
neuD_phylogeny$level <- "#636363"
neuD_phylogeny$GCF_ID <- paste0(neuD_phylogeny$GCF_ID, "_protein")


#Join the data
data_neuD_itol_represent <- rbind(neuD_phylogeny, diff_representative_neuD)
View(data_neuD_itol_represent)

#save results into a file
write_tsv(data_neuD_itol_represent, "genomes_download/plots_data/itol/neuD_itol_represent_EANS_paper.tsv")
# Out:
#   GCF_ID
# 1 GCF_000767075.1
# 2 GCF_032598905.1
# 3 GCF_036189845.1
# 4 GCF_036226185.1
# 5 GCF_036224405.1
# 6 GCF_008704995.1
#      GCF_ID                  level
# 1    GCF_036345175.1_protein #636363
# 2    GCF_024347515.1_protein #636363
# 3    GCF_027945035.1_protein #636363
# 4    GCF_027945015.1_protein #636363
# 5    GCF_027945095.1_protein #636363
# 6    GCF_027944715.1_protein #636363
# 7    GCF_028898625.1_protein #636363
# 8    GCF_028898665.1_protein #636363
# 9    GCF_028898705.1_protein #636363
# 10   GCF_000770115.1_protein #636363
# 11   GCF_024346975.1_protein #636363
# 12   GCF_000831125.1_protein #636363
# 13   GCF_000831105.1_protein #636363
# 14   GCF_003288055.1_protein #636363
# 15   GCF_000831145.1_protein #636363
# 16   GCF_016838665.1_protein #636363
# 17   GCF_036013895.1_protein #636363
# 18   GCF_009883835.1_protein #636363
# 19   GCF_021730025.1_protein #636363
# 20   GCF_021729965.1_protein #636363
# 21   GCF_030552955.1_protein #636363
# 22   GCF_028609705.1_protein #636363
# 23   GCF_009763445.1_protein #636363
# 24   GCF_009665495.1_protein #636363
# 25   GCF_000196095.1_protein #636363
# 26   GCF_030059845.1_protein #636363
# 27   GCF_002073775.2_protein #636363
# 28   GCF_004006515.1_protein #636363
# 29   GCF_028609685.1_protein #636363
# 30   GCF_001879585.1_protein #636363
# ⋮    ⋮                       ⋮
# 2430 GCF_016313205.1_protein #bdbdbd
# 2431 GCF_023573005.1_protein #bdbdbd
# 2432 GCF_019134675.1_protein #bdbdbd
# 2433 GCF_009739575.1_protein #bdbdbd
# 2434 GCF_018139065.1_protein #bdbdbd
# 2435 GCF_004792595.1_protein #bdbdbd
# 2436 GCF_021474145.1_protein #bdbdbd
# 2437 GCF_036416355.1_protein #bdbdbd
# 2438 GCF_026315145.1_protein #bdbdbd
# 2439 GCF_002068175.1_protein #bdbdbd
# 2440 GCF_018968665.1_protein #bdbdbd
# 2441 GCF_004792555.1_protein #bdbdbd
# 2442 GCF_001874445.1_protein #bdbdbd
# 2443 GCF_023587585.1_protein #bdbdbd
# 2444 GCF_024055505.2_protein #bdbdbd
# 2445 GCF_000259545.1_protein #bdbdbd
# 2446 GCF_026409365.1_protein #bdbdbd
# 2447 GCF_026315125.1_protein #bdbdbd
# 2448 GCF_000495635.2_protein #bdbdbd
# 2449 GCF_019285735.1_protein #bdbdbd
# 2450 GCF_000147815.2_protein #bdbdbd
# 2451 GCF_020034615.1_protein #bdbdbd
# 2452 GCF_008086425.1_protein #bdbdbd
# 2453 GCF_016415165.1_protein #bdbdbd
# 2454 GCF_008087605.1_protein #bdbdbd
# 2455 GCF_036541015.1_protein #bdbdbd
# 2456 GCF_003932965.1_protein #bdbdbd
# 2457 GCF_036226805.1_protein #bdbdbd
# 2458 GCF_008931805.1_protein #bdbdbd
# 2459 GCF_024362265.1_protein #bdbdbd

# %%
#KpsD

#See what is different: the ones which were not in protein dataset's results
diff_representative_KpsD <- setdiff(all_GCF_files %>% select(GCF_ID), KpsD_phylogeny %>% select(GCF_ID))
head(diff_representative_KpsD)

#Atributte color and attach string "_protein" to IDs which were not identified any protein
diff_representative_KpsD$level <- "#cea2fd"
diff_representative_KpsD$GCF_ID <- paste0(diff_representative_KpsD$GCF_ID, "_protein")

#Atributte color and attach string "_protein" to ID's identified with protein
KpsD_phylogeny$level <- "#800080"
KpsD_phylogeny$GCF_ID <- paste0(KpsD_phylogeny$GCF_ID, "_protein")


#Join the data
data_KpsD_itol_represent <- rbind(KpsD_phylogeny, diff_representative_KpsD)
View(data_KpsD_itol_represent)

#save results into a file
write_tsv(data_KpsD_itol_represent, "genomes_download/plots_data/itol/KpsD_itol_represent_EANS_paper.tsv")
# Out:
#   GCF_ID
# 1 GCF_000767075.1
# 2 GCF_032598905.1
# 3 GCF_002866045.1
# 4 GCF_029338175.1
# 5 GCF_036189845.1
# 6 GCF_036226185.1
#      GCF_ID                  level
# 1    GCF_013357745.1_protein #800080
# 2    GCF_001687475.2_protein #800080
# 3    GCF_002407505.1_protein #800080
# 4    GCF_963666525.1_protein #800080
# 5    GCF_022220325.1_protein #800080
# 6    GCF_009498375.1_protein #800080
# 7    GCF_022220305.1_protein #800080
# 8    GCF_025200945.1_protein #800080
# 9    GCF_004564095.1_protein #800080
# 10   GCF_020810655.1_protein #800080
# 11   GCF_020271605.1_protein #800080
# 12   GCF_029774055.1_protein #800080
# 13   GCF_023824315.1_protein #800080
# 14   GCF_003097535.1_protein #800080
# 15   GCF_022369435.1_protein #800080
# 16   GCF_013201605.1_protein #800080
# 17   GCF_014788985.1_protein #800080
# 18   GCF_949361555.1_protein #800080
# 19   GCF_004795855.1_protein #800080
# 20   GCF_002850575.1_protein #800080
# 21   GCF_000196095.1_protein #800080
# 22   GCF_030552955.1_protein #800080
# 23   GCF_004006515.1_protein #800080
# 24   GCF_002073775.2_protein #800080
# 25   GCF_030060635.1_protein #800080
# 26   GCF_001186215.2_protein #800080
# 27   GCF_005234135.1_protein #800080
# 28   GCF_019797805.1_protein #800080
# 29   GCF_003287015.1_protein #800080
# 30   GCF_029774095.1_protein #800080
# ⋮    ⋮                       ⋮
# 2430 GCF_018128905.1_protein #cea2fd
# 2431 GCF_030370195.1_protein #cea2fd
# 2432 GCF_030370215.1_protein #cea2fd
# 2433 GCF_030370355.1_protein #cea2fd
# 2434 GCF_020971705.1_protein #cea2fd
# 2435 GCF_030503855.1_protein #cea2fd
# 2436 GCF_036226405.1_protein #cea2fd
# 2437 GCF_031844685.1_protein #cea2fd
# 2438 GCF_000328545.1_protein #cea2fd
# 2439 GCF_016653495.1_protein #cea2fd
# 2440 GCF_036206925.1_protein #cea2fd
# 2441 GCF_008632955.1_protein #cea2fd
# 2442 GCF_028743695.1_protein #cea2fd
# 2443 GCF_035982055.1_protein #cea2fd
# 2444 GCF_021474145.1_protein #cea2fd
# 2445 GCF_000495635.2_protein #cea2fd
# 2446 GCF_019285735.1_protein #cea2fd
# 2447 GCF_000147815.2_protein #cea2fd
# 2448 GCF_020034615.1_protein #cea2fd
# 2449 GCF_008086425.1_protein #cea2fd
# 2450 GCF_016415165.1_protein #cea2fd
# 2451 GCF_008087605.1_protein #cea2fd
# 2452 GCF_036541015.1_protein #cea2fd
# 2453 GCF_002240035.1_protein #cea2fd
# 2454 GCF_019930805.1_protein #cea2fd
# 2455 GCF_001999985.1_protein #cea2fd
# 2456 GCF_003932965.1_protein #cea2fd
# 2457 GCF_036226805.1_protein #cea2fd
# 2458 GCF_008931805.1_protein #cea2fd
# 2459 GCF_024362265.1_protein #cea2fd

# %%
#VFDB - virulence factors

#select first columm
vfdb_itol_represent <- vfdb_70id_60cov[,1]
colnames(vfdb_itol_represent) <- "Sequence"

#take fisrt hit for each ID
vfdb_itol_represent <- distinct(vfdb_itol_represent)

#Extract ID and some part put in another columm
df_vfdb <- vfdb_itol_represent %>%
  mutate(GCF_ID = str_extract(Sequence, "^[^_]*_[^_]*"))

#add _protein to each line 
df_vfdb$Part1 <- paste0(df_vfdb$GCF_ID, "_protein")

#see what is different between datasets
diff_representative_vfdb <- setdiff(all_GCF_files %>% select(GCF_ID), df_vfdb %>% select(GCF_ID))
head(diff_representative_vfdb)


#Atributte color and attach string "_protein" to IDs which were not identified any protein
diff_representative_vfdb$level <- "#DC143C"

diff_representative_vfdb$GCF_ID <- paste0(diff_representative_vfdb$GCF_ID, "_protein")

write_tsv(diff_representative_vfdb,"genomes_download/plots_data/itol/no_virulence_sialylation.tsv")

#Atributte color and attach string "_protein" to ID's identified with protein
df_vfdb$level <- "#50C878"
df_vfdb1 <- df_vfdb[ , c(-1,-2)]

colnames(df_vfdb1) <- c("GCF_ID", "level")
write_tsv(df_vfdb,"genomes_download/plots_data/itol/virulence_sialylation.tsv")
#Join the data
data_vfdb_itol_represent <- rbind(df_vfdb1, diff_representative_vfdb)
head(data_vfdb_itol_represent)

#save results in a file
write_tsv(data_vfdb_itol_represent, "genomes_download/plots_data/itol/vfdb_itol_represent_EANS.tsv")
# Out:
#   GCF_ID
# 1 GCF_004353525.1
# 2 GCF_003019695.1
# 3 GCF_000348785.1
# 4 GCF_025151995.1
# 5 GCF_003019715.1
# 6 GCF_003055625.1
#   GCF_ID                  level
# 1 GCF_000006825.1_protein #50C878
# 2 GCF_000007265.1_protein #50C878
# 3 GCF_000007945.1_protein #50C878
# 4 GCF_000007985.2_protein #50C878
# 5 GCF_000008465.1_protein #50C878
# 6 GCF_000008485.1_protein #50C878

# %%
tail(data_vfdb_itol_represent)
# Out:
#   GCF_ID                  level
# 1 GCF_002209145.2_protein #DC143C
# 2 GCF_019048465.1_protein #DC143C
# 3 GCF_900475835.1_protein #DC143C
# 4 GCF_002871855.1_protein #DC143C
# 5 GCF_001513675.1_protein #DC143C
# 6 GCF_001975955.2_protein #DC143C

# %%
#label each node with specie name

#Upload data from host_distribution script
host_data_comm_sia_species <- read_delim("genomes_download/plots_data/itol/host_data_comm_sia_update_2026.tsv", 
                                 delim = "\t", escape_double = FALSE, 
                                 trim_ws = TRUE)
head(host_data_comm_sia_species)

select_ID_name <- host_data_comm_sia_species
select_ID_name$`Assembly Accession` <- paste0(select_ID_name$`Assembly Accession`, "_protein")


#save file
write_tsv(select_ID_name, "genomes_download/plots_data/itol/representative_labels_itol.tsv")
# Out:
# Rows: 2459 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (2): Assembly Accession, first_two_words
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   Assembly Accession first_two_words
# 1 GCF_000007985.2    Geobacter sulfurreducens
# 2 GCF_000009085.1    Campylobacter jejuni
# 3 GCF_000009465.1    Neisseria meningitidis
# 4 GCF_000012185.1    Haemophilus influenzae
# 5 GCF_000014105.1    Neisseria meningitidis
# 6 GCF_000019305.1    Clostridium botulinum

# %%
#label for phylum

accession_list_1 <- read_delim("genomes_download/plots_data/accession_complete_fields.tsv", 
                                 delim = "\t", escape_double = FALSE, 
                                 trim_ws = TRUE)
head(accession_list_1)
colnames(accession_list_1)

#select columm that I want
select_data <- accession_list_1%>% select('Assembly Accession', 'Assembly BioSample Host', 'Organism Taxonomic ID')

#ascending format by Taxonomic ID
select_data_asc <- select_data %>% arrange('Organism Taxonomic ID')
# Out:
# Rows: 2459 Columns: 11
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (6): Assembly Accession, Assembly BioSample Geographic location, Assembl...
# dbl (4): Assembly Stats GC Percent, Assembly Stats Total Sequence Length, Or...
# lgl (1): Organelle Assembly Name
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   Assembly Accession Assembly BioSample Geographic location
# 1 GCF_000007985.2    NA
# 2 GCF_000009085.1    NA
# 3 GCF_000009465.1    NA
# 4 GCF_000012185.1    NA
# 5 GCF_000014105.1    NA
# 6 GCF_000019305.1    NA
#   Assembly BioSample Host Assembly BioSample Host disease
# 1 NA                      NA
# 2 NA                      NA
# 3 NA                      NA
# 4 NA                      NA
# 5 NA                      NA
# 6 NA                      NA
#   Assembly BioSample Isolation source Assembly Stats GC Percent
# 1 NA                                  61.0
# 2 NA                                  30.5
# 3 NA                                  51.5
# 4 NA                                  38.0
# 5 NA                                  51.5
# 6 NA                                  28.0
#   Assembly Stats Total Sequence Length Organelle Assembly Name
# 1 3814128                              NA
# 2 1641481                              NA
# 3 2194961                              NA
# 4 1914490                              NA
# 5 2153416                              NA
# 6 4107013                              NA
#   Organism Name
# 1 Geobacter sulfurreducens PCA
# 2 Campylobacter jejuni subsp. jejuni NCTC 11168 = ATCC 700819
# 3 Neisseria meningitidis FAM18
# 4 Haemophilus influenzae 86-028NP
# 5 Neisseria meningitidis 053442
# 6 Clostridium botulinum B1 str. Okra
#   Organism Taxonomic ID Annotation Count Gene Protein-coding
# 1 243231                3405
# 2 192222                1572
# 3 272831                1971
# 4 281310                1785
# 5 374833                1909
# 6 498213                3741
#  [1] "Assembly Accession"
#  [2] "Assembly BioSample Geographic location"
#  [3] "Assembly BioSample Host"
#  [4] "Assembly BioSample Host disease"
#  [5] "Assembly BioSample Isolation source"
#  [6] "Assembly Stats GC Percent"
#  [7] "Assembly Stats Total Sequence Length"
#  [8] "Organelle Assembly Name"
#  [9] "Organism Name"
# [10] "Organism Taxonomic ID"
# [11] "Annotation Count Gene Protein-coding"

# %%
#Upload taxonomy info
taxonomy_summary <- read_delim("genomes_download/plots_data/taxonomy_summary.tsv", 
                               delim = "\t", escape_double = FALSE, 
                               trim_ws = TRUE)
head(taxonomy_summary)
# Out:
# Rows: 992 Columns: 27
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (16): Tax name, Authority, Rank, Basionym, Basionym authority, Curator c...
# dbl (10): Query, Taxid, Domain/Realm taxid, Kingdom taxid, Phylum taxid, Cla...
# lgl  (1): Scientific name is formal
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   Query   Taxid   Tax name                               Authority Rank
# 1  100226  100226 Streptomyces coelicolor A3(2)          NA        STRAIN
# 2 1002546 1002546 uncultured Cohaesibacter sp.           NA        SPECIES
# 3 1004951 1004951 Streptococcus suis ST1                 NA        STRAIN
# 4 1005041 1005041 Streptococcus suis SS12                NA        STRAIN
# 5 1031564 1031564 Campylobacter insulaenigrae NCTC 12927 NA        STRAIN
# 6 1031733 1031733 Campylobacter upsaliensis RM3940       NA        STRAIN
#   Basionym Basionym authority Curator common name Has type material
# 1 NA       NA                 NA                  no
# 2 NA       NA                 NA                  no
# 3 NA       NA                 NA                  no
# 4 NA       NA                 NA                  no
# 5 NA       NA                 NA                  no
# 6 NA       NA                 NA                  no
#   Group name                      ⋯ Class taxid Order name        Order taxid
# 1 high G+C Gram-positive bacteria ⋯    1760     Kitasatosporales   85011
# 2 a-proteobacteria                ⋯   28211     Hyphomicrobiales     356
# 3 firmicutes                      ⋯   91061     Lactobacillales   186826
# 4 firmicutes                      ⋯   91061     Lactobacillales   186826
# 5 e-proteobacteria                ⋯ 3031852     Campylobacterales 213849
# 6 e-proteobacteria                ⋯ 3031852     Campylobacterales 213849
#   Family name        Family taxid Genus name    Genus taxid
# 1 Streptomycetaceae    2062       Streptomyces    1883
# 2 Cohaesibacteraceae 655351       Cohaesibacter 655352
# 3 Streptococcaceae     1300       Streptococcus   1301
# 4 Streptococcaceae     1300       Streptococcus   1301
# 5 Campylobacteraceae  72294       Campylobacter    194
# 6 Campylobacteraceae  72294       Campylobacter    194
#   Species name                 Species taxid Scientific name is formal
# 1 Streptomyces coelicolor         1902       FALSE
# 2 uncultured Cohaesibacter sp. 1002546       FALSE
# 3 Streptococcus suis              1307       FALSE
# 4 Streptococcus suis              1307       FALSE
# 5 Campylobacter insulaenigrae   260714       FALSE
# 6 Campylobacter upsaliensis      28080       FALSE

# %%
#let in ascending format by Taxonomic ID
select_taxo_asc <- taxonomy_summary %>% arrange('Query')

#rename data to join after
colnames(select_taxo_asc)[1] <- "Organism Taxonomic ID"

# %%
#join data
missed_data <- left_join(select_data_asc, select_taxo_asc, by = 'Organism Taxonomic ID')

# %%
select_phylum <- missed_data %>% select('Assembly Accession', 'Phylum name')

unique(select_phylum$`Phylum name`)
select_phylum$'Assembly Accession' <- paste0(select_phylum$'Assembly Accession', "_protein")
       
       select_phylum$label_type <- "label_background"
# Out:
# [1] "Thermodesulfobacteriota" "Campylobacterota"
# [3] "Pseudomonadota"          "Bacillota"
# [5] "Actinomycetota"          "Fusobacteriota"
# [7] "Cyanobacteriota"         "Bacteroidota"
# [9] "Balneolota"

# %%
head(select_phylum)
# Out:
#   Assembly Accession      Phylum name             label_type
# 1 GCF_000007985.2_protein Thermodesulfobacteriota label_background
# 2 GCF_000009085.1_protein Campylobacterota        label_background
# 3 GCF_000009465.1_protein Pseudomonadota          label_background
# 4 GCF_000012185.1_protein Pseudomonadota          label_background
# 5 GCF_000014105.1_protein Pseudomonadota          label_background
# 6 GCF_000019305.1_protein Bacillota               label_background

# %%
#count how many files 
select_phylum_counts <- table(select_phylum$`Phylum name`)
print(select_phylum_counts)
# Out:
#          Actinomycetota               Bacillota            Bacteroidota
#                     795                     245                      15
#              Balneolota        Campylobacterota         Cyanobacteriota
#                       1                     245                       3
#          Fusobacteriota          Pseudomonadota Thermodesulfobacteriota
#                       9                    1143                       3

# %%
result <- select_phylum %>%
  group_by(`Phylum name`) %>%
  summarise(count = n(), .groups = "drop") %>%
  mutate(
    percentage_raw = (count / sum(count)) * 100,
    percentage = round(percentage_raw, 2)
  )
print(result)
# Out:
# # A tibble: 9 × 4
#   `Phylum name`           count percentage_raw percentage
#   <chr>                   <int>          <dbl>      <dbl>
# 1 Actinomycetota            795        32.3         32.3
# 2 Bacillota                 245         9.96         9.96
# 3 Bacteroidota               15         0.610        0.61
# 4 Balneolota                  1         0.0407       0.04
# 5 Campylobacterota          245         9.96         9.96
# 6 Cyanobacteriota             3         0.122        0.12
# 7 Fusobacteriota              9         0.366        0.37
# 8 Pseudomonadota           1143        46.5         46.5
# 9 Thermodesulfobacteriota     3         0.122        0.12

# %%
#Atribbute color to matched phylum
       cor_names <- c("Pseudomonadota" = "#feebe2",  "Campylobacterota" = "#fbb4b9",
                      "Bacteroidota" = "#d7b5d8", "Bacillota"= "#f768a1",  "Balneolota" = "#df65b0",
                      "Fusobacteriota"= "#c51b8a", "Thermodesulfobacteriota"= "#dd1c77", 
                      "Actinomycetota"= "#980043", "Cyanobacteriota" = "#7a0177")
       #df65b0
       #for matched phylum, put hexcode color into another columm "COR_PHYLUM
       select_phylum$COR_PHYLUM <- ifelse(as.character(select_phylum$`Phylum name`) %in% names(cor_names),
                                          cor_names[as.character(select_phylum$`Phylum name`)], "NULL")
       #remove undesired columm
       select_phylum <- select_phylum[,-2]

# %%
head(select_phylum)
# Out:
#   Assembly Accession      label_type       COR_PHYLUM
# 1 GCF_000007985.2_protein label_background #dd1c77
# 2 GCF_000009085.1_protein label_background #fbb4b9
# 3 GCF_000009465.1_protein label_background #feebe2
# 4 GCF_000012185.1_protein label_background #feebe2
# 5 GCF_000014105.1_protein label_background #feebe2
# 6 GCF_000019305.1_protein label_background #f768a1

# %%
   #save result into a file - Iy's already at this PATH
       write_tsv(select_phylum, "genomes_download/plots_data/itol/representative_phylum_itol.tsv")
