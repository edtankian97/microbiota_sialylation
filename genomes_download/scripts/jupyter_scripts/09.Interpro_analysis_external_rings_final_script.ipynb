# %% [markdown]
# # Interpro analysis of external rings

# %%
# Upload libraries
library(readr)
library(data.table)
library(dplyr)
library(stringr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
# Set the working directory to the parent folder of plots_data/ or if you get new results, set setwd to PATH where the files are located.
# Example:
# setwd("~/microbiota_sialylation/genomes_download/")

# %%
setwd("/mnt/l/Sia_git/genomes_download/")

# %%
# Upload data
matched_KpsM_ID_interpro <- read_delim("plots_data/Interpro_results/KpsM_ID_final.tsv_retrieved_final_results.tsv", 
                                       delim = "\t", escape_double = FALSE, 
                                       col_names = FALSE, trim_ws = TRUE)

# set header
column_names_interpro <-c("Sequence", "md5", "unkown", "Bank", "signature", "annotation", "align_begin",
                          "align_end", "e-value","Hit", "date", "Interpro_code", "annotation_two", "unkown2", "unkown3")

setnames(matched_KpsM_ID_interpro, column_names_interpro)

head(matched_KpsM_ID_interpro)
nrow(matched_KpsM_ID_interpro)

# See unique names for annotation column
unique_annot_KpsM <- unique(matched_KpsM_ID_interpro$annotation)
unique_annot_KpsM
# Out:
# Rows: 11689 Columns: 15
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (11): X1, X2, X4, X5, X6, X9, X11, X12, X13, X14, X15
# dbl  (3): X3, X7, X8
# lgl  (1): X10
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   Sequence                                   md5
# 1 GCF_012224765.1_protein.faa_WP_167844504.1 05c8429d6d974e9df66e2c3ffaae9c11
# 2 GCF_012224765.1_protein.faa_WP_167844504.1 05c8429d6d974e9df66e2c3ffaae9c11
# 3 GCF_012224765.1_protein.faa_WP_167844504.1 05c8429d6d974e9df66e2c3ffaae9c11
# 4 GCF_012224765.1_protein.faa_WP_167844504.1 05c8429d6d974e9df66e2c3ffaae9c11
# 5 GCF_012224765.1_protein.faa_WP_167844504.1 05c8429d6d974e9df66e2c3ffaae9c11
# 6 GCF_012224765.1_protein.faa_WP_167844504.1 05c8429d6d974e9df66e2c3ffaae9c11
#   unkown Bank    signature
# 1 260    Pfam    PF01061
# 2 260    PANTHER PTHR30413
# 3 260    PRINTS  PR00164
# 4 260    PRINTS  PR00164
# 5 260    PRINTS  PR00164
# 6 260    PRINTS  PR00164
#   annotation                                             align_begin align_end
# 1 ABC-2 type transporter                                   5         218
# 2 INNER MEMBRANE TRANSPORT PERMEASE                        3         248
# 3 ABC-2 type transport system membrane protein signature  25          46
# 4 ABC-2 type transport system membrane protein signature 138         162
# 5 ABC-2 type transport system membrane protein signature 175         194
# 6 ABC-2 type transport system membrane protein signature 195         214
#   e-value Hit  date       Interpro_code
# 1 9.2E-8  TRUE 24-01-2026 IPR013525
# 2 1.7E-15 TRUE 24-01-2026 -
# 3 6.2E-8  TRUE 24-01-2026 IPR000412
# 4 6.2E-8  TRUE 24-01-2026 IPR000412
# 5 6.2E-8  TRUE 24-01-2026 IPR000412
# 6 6.2E-8  TRUE 24-01-2026 IPR000412
#   annotation_two                               unkown2 unkown3
# 1 ABC-2 type transporter, transmembrane domain -       -
# 2 -                                            -       -
# 3 ABC-2 transporter                            -       -
# 4 ABC-2 transporter                            -       -
# 5 ABC-2 transporter                            -       -
# 6 ABC-2 transporter                            -       -
# [1] 11689
# [1] "ABC-2 type transporter"
# [2] "INNER MEMBRANE TRANSPORT PERMEASE"
# [3] "ABC-2 type transport system membrane protein signature"
# [4] "DrrB"
# [5] "INNER MEMBRANE TRANSPORT PERMEASE YADH-RELATED"
# [6] "ABC transporter permease"
# [7] "consensus disorder prediction"
# [8] "NODULATION PROTEIN J"

# %%
# Filter by code of KpsM
patterns_KpsM <- c("PTHR30413","PS51012","PIRSF006648", "PF01061", "PR00164")

filtered_KpsM_interpro <- matched_KpsM_ID_interpro %>%
  filter(signature %in% patterns_KpsM)

# Get unique IDs
KpsM_interpro_distinct <- filtered_KpsM_interpro%>% distinct(Sequence, .keep_all = TRUE)
KpsM_interpro_distinct$GCF_ID <- str_extract(KpsM_interpro_distinct$Sequence, "^[^_]+_[^_]+") #extract GCF NCBI ID
KpsM_interpro_distinct_unique <- KpsM_interpro_distinct%>% distinct(GCF_ID, .keep_all = FALSE) #get unique GCF NCBI ID

nrow(filtered_KpsM_interpro)
nrow(KpsM_interpro_distinct_unique)
# Out:
# [1] 10698
# [1] 2172

# %%
#filter Interpro for KpsT
matched_KpsT_ID_interpro <- read_delim("plots_data/Interpro_results/KpsT_ID_final.tsv_retrieved_final_results.tsv", 
                                       delim = "\t", escape_double = FALSE, 
                                       col_names = FALSE, trim_ws = TRUE)

setnames(matched_KpsT_ID_interpro, column_names_interpro)

head(matched_KpsT_ID_interpro)
nrow(matched_KpsT_ID_interpro)

unique_annot_KpsT <- unique(matched_KpsT_ID_interpro$annotation)
unique_annot_KpsT
# Out:
# Rows: 11513 Columns: 15
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (11): X1, X2, X4, X5, X6, X9, X11, X12, X13, X14, X15
# dbl  (3): X3, X7, X8
# lgl  (1): X10
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   Sequence                                   md5
# 1 GCF_020410765.1_protein.faa_WP_086157215.1 b14d48c2285a6f69ba2a4bfb8a9d5d62
# 2 GCF_020410765.1_protein.faa_WP_086157215.1 b14d48c2285a6f69ba2a4bfb8a9d5d62
# 3 GCF_020410765.1_protein.faa_WP_086157215.1 b14d48c2285a6f69ba2a4bfb8a9d5d62
# 4 GCF_020410765.1_protein.faa_WP_086157215.1 b14d48c2285a6f69ba2a4bfb8a9d5d62
# 5 GCF_020410765.1_protein.faa_WP_086157215.1 b14d48c2285a6f69ba2a4bfb8a9d5d62
# 6 GCF_020410765.1_protein.faa_WP_086157215.1 b14d48c2285a6f69ba2a4bfb8a9d5d62
#   unkown Bank        signature
# 1 264    CDD         cd03220
# 2 264    SUPERFAMILY SSF52540
# 3 264    PANTHER     PTHR46743
# 4 264    Gene3D      G3DSA:3.40.50.300
# 5 264    Pfam        PF00005
# 6 264    SMART       SM00382
#   annotation                                           align_begin align_end
# 1 ABC_KpsT_Wzt                                         19          249
# 2 P-loop containing nucleoside triphosphate hydrolases 53          258
# 3 TEICHOIC ACIDS EXPORT ATP-BINDING PROTEIN TAGH       19          262
# 4 -                                                    49          263
# 5 ABC transporter                                      62          195
# 6 AAA_5                                                70          244
#   e-value     Hit  date       Interpro_code
# 1 4.01601E-94 TRUE 24-01-2026 IPR015860
# 2 5.0E-42     TRUE 24-01-2026 IPR027417
# 3 2.0E-89     TRUE 24-01-2026 IPR050683
# 4 4.6E-43     TRUE 24-01-2026 IPR027417
# 5 9.6E-16     TRUE 24-01-2026 IPR003439
# 6 1.3E-15     TRUE 24-01-2026 IPR003593
#   annotation_two                                      unkown2 unkown3
# 1 ABC transporter, teichoic acids export TagH-like    -       -
# 2 P-loop containing nucleoside triphosphate hydrolase -       -
# 3 Bacterial Polysaccharide Export ATP-binding         -       -
# 4 P-loop containing nucleoside triphosphate hydrolase -       -
# 5 ABC transporter-like, ATP-binding domain            -       -
# 6 AAA+ ATPase domain                                  -       -
# [1] 11513
#  [1] "ABC_KpsT_Wzt"
#  [2] "P-loop containing nucleoside triphosphate hydrolases"
#  [3] "TEICHOIC ACIDS EXPORT ATP-BINDING PROTEIN TAGH"
#  [4] "-"
#  [5] "ABC transporter"
#  [6] "AAA_5"
#  [7] "Wzt_C-like"
#  [8] "Wzt C-terminal domain"
#  [9] "consensus disorder prediction"
# [10] "Coil"
# [11] "ABC TRANSPORTER ATP-BINDING PROTEIN"
# [12] "ABC_DR_subfamily_A"
# [13] "ATP-BINDING CASSETTE, SUB-FAMILY H, MEMBER 1"
# [14] "ABC TRANSPORTER, ATP-BINDING PROTEIN"
# [15] "teichoic acids export protein ATP-binding subunit"
# [16] "teichoic acids export ABC transporter ATP-binding subunit TagH"
# [17] "Bacterial SH3 domain"
# [18] "SH3 Domains"
# [19] "sh3_bac_9"
# [20] "ABC_subfamily_A"
# [21] "SKFA PEPTIDE EXPORT ATP-BINDING PROTEIN SKFE"

# %%
# Filter by code for KpsT
patterns_KpsT <- c("G3DSA:3.40.50.300","PF00005","SM00382",
                   "PTHR46743","SSF52540","PS50893","PS00211","cd03220")

filtered_KpsT_interpro <- matched_KpsT_ID_interpro %>%
  filter(signature %in% patterns_KpsT)

# Get unique IDs
KpsT_interpro_distinct <- filtered_KpsT_interpro%>% distinct(Sequence, .keep_all = TRUE)
KpsT_interpro_distinct$GCF_ID <- str_extract(KpsT_interpro_distinct$Sequence, "^[^_]+_[^_]+") #extract GCF NCBI ID
KpsT_interpro_distinct_unique <- KpsT_interpro_distinct%>% distinct(GCF_ID, .keep_all = FALSE) #get unique GCF NCBI ID

nrow(filtered_KpsT_interpro)
nrow(KpsT_interpro_distinct_unique)
# Out:
# [1] 11033
# [1] 1849

# %%
#KpsD

#filter Interpro for KpsD
matched_KpsD_ID_interpro <- read_delim("plots_data/Interpro_results/KpsD_ID_final.tsv_retrieved_final_results.tsv", 
                                       delim = "\t", escape_double = FALSE, 
                                       col_names = FALSE, trim_ws = TRUE)

setnames(matched_KpsD_ID_interpro, column_names_interpro)

head(matched_KpsD_ID_interpro)
nrow(matched_KpsD_ID_interpro)

unique_annot_KpsD <- unique(matched_KpsD_ID_interpro$annotation)
unique_annot_KpsD
# Out:
# Rows: 6851 Columns: 15
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (11): X1, X2, X4, X5, X6, X9, X11, X12, X13, X14, X15
# dbl  (3): X3, X7, X8
# lgl  (1): X10
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   Sequence                                   md5
# 1 GCF_013357745.1_protein.faa_WP_000039770.1 c74d39c7bb81034ca45922fd9de0ca03
# 2 GCF_013357745.1_protein.faa_WP_000039770.1 c74d39c7bb81034ca45922fd9de0ca03
# 3 GCF_013357745.1_protein.faa_WP_000039770.1 c74d39c7bb81034ca45922fd9de0ca03
# 4 GCF_013357745.1_protein.faa_WP_000039770.1 c74d39c7bb81034ca45922fd9de0ca03
# 5 GCF_013357745.1_protein.faa_WP_000039770.1 c74d39c7bb81034ca45922fd9de0ca03
# 6 GCF_013357745.1_protein.faa_WP_000039770.1 c74d39c7bb81034ca45922fd9de0ca03
#   unkown Bank    signature
# 1 385    Gene3D  G3DSA:3.30.1950.10
# 2 385    Pfam    PF18412
# 3 385    Pfam    PF02563
# 4 385    Gene3D  G3DSA:3.10.560.10
# 5 385    Gene3D  G3DSA:3.10.560.10
# 6 385    PANTHER PTHR33619
#   annotation                                       align_begin align_end
# 1 wza like domain                                   88         167
# 2 Outer-membrane lipoprotein Wza C-terminal domain 352         381
# 3 Polysaccharide biosynthesis/export protein        80         163
# 4 Outer membrane lipoprotein wza domain like       173         250
# 5 Outer membrane lipoprotein wza domain like       253         349
# 6 POLYSACCHARIDE EXPORT PROTEIN GFCE-RELATED        12         371
#   e-value  Hit  date       Interpro_code
# 1 1.6E-108 TRUE 24-01-2026 -
# 2 5.8E-11  TRUE 24-01-2026 IPR040716
# 3 3.6E-22  TRUE 24-01-2026 IPR003715
# 4 1.6E-108 TRUE 24-01-2026 -
# 5 1.6E-108 TRUE 24-01-2026 -
# 6 2.9E-68  TRUE 24-01-2026 IPR049712
#   annotation_two                                    unkown2 unkown3
# 1 -                                                 -       -
# 2 Outer-membrane lipoprotein Wza, C-terminal domain -       -
# 3 Polysaccharide export protein, N-terminal domain  -       -
# 4 -                                                 -       -
# 5 -                                                 -       -
# 6 Polysaccharide export protein                     -       -
# [1] 6851
#  [1] "wza like domain"
#  [2] "Outer-membrane lipoprotein Wza C-terminal domain"
#  [3] "Polysaccharide biosynthesis/export protein"
#  [4] "Outer membrane lipoprotein wza domain like"
#  [5] "POLYSACCHARIDE EXPORT PROTEIN GFCE-RELATED"
#  [6] "polysaccharide export protein"
#  [7] "SLBB domain"
#  [8] "-"
#  [9] "Coil"
# [10] "consensus disorder prediction"
# [11] "Nqo1 middle domain-like"
# [12] "Capsule biosynthesis GfcC C-terminal"
# [13] "polysaccharide export protein EpsE"
# [14] "XrtA/PEP-CTERM system exopolysaccharide export protein, Rfer_0658/Tmz1t_3282 family"

# %%
# Filter by KpsD code
patterns_KpsD <- c("G3DSA:3.10.560.10","PTHR33619",
                   "PF10531","PF02563")

filtered_KpsD_interpro <- matched_KpsD_ID_interpro %>%
  filter(signature %in% patterns_KpsD)

# Get unique IDs
KpsD_interpro_distinct <- filtered_KpsD_interpro%>% distinct(Sequence, .keep_all = TRUE)
KpsD_interpro_distinct$GCF_ID <- str_extract(KpsD_interpro_distinct$Sequence, "^[^_]+_[^_]+") #extract GCF NCBI ID
KpsD_interpro_distinct_unique <- KpsD_interpro_distinct%>% distinct(GCF_ID, .keep_all = FALSE) #get unique GCF NCBI ID

nrow(filtered_KpsD_interpro)
nrow(KpsD_interpro_distinct_unique)
# Out:
# [1] 4519
# [1] 818

# %%
#neuO

matched_neuO_ID_interpro <- read_delim("plots_data/Interpro_results/neuO_ID_final.tsv_retrieved_final_results.tsv", 
                                       delim = "\t", escape_double = FALSE, 
                                       col_names = FALSE, trim_ws = TRUE)

setnames(matched_neuO_ID_interpro, column_names_interpro)
head(matched_neuO_ID_interpro)
nrow(matched_neuO_ID_interpro)

unique_annot_neuO <- unique(matched_neuO_ID_interpro$annotation)
unique_annot_neuO
# Out:
# Rows: 9276 Columns: 15
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (11): X1, X2, X4, X5, X6, X9, X11, X12, X13, X14, X15
# dbl  (3): X3, X7, X8
# lgl  (1): X10
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   Sequence                                   md5
# 1 GCF_008704715.1_protein.faa_WP_150504405.1 007e2eb5e2f839a632be266dfe33268a
# 2 GCF_008704715.1_protein.faa_WP_150504405.1 007e2eb5e2f839a632be266dfe33268a
# 3 GCF_008704715.1_protein.faa_WP_150504405.1 007e2eb5e2f839a632be266dfe33268a
# 4 GCF_008704715.1_protein.faa_WP_150504405.1 007e2eb5e2f839a632be266dfe33268a
# 5 GCF_008704715.1_protein.faa_WP_150504405.1 007e2eb5e2f839a632be266dfe33268a
# 6 GCF_008704715.1_protein.faa_WP_150504405.1 007e2eb5e2f839a632be266dfe33268a
#   unkown Bank        signature
# 1 272    CDD         cd04647
# 2 272    MobiDBLite  mobidb-lite
# 3 272    Pfam        PF00132
# 4 272    Gene3D      G3DSA:2.160.10.10
# 5 272    PANTHER     PTHR23416
# 6 272    SUPERFAMILY SSF51161
#   annotation                                      align_begin align_end
# 1 LbH_MAT_like                                     95         203
# 2 consensus disorder prediction                   209         228
# 3 Bacterial transferase hexapeptide (six repeats) 153         187
# 4 Hexapeptide repeat proteins                      10         211
# 5 SIALIC ACID SYNTHASE-RELATED                     54         212
# 6 Trimeric LpxA-like enzymes                       54         210
#   e-value     Hit  date       Interpro_code
# 1 4.80528E-33 TRUE 24-01-2026 -
# 2 -           TRUE 24-01-2026 -
# 3 4.1E-7      TRUE 24-01-2026 IPR001451
# 4 3.6E-36     TRUE 24-01-2026 -
# 5 2.8E-37     TRUE 24-01-2026 IPR051159
# 6 3.06E-36    TRUE 24-01-2026 IPR011004
#   annotation_two                                   unkown2 unkown3
# 1 -                                                -       -
# 2 -                                                -       -
# 3 Hexapeptide repeat                               -       -
# 4 -                                                -       -
# 5 Hexapeptide-repeat containing acetyltransferases -       -
# 6 Trimeric LpxA-like superfamily                   -       -
# [1] 9276
#  [1] "LbH_MAT_like"
#  [2] "consensus disorder prediction"
#  [3] "Bacterial transferase hexapeptide (six repeats)"
#  [4] "Hexapeptide repeat proteins"
#  [5] "SIALIC ACID SYNTHASE-RELATED"
#  [6] "Trimeric LpxA-like enzymes"
#  [7] "LbH_MAT_GAT"
#  [8] "Mac_2"
#  [9] "Maltose acetyltransferase hexapeptide capping motif"
# [10] "GALACTOSIDE O-ACETYLTRANSFERASE"
# [11] "Hexapeptide repeat of succinyl-transferase"
# [12] "galactoside O-acetyltransferase"
# [13] "ACETYLTRANSFERASE"
# [14] "LbH_XAT"
# [15] "maltose O-acetyltransferase"
# [16] "Coil"
# [17] "LbH_SAT"
# [18] "serine acetyltransferase, domain 1"
# [19] "serine O-acetyltransferase EpsC"
# [20] "serine O-acetyltransferase"
# [21] "SERINE ACETYLTRANSFERASE"
# [22] "CysE"
# [23] "-"
# [24] "Tropomyosin"
# [25] "Serine acetyltransferase, N-terminal"
# [26] "LbH_wcaF_like"
# [27] "WcaF family extracellular polysaccharide biosynthesis acetyltransferase"
# [28] "Chorismate mutase II"
# [29] "Chorismate mutase type II"
# [30] "CM_2_4"
# [31] "chorismate mutase"
# [32] "Chorismate mutase"
# [33] "LbH_WxcM_N_like"

# %%
# Filter by NeuO code 
patterns_neuO <- c("SSF51161","G3DSA:2.160.10.10")

filtered_neuO_interpro <- matched_neuO_ID_interpro %>%
  filter(signature %in% patterns_neuO)

# Get unique IDs
neuO_interpro_distinct <- filtered_neuO_interpro%>% distinct(Sequence, .keep_all = TRUE)
neuO_interpro_distinct$GCF_ID <- str_extract(neuO_interpro_distinct$Sequence, "^[^_]+_[^_]+") #extract GCF NCBI ID
neuO_interpro_distinct_unique <- neuO_interpro_distinct%>% distinct(GCF_ID, .keep_all = FALSE) #get unique GCF NCBI ID

nrow(filtered_neuO_interpro)
nrow(neuO_interpro_distinct_unique)
# Out:
# [1] 2777
# [1] 1386

# %%
#neuD

matched_neuD_ID_interpro <- read_delim("plots_data/Interpro_results/neuD_ID_final.tsv_retrieved_final_results.tsv", 
                                       delim = "\t", escape_double = FALSE, 
                                       col_names = FALSE, trim_ws = TRUE)

setnames(matched_neuD_ID_interpro, column_names_interpro)
head(matched_neuD_ID_interpro)
nrow(matched_neuD_ID_interpro)

unique_annot_neuD <- unique(matched_neuD_ID_interpro$annotation)
unique_annot_neuD
# Out:
# Rows: 9335 Columns: 15
# ── Column specification ──────────────────────────────────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (11): X1, X2, X4, X5, X6, X9, X11, X12, X13, X14, X15
# dbl  (3): X3, X7, X8
# lgl  (1): X10
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   Sequence                                   md5
# 1 GCF_036345175.1_protein.faa_WP_330292806.1 9c2f7dc1e8019dfe45188ae6cae9adef
# 2 GCF_036345175.1_protein.faa_WP_330292806.1 9c2f7dc1e8019dfe45188ae6cae9adef
# 3 GCF_036345175.1_protein.faa_WP_330292806.1 9c2f7dc1e8019dfe45188ae6cae9adef
# 4 GCF_036345175.1_protein.faa_WP_330292806.1 9c2f7dc1e8019dfe45188ae6cae9adef
# 5 GCF_036345175.1_protein.faa_WP_330292806.1 9c2f7dc1e8019dfe45188ae6cae9adef
# 6 GCF_036345175.1_protein.faa_WP_330292806.1 9c2f7dc1e8019dfe45188ae6cae9adef
#   unkown Bank        signature
# 1 229    PANTHER     PTHR43300
# 2 229    NCBIfam     TIGR03570
# 3 229    CDD         cd03360
# 4 229    Pfam        PF17836
# 5 229    SUPERFAMILY SSF51161
# 6 229    Gene3D      G3DSA:2.160.10.10
#   annotation                                    align_begin align_end
# 1 ACETYLTRANSFERASE                             89          211
# 2 NeuD/PglB/VioB family sugar acetyltransferase  4          206
# 3 LbH_AT_putative                                6          204
# 4 PglD N-terminal domain                         4           82
# 5 Trimeric LpxA-like enzymes                     2          213
# 6 Hexapeptide repeat proteins                   89          221
#   e-value     Hit  date       Interpro_code annotation_two
# 1 1.1E-22     TRUE 24-01-2026 IPR050179     Transferase hexapeptide repeat
# 2 3.8E-53     TRUE 24-01-2026 IPR020019     Acyltransferase PglD-like
# 3 4.95844E-59 TRUE 24-01-2026 IPR020019     Acyltransferase PglD-like
# 4 5.7E-6      TRUE 24-01-2026 IPR041561     PglD, N-terminal
# 5 1.52E-36    TRUE 24-01-2026 IPR011004     Trimeric LpxA-like superfamily
# 6 2.4E-27     TRUE 24-01-2026 -             -
#   unkown2 unkown3
# 1 -       -
# 2 -       -
# 3 -       -
# 4 -       -
# 5 -       -
# 6 -       -
# [1] 9335
#  [1] "ACETYLTRANSFERASE"
#  [2] "NeuD/PglB/VioB family sugar acetyltransferase"
#  [3] "LbH_AT_putative"
#  [4] "PglD N-terminal domain"
#  [5] "Trimeric LpxA-like enzymes"
#  [6] "Hexapeptide repeat proteins"
#  [7] "-"
#  [8] "Hexapeptide repeat of succinyl-transferase"
#  [9] "Bacterial transferase hexapeptide (six repeats)"
# [10] "2,3,4,5-tetrahydropyridine-2,6-dicarboxylate N-acetyltransferase"
# [11] "LbH_THP_succinylT"
# [12] "2,3,4,5-tetrahydropyridine-2,6-dicarboxylate N-acetyltransferase [dapH]."
# [13] "Tetrahydrodipicolinate succinyltransferase N-terminal"
# [14] "LbH_SAT"
# [15] "consensus disorder prediction"
# [16] "serine O-acetyltransferase EpsC"
# [17] "serine acetyltransferase, domain 1"
# [18] "SERINE ACETYLTRANSFERASE"
# [19] "serine O-acetyltransferase"
# [20] "LbH_gamma_CA_like"
# [21] "DYNACTIN SUBUNIT P25"
# [22] "CysE"
# [23] "GMPPB C-terminal domain"
# [24] "COLANIC BIOSYNTHESIS UDP-GLUCOSE LIPID CARRIER TRANSFERASE"
# [25] "Bacterial sugar transferase"
# [26] "SIALIC ACID SYNTHASE-RELATED"
# [27] "Serine acetyltransferase, N-terminal"
# [28] "Single hybrid motif"
# [29] "Coil"
# [30] "Biotin-requiring enzyme"
# [31] "NAD(P)-binding Rossmann-fold domains"
# [32] "ACYL-[ACYL-CARRIER-PROTEIN]--UDP-N-ACETYLGLUCOSAMINE O-ACYLTRANSFERASE"
# [33] "LbH_WxcM_N_like"
# [34] "S-adenosyl-L-methionine-dependent methyltransferases"
# [35] "UDP-3-O-(3-hydroxymyristoyl)glucosamine N-acyltransferase [lpxD]."
# [36] "UDP-3-O-ACYLGLUCOSAMINE N-ACYLTRANSFERASE"
# [37] "UDP-3-O-(3-hydroxymyristoyl)glucosamine N-acyltransferase"
# [38] "UDP-3-O-[3-hydroxymyristoyl] glucosamine N-acyltransferase, LpxD"
# [39] "LbH_LpxD"
# [40] "lipoyl_domain"

# %%
# Filter by NeuD Interpro code
patterns_neuD <- c("SSF51161","TIGR03570","cd03360","PF17836",
                   "PTHR43300","G3DSA:3.40.50.20","G3DSA:2.160.10.10","PS00101")

filtered_neuD_interpro <- matched_neuD_ID_interpro %>%
  filter(signature %in% patterns_neuD)

# Get unique IDs
neuD_interpro_distinct <- filtered_neuD_interpro%>% distinct(Sequence, .keep_all = TRUE)
neuD_interpro_distinct$GCF_ID <- str_extract(neuD_interpro_distinct$Sequence, "^[^_]+_[^_]+") #extract GCF NCBI ID
neuD_interpro_distinct_unique <- neuD_interpro_distinct%>% distinct(GCF_ID, .keep_all = FALSE) #get unique GCF NCBI ID

nrow(filtered_neuD_interpro)
nrow(neuD_interpro_distinct_unique)
# Out:
# [1] 8451
# [1] 1278

# %%
#save file with NCBI ID - Result is already available at PATH below
write_tsv(neuO_interpro_distinct_unique, "plots_data/itol/neuO_interpro_distinct_unique_phylogeny.tsv")
write_tsv(KpsT_interpro_distinct_unique, "plots_data/itol/KpsT_interpro_distinct_unique_phylogeny.tsv")
write_tsv(KpsM_interpro_distinct_unique, "plots_data/itol/KpsM_interpro_distinct_unique_phylogeny.tsv")
write_tsv(neuD_interpro_distinct_unique, "plots_data/itol/neuD_interpro_distinct_unique_phylogeny.tsv")
write_tsv(KpsD_interpro_distinct_unique, "plots_data/itol/KpsD_interpro_distinct_unique_phylogeny.tsv")
